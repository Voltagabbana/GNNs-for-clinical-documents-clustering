# %% [markdown]
# ########### NOTA BENE #################
#
# QUESTO E' IL FILE CHE COSTRUISCE I GRAFI PER INFOGRAPH!

# %%
### Nota bene 2 (modifiche di fine gennaio inizio febbraio): #########

# sto cercando ora di modificare i grafi per non essere solon grafi di linea ma anzi essere del tipo di text level
# gcn dove la matrice di adiacenza è sulla base delle parole adiacenti con una finestra "p"

# per valutare la bonta della produzione vado sul file ValutazioneGrafi.ipynb che analizza nel dettaglio i dataset di grafo creati
# cosicche sfrutto i file pickle e non devo rirunnare tutto il codice!

#Vedo CostruzioneGrafoPython per capire come sono stati creati i grafi!

# %%
import pickle
import numpy as np
import torch
from torch_geometric.data import Data
from torch_geometric.loader import DataLoader

# %%
with open('corpusParoleInutiliStemming.pkl', 'rb') as file:
    # Carica i dati dal file
    corpus_filtrato = pickle.load(file)
#len(corpus_filtrato[0])

# %%
with open("my_vecs_GennaioStemming.p", "rb") as file:
    word2Vec_model = pickle.load(file)

# %%
vocabolario = set()

for documento in corpus_filtrato:
    for parola in documento:
        vocabolario.add(parola)

# %%
word_names = word2Vec_model.wv.index_to_key

word_vectors = [word2Vec_model.wv[word] for word in word_names]

corpus_filtrato_embedding = []
for doc in corpus_filtrato:
    doc_embedding = []
    for parola in doc:
        doc_embedding.append(word2Vec_model.wv[parola])
    corpus_filtrato_embedding.append(doc_embedding)
    
#corpus_filtrato[1]
#word2Vec_model.wv['giovan']
#corpus_filtrato_embedding[0]

# %%
#Controllo se qualche documento ha una ripetizione di parole
def sono_tutte_diverse(lista):
    set_parole = set(lista)
    return len(set_parole) == len(lista)

# %%
sono_tutte_diverse(corpus_filtrato[0]) # NB osservo che ci sono (ovviamente ripetizioni di parole) dentro un documento!! Quindi 
#devo tenere conto di ciò quando costruisco la matrice di adiacenza del grafo!!

corpus_filtrato_embedding[1]

def sono_tutte_diverse(array):
    # Converte l'array in un array bidimensionale
    array_bidimensionale = np.array(array)

    # Controlla se tutte le liste interne sono diverse
    return len(array_bidimensionale) == len(set(map(tuple, array_bidimensionale)))
def conta_vettori_unici(array):
    # Converte l'array in un array bidimensionale
    array_bidimensionale = np.array(array)
    return len(set(map(tuple, array_bidimensionale)))
#Doc0 = np.array(corpus_filtrato_embedding[0])
#print(conta_vettori_unici(Doc0),len(set(corpus_filtrato[0]))
      #MOLTO BENE! HO OTTENUTO UN MODO PER TROVARE IL NUMERO DI PAROLE UNICHE DI UN DOCUMENTO
#def Toglie_Duplicati(array):
 #   Docunique = set(map(tuple, array))
  #  Docunique_array = np.array(list(Docunique))
   # return Docunique_array

# %%
#Doc0unique = set(map(tuple, Doc0))
#Doc0unique_array = np.array(list(Doc0unique))
#len(Doc0unique_array) ok torna
#conta_vettori_unici(Doc0)
# Out:
# 236

# %%
def checkParolaNuova(parola, dizionario):
            if parola in dizionario:
                #indice = diz[parola]
                return False
            else:
                #dizionario[parola]=len(dizionario)
                return True

# %%
''''
testo = ['io','oggi','sono','mela','oggi','banana','leggere','coltello','penna']
diz = {}
for parola in testo:
    print(checkParolaNuova(parola,diz))
diz
if(checkParolaNuova('cane',diz))==True:
    print('ciao')
diz

#provo su un toy example la mia strategia:

dim = len(set(testo))
A = np.zeros((dim,dim), dtype=int)
A
A = Crea_Matrice_Adiacenza(testo)
A
''''
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# {}

# %%
#VERSIONE DEFINITIVA PER CREARE MATRICE DI ADIACENZA DATO UN TESTO, PER TENER CONTO SE LA PAROLA ERA GIA USCITA, PER P = 1
#(DIREI CHE P = 2 NON LO FACCIAMO)
def Crea_Matrice_Adiacenza(testo):
    dim = len(set(testo))
    A = np.zeros((dim,dim), dtype=int)
    diz = {}
    for i,parola in enumerate(testo):
        if (checkParolaNuova(parola,diz)==True):

            diz[parola]=len(diz) #indiceNuovo = len(diz)
            indicei = diz[parola] 

        else:      
            indicei = diz[parola] 
        if i != 0:  
            if (checkParolaNuova(testo[i-1],diz)==True):
                diz[testo[i-1]]=len(diz)
                indicej = diz[testo[i-1]]
                A[indicei,indicej]=1

            else:
                indicej = diz[testo[i-1]]
                A[indicei,indicej]=1
        if i!= len(testo)-1:
            if (checkParolaNuova(testo[i+1],diz)==True):
                diz[testo[i+1]]=len(diz)
                indicej = diz[testo[i+1]]
                A[indicei,indicej]=1

            else:
                indicej = diz[testo[i+1]]
                A[indicei,indicej]=1
    return A

# %% [markdown]
# NB: questo codice funziona se gli passo il testo con le parole (corpus_filtrato), non posso farlo con corpus filtrato embedding!

# %%
# Nel ciclo for, per creare i file di formato "Data", devo avere le informazioni sia su corpus_filtrato_embedding che
# corpus_filtrato! QUindi per ovviare a ciò creo due liste in due cicli for (per embedding e non embedding e poi le accorpo)

# %%
A_list =[]
for i,Doc in enumerate(corpus_filtrato):
    A = Crea_Matrice_Adiacenza(Doc)
    A_list.append(A)

# %%
len(corpus_filtrato1[0])
# Out:
# 319

# %%
len(corpus_filtrato_embedding[0])
len(corpus_filtrato[0])
# Out:
# 401

# %%
len(set(corpus_filtrato1[0]))
# Out:
# 235

# %%
datasetGrafi
# Out:
# [Data(x=[236, 10], edge_index=[2, 740]),
#  Data(x=[365, 10], edge_index=[2, 1148]),
#  Data(x=[251, 10], edge_index=[2, 792]),
#  Data(x=[195, 10], edge_index=[2, 478]),
#  Data(x=[320, 10], edge_index=[2, 991]),
#  Data(x=[316, 10], edge_index=[2, 836]),
#  Data(x=[239, 10], edge_index=[2, 720]),
#  Data(x=[259, 10], edge_index=[2, 726]),
#  Data(x=[243, 10], edge_index=[2, 742]),
#  Data(x=[347, 10], edge_index=[2, 912]),
#  Data(x=[12, 10], edge_index=[2, 22]),
#  Data(x=[9, 10], edge_index=[2, 16]),
#  Data(x=[14, 10], edge_index=[2, 28]),
#  Data(x=[23, 10], edge_index=[2, 44]),
#  Data(x=[9, 10], edge_index=[2, 16]),
#  Data(x=[9, 10], edge_index=[2, 16]),
#  Data(x=[11, 10], edge_index=[2, 20]),
#  Data(x=[11, 10], edge_index=[2, 20]),
#  Data(x=[10, 10], edge_index=[2, 18]),
#  Data(x=[12, 10], edge_index=[2, 22]),
#  Data(x=[19, 10], edge_index=[2, 36]),
#  Data(x=[18, 10], edge_index=[2, 34]),
#  Data(x=[16, 10], edge_index=[2, 30]),
#  Data(x=[14, 10], edge_index=[2, 37]),
#  Data(x=[27, 10], edge_index=[2, 52]),
#  Data(x=[23, 10], edge_index=[2, 44]),
#  Data(x=[25, 10], edge_index=[2, 50]),
#  Data(x=[12, 10], edge_index=[2, 22]),
#  Data(x=[12, 10], edge_index=[2, 22]),
#  Data(x=[13, 10], edge_index=[2, 24]),
#  Data(x=[23, 10], edge_index=[2, 44]),
#  Data(x=[10, 10], edge_index=[2, 20]),
#  Data(x=[16, 10], edge_index=[2, 32]),
#  Data(x=[13, 10], edge_index=[2, 26]),
#  Data(x=[13, 10], edge_index=[2, 29]),
#  Data(x=[9, 10], edge_index=[2, 16]),
#  Data(x=[18, 10], edge_index=[2, 40]),
#  Data(x=[15, 10], edge_index=[2, 34]),
#  Data(x=[18, 10], edge_index=[2, 38]),
#  Data(x=[16, 10], edge_index=[2, 31]),
#  Data(x=[21, 10], edge_index=[2, 44]),
#  Data(x=[9, 10], edge_index=[2, 16]),
#  Data(x=[15, 10], edge_index=[2, 28]),
#  Data(x=[31, 10], edge_index=[2, 64]),
#  Data(x=[8, 10], edge_index=[2, 14]),
#  Data(x=[30, 10], edge_index=[2, 58]),
#  Data(x=[26, 10], edge_index=[2, 50]),
#  Data(x=[17, 10], edge_index=[2, 34]),
#  Data(x=[18, 10], edge_index=[2, 34]),
#  Data(x=[15, 10], edge_index=[2, 28]),
#  Data(x=[12, 10], edge_index=[2, 22]),
#  Data(x=[25, 10], edge_index=[2, 52]),
#  Data(x=[8, 10], edge_index=[2, 14]),
#  Data(x=[12, 10], edge_index=[2, 22]),
#  Data(x=[13, 10], edge_index=[2, 24]),
#  Data(x=[15, 10], edge_index=[2, 28]),
#  Data(x=[10, 10], edge_index=[2, 18]),
#  Data(x=[13, 10], edge_index=[2, 26]),
#  Data(x=[5, 10], edge_index=[2, 8]),
#  Data(x=[6, 10], edge_index=[2, 10]),
#  Data(x=[8, 10], edge_index=[2, 14]),
#  Data(x=[24, 10], edge_index=[2, 48]),
#  Data(x=[32, 10], edge_index=[2, 64]),
#  Data(x=[14, 10], edge_index=[2, 26]),
#  Data(x=[19, 10], edge_index=[2, 38]),
#  Data(x=[15, 10], edge_index=[2, 28]),
#  Data(x=[16, 10], edge_index=[2, 34]),
#  Data(x=[20, 10], edge_index=[2, 38]),
#  Data(x=[10, 10], edge_index=[2, 18]),
#  Data(x=[25, 10], edge_index=[2, 48]),
#  Data(x=[22, 10], edge_index=[2, 42]),
#  Data(x=[4, 10], edge_index=[2, 6]),
#  Data(x=[34, 10], edge_index=[2, 71]),
#  Data(x=[5, 10], edge_index=[2, 8]),
#  Data(x=[16, 10], edge_index=[2, 32]),
#  Data(x=[13, 10], edge_index=[2, 24]),
#  Data(x=[15, 10], edge_index=[2, 28]),
#  Data(x=[21, 10], edge_index=[2, 42]),
#  Data(x=[21, 10], edge_index=[2, 40]),
#  Data(x=[28, 10], edge_index=[2, 58]),
#  Data(x=[26, 10], edge_index=[2, 52]),
#  Data(x=[38, 10], edge_index=[2, 76]),
#  Data(x=[6, 10], edge_index=[2, 12]),
#  Data(x=[26, 10], edge_index=[2, 50]),
#  Data(x=[26, 10], edge_index=[2, 50]),
#  Data(x=[15, 10], edge_index=[2, 28]),
#  Data(x=[28, 10], edge_index=[2, 54]),
#  Data(x=[21, 10], edge_index=[2, 40]),
#  Data(x=[25, 10], edge_index=[2, 50]),
#  Data(x=[31, 10], edge_index=[2, 60]),
#  Data(x=[32, 10], edge_index=[2, 64]),
#  Data(x=[36, 10], edge_index=[2, 72]),
#  Data(x=[11, 10], edge_index=[2, 20]),
#  Data(x=[9, 10], edge_index=[2, 16]),
#  Data(x=[22, 10], edge_index=[2, 42]),
#  Data(x=[20, 10], edge_index=[2, 40]),
#  Data(x=[13, 10], edge_index=[2, 24]),
#  Data(x=[33, 10], edge_index=[2, 66]),
#  Data(x=[17, 10], edge_index=[2, 32]),
#  Data(x=[18, 10], edge_index=[2, 38]),
#  Data(x=[6, 10], edge_index=[2, 12]),
#  Data(x=[8, 10], edge_index=[2, 14]),
#  Data(x=[6, 10], edge_index=[2, 10]),
#  Data(x=[9, 10], edge_index=[2, 16]),
#  Data(x=[11, 10], edge_index=[2, 20]),
#  Data(x=[12, 10], edge_index=[2, 24]),
#  Data(x=[25, 10], edge_index=[2, 48]),
#  Data(x=[16, 10], edge_index=[2, 30]),
#  Data(x=[12, 10], edge_index=[2, 24]),
#  Data(x=[13, 10], edge_index=[2, 24]),
#  Data(x=[9, 10], edge_index=[2, 16]),
#  Data(x=[12, 10], edge_index=[2, 22]),
#  Data(x=[19, 10], edge_index=[2, 36]),
#  Data(x=[6, 10], edge_index=[2, 10]),
#  Data(x=[6, 10], edge_index=[2, 10]),
#  Data(x=[14, 10], edge_index=[2, 26]),
#  Data(x=[23, 10], edge_index=[2, 46]),
#  Data(x=[12, 10], edge_index=[2, 24]),
#  Data(x=[25, 10], edge_index=[2, 52]),
#  Data(x=[16, 10], edge_index=[2, 30]),
#  Data(x=[23, 10], edge_index=[2, 44]),
#  Data(x=[12, 10], edge_index=[2, 22]),
#  Data(x=[22, 10], edge_index=[2, 42]),
#  Data(x=[22, 10], edge_index=[2, 42]),
#  Data(x=[27, 10], edge_index=[2, 52]),
#  Data(x=[28, 10], edge_index=[2, 58]),
#  Data(x=[31, 10], edge_index=[2, 68]),
#  Data(x=[44, 10], edge_index=[2, 92]),
#  Data(x=[42, 10], edge_index=[2, 88]),
#  Data(x=[24, 10], edge_index=[2, 48]),
#  Data(x=[54, 10], edge_index=[2, 106]),
#  Data(x=[35, 10], edge_index=[2, 74]),
#  Data(x=[13, 10], edge_index=[2, 24]),
#  Data(x=[25, 10], edge_index=[2, 52]),
#  Data(x=[20, 10], edge_index=[2, 38]),
#  Data(x=[21, 10], edge_index=[2, 40]),
#  Data(x=[31, 10], edge_index=[2, 60]),
#  Data(x=[25, 10], edge_index=[2, 52]),
#  Data(x=[45, 10], edge_index=[2, 88]),
#  Data(x=[38, 10], edge_index=[2, 76]),
#  Data(x=[21, 10], edge_index=[2, 44]),
#  Data(x=[29, 10], edge_index=[2, 58]),
#  Data(x=[33, 10], edge_index=[2, 70]),
#  Data(x=[39, 10], edge_index=[2, 78]),
#  Data(x=[14, 10], edge_index=[2, 26]),
#  Data(x=[19, 10], edge_index=[2, 36]),
#  Data(x=[25, 10], edge_index=[2, 54]),
#  Data(x=[18, 10], edge_index=[2, 34]),
#  Data(x=[26, 10], edge_index=[2, 54]),
#  Data(x=[31, 10], edge_index=[2, 62]),
#  Data(x=[28, 10], edge_index=[2, 56]),
#  Data(x=[18, 10], edge_index=[2, 34]),
#  Data(x=[17, 10], edge_index=[2, 34]),
#  Data(x=[9, 10], edge_index=[2, 16]),
#  Data(x=[29, 10], edge_index=[2, 58]),
#  Data(x=[24, 10], edge_index=[2, 48]),
#  Data(x=[17, 10], edge_index=[2, 32]),
#  Data(x=[14, 10], edge_index=[2, 26]),
#  Data(x=[41, 10], edge_index=[2, 86]),
#  Data(x=[23, 10], edge_index=[2, 46]),
#  Data(x=[6, 10], edge_index=[2, 10]),
#  Data(x=[10, 10], edge_index=[2, 18]),
#  Data(x=[10, 10], edge_index=[2, 18]),
#  Data(x=[17, 10], edge_index=[2, 32]),
#  Data(x=[14, 10], edge_index=[2, 26]),
#  Data(x=[13, 10], edge_index=[2, 26]),
#  Data(x=[18, 10], edge_index=[2, 36]),
#  Data(x=[14, 10], edge_index=[2, 26]),
#  Data(x=[27, 10], edge_index=[2, 52]),
#  Data(x=[19, 10], edge_index=[2, 38]),
#  Data(x=[36, 10], edge_index=[2, 76]),
#  Data(x=[15, 10], edge_index=[2, 28]),
#  Data(x=[7, 10], edge_index=[2, 12]),
#  Data(x=[19, 10], edge_index=[2, 36]),
#  Data(x=[18, 10], edge_index=[2, 34]),
#  Data(x=[16, 10], edge_index=[2, 30]),
#  Data(x=[45, 10], edge_index=[2, 98]),
#  Data(x=[19, 10], edge_index=[2, 36]),
#  Data(x=[45, 10], edge_index=[2, 88]),
#  Data(x=[15, 10], edge_index=[2, 30]),
#  Data(x=[23, 10], edge_index=[2, 46]),
#  Data(x=[31, 10], edge_index=[2, 62]),
#  Data(x=[49, 10], edge_index=[2, 100]),
#  Data(x=[30, 10], edge_index=[2, 62]),
#  Data(x=[26, 10], edge_index=[2, 50]),
#  Data(x=[49, 10], edge_index=[2, 96]),
#  Data(x=[46, 10], edge_index=[2, 96]),
#  Data(x=[48, 10], edge_index=[2, 96]),
#  Data(x=[28, 10], edge_index=[2, 54]),
#  Data(x=[25, 10], edge_index=[2, 52]),
#  Data(x=[41, 10], edge_index=[2, 84]),
#  Data(x=[24, 10], edge_index=[2, 48]),
#  Data(x=[61, 10], edge_index=[2, 142]),
#  Data(x=[25, 10], edge_index=[2, 50]),
#  Data(x=[18, 10], edge_index=[2, 38]),
#  Data(x=[17, 10], edge_index=[2, 32]),
#  Data(x=[24, 10], edge_index=[2, 50]),
#  Data(x=[20, 10], edge_index=[2, 40]),
#  Data(x=[18, 10], edge_index=[2, 34]),
#  Data(x=[13, 10], edge_index=[2, 24]),
#  Data(x=[25, 10], edge_index=[2, 48]),
#  Data(x=[10, 10], edge_index=[2, 18]),
#  Data(x=[13, 10], edge_index=[2, 26]),
#  Data(x=[27, 10], edge_index=[2, 56]),
#  Data(x=[13, 10], edge_index=[2, 24]),
#  Data(x=[18, 10], edge_index=[2, 34]),
#  Data(x=[22, 10], edge_index=[2, 46]),
#  Data(x=[11, 10], edge_index=[2, 20]),
#  Data(x=[31, 10], edge_index=[2, 66]),
#  Data(x=[35, 10], edge_index=[2, 70]),
#  Data(x=[24, 10], edge_index=[2, 50]),
#  Data(x=[22, 10], edge_index=[2, 48]),
#  Data(x=[17, 10], edge_index=[2, 34]),
#  Data(x=[22, 10], edge_index=[2, 42]),
#  Data(x=[16, 10], edge_index=[2, 34]),
#  Data(x=[17, 10], edge_index=[2, 32]),
#  Data(x=[16, 10], edge_index=[2, 34]),
#  Data(x=[20, 10], edge_index=[2, 44]),
#  Data(x=[32, 10], edge_index=[2, 68]),
#  Data(x=[18, 10], edge_index=[2, 36]),
#  Data(x=[12, 10], edge_index=[2, 24]),
#  Data(x=[23, 10], edge_index=[2, 50]),
#  Data(x=[35, 10], edge_index=[2, 68]),
#  Data(x=[23, 10], edge_index=[2, 44]),
#  Data(x=[29, 10], edge_index=[2, 58]),
#  Data(x=[18, 10], edge_index=[2, 36]),
#  Data(x=[8, 10], edge_index=[2, 14]),
#  Data(x=[11, 10], edge_index=[2, 20]),
#  Data(x=[14, 10], edge_index=[2, 26]),
#  Data(x=[9, 10], edge_index=[2, 16]),
#  Data(x=[29, 10], edge_index=[2, 58]),
#  Data(x=[20, 10], edge_index=[2, 40]),
#  Data(x=[29, 10], edge_index=[2, 58]),
#  Data(x=[24, 10], edge_index=[2, 48]),
#  Data(x=[14, 10], edge_index=[2, 26]),
#  Data(x=[15, 10], edge_index=[2, 28]),
#  Data(x=[16, 10], edge_index=[2, 30]),
#  Data(x=[10, 10], edge_index=[2, 18]),
#  Data(x=[17, 10], edge_index=[2, 34]),
#  Data(x=[36, 10], edge_index=[2, 72]),
#  Data(x=[10, 10], edge_index=[2, 18]),
#  Data(x=[15, 10], edge_index=[2, 30]),
#  Data(x=[24, 10], edge_index=[2, 46]),
#  Data(x=[23, 10], edge_index=[2, 44]),
#  Data(x=[21, 10], edge_index=[2, 42]),
#  Data(x=[15, 10], edge_index=[2, 28]),
#  Data(x=[9, 10], edge_index=[2, 16]),
#  Data(x=[19, 10], edge_index=[2, 40]),
#  Data(x=[13, 10], edge_index=[2, 26]),
#  Data(x=[23, 10], edge_index=[2, 48]),
#  Data(x=[24, 10], edge_index=[2, 50]),
#  Data(x=[13, 10], edge_index=[2, 24]),
#  Data(x=[24, 10], edge_index=[2, 50]),
#  Data(x=[12, 10], edge_index=[2, 22]),
#  Data(x=[15, 10], edge_index=[2, 32]),
#  Data(x=[20, 10], edge_index=[2, 42]),
#  Data(x=[18, 10], edge_index=[2, 34]),
#  Data(x=[27, 10], edge_index=[2, 52]),
#  Data(x=[7, 10], edge_index=[2, 12]),
#  Data(x=[10, 10], edge_index=[2, 18]),
#  Data(x=[24, 10], edge_index=[2, 54]),
#  Data(x=[22, 10], edge_index=[2, 44]),
#  Data(x=[6, 10], edge_index=[2, 10]),
#  Data(x=[18, 10], edge_index=[2, 36]),
#  Data(x=[19, 10], edge_index=[2, 38]),
#  Data(x=[8, 10], edge_index=[2, 14]),
#  Data(x=[8, 10], edge_index=[2, 14]),
#  Data(x=[11, 10], edge_index=[2, 20]),
#  Data(x=[16, 10], edge_index=[2, 30]),
#  Data(x=[14, 10], edge_index=[2, 28]),
#  Data(x=[7, 10], edge_index=[2, 12]),
#  Data(x=[21, 10], edge_index=[2, 46]),
#  Data(x=[12, 10], edge_index=[2, 24]),
#  Data(x=[23, 10], edge_index=[2, 46]),
#  Data(x=[9, 10], edge_index=[2, 16]),
#  Data(x=[26, 10], edge_index=[2, 58]),
#  Data(x=[14, 10], edge_index=[2, 26]),
#  Data(x=[29, 10], edge_index=[2, 59]),
#  Data(x=[22, 10], edge_index=[2, 42]),
#  Data(x=[12, 10], edge_index=[2, 24]),
#  Data(x=[13, 10], edge_index=[2, 24]),
#  Data(x=[18, 10], edge_index=[2, 36]),
#  Data(x=[21, 10], edge_index=[2, 44]),
#  Data(x=[17, 10], edge_index=[2, 34]),
#  Data(x=[21, 10], edge_index=[2, 44]),
#  Data(x=[17, 10], edge_index=[2, 34]),
#  Data(x=[16, 10], edge_index=[2, 34]),
#  Data(x=[14, 10], edge_index=[2, 26]),
#  Data(x=[13, 10], edge_index=[2, 24]),
#  Data(x=[16, 10], edge_index=[2, 34]),
#  Data(x=[12, 10], edge_index=[2, 22]),
#  Data(x=[10, 10], edge_index=[2, 18]),
#  Data(x=[12, 10], edge_index=[2, 22]),
#  Data(x=[9, 10], edge_index=[2, 16]),
#  Data(x=[17, 10], edge_index=[2, 32]),
#  Data(x=[12, 10], edge_index=[2, 22]),
#  Data(x=[14, 10], edge_index=[2, 26]),
#  Data(x=[17, 10], edge_index=[2, 32]),
#  Data(x=[18, 10], edge_index=[2, 36]),
#  Data(x=[14, 10], edge_index=[2, 26]),
#  Data(x=[11, 10], edge_index=[2, 20]),
#  Data(x=[6, 10], edge_index=[2, 10]),
#  Data(x=[6, 10], edge_index=[2, 10]),
#  Data(x=[10, 10], edge_index=[2, 18]),
#  Data(x=[8, 10], edge_index=[2, 14]),
#  Data(x=[5, 10], edge_index=[2, 8]),
#  Data(x=[11, 10], edge_index=[2, 20]),
#  Data(x=[28, 10], edge_index=[2, 58]),
#  Data(x=[6, 10], edge_index=[2, 10]),
#  Data(x=[26, 10], edge_index=[2, 56]),
#  Data(x=[16, 10], edge_index=[2, 30]),
#  Data(x=[11, 10], edge_index=[2, 20]),
#  Data(x=[41, 10], edge_index=[2, 80]),
#  Data(x=[284, 10], edge_index=[2, 756]),
#  Data(x=[78, 10], edge_index=[2, 168]),
#  Data(x=[83, 10], edge_index=[2, 202]),
#  Data(x=[116, 10], edge_index=[2, 280]),
#  Data(x=[49, 10], edge_index=[2, 136]),
#  Data(x=[109, 10], edge_index=[2, 238]),
#  Data(x=[68, 10], edge_index=[2, 154]),
#  Data(x=[114, 10], edge_index=[2, 262]),
#  Data(x=[104, 10], edge_index=[2, 222]),
#  Data(x=[96, 10], edge_index=[2, 234]),
#  Data(x=[94, 10], edge_index=[2, 214]),
#  Data(x=[121, 10], edge_index=[2, 270]),
#  Data(x=[107, 10], edge_index=[2, 244]),
#  Data(x=[69, 10], edge_index=[2, 150]),
#  Data(x=[97, 10], edge_index=[2, 224]),
#  Data(x=[99, 10], edge_index=[2, 228]),
#  Data(x=[109, 10], edge_index=[2, 242]),
#  Data(x=[91, 10], edge_index=[2, 206]),
#  Data(x=[111, 10], edge_index=[2, 272]),
#  Data(x=[86, 10], edge_index=[2, 204]),
#  Data(x=[104, 10], edge_index=[2, 258]),
#  Data(x=[122, 10], edge_index=[2, 280]),
#  Data(x=[106, 10], edge_index=[2, 264]),
#  Data(x=[104, 10], edge_index=[2, 254]),
#  Data(x=[116, 10], edge_index=[2, 262]),
#  Data(x=[120, 10], edge_index=[2, 264]),
#  Data(x=[125, 10], edge_index=[2, 277]),
#  Data(x=[125, 10], edge_index=[2, 286]),
#  Data(x=[128, 10], edge_index=[2, 288]),
#  Data(x=[111, 10], edge_index=[2, 272]),
#  Data(x=[109, 10], edge_index=[2, 256]),
#  Data(x=[91, 10], edge_index=[2, 224]),
#  Data(x=[125, 10], edge_index=[2, 310]),
#  Data(x=[110, 10], edge_index=[2, 230]),
#  Data(x=[125, 10], edge_index=[2, 270]),
#  Data(x=[121, 10], edge_index=[2, 260]),
#  Data(x=[105, 10], edge_index=[2, 238]),
#  Data(x=[121, 10], edge_index=[2, 262]),
#  Data(x=[129, 10], edge_index=[2, 272]),
#  Data(x=[120, 10], edge_index=[2, 278]),
#  Data(x=[104, 10], edge_index=[2, 232]),
#  Data(x=[97, 10], edge_index=[2, 212]),
#  Data(x=[102, 10], edge_index=[2, 248]),
#  Data(x=[103, 10], edge_index=[2, 234]),
#  Data(x=[117, 10], edge_index=[2, 280]),
#  Data(x=[91, 10], edge_index=[2, 214]),
#  Data(x=[89, 10], edge_index=[2, 206]),
#  Data(x=[108, 10], edge_index=[2, 256]),
#  Data(x=[109, 10], edge_index=[2, 260]),
#  Data(x=[112, 10], edge_index=[2, 260]),
#  Data(x=[90, 10], edge_index=[2, 184]),
#  Data(x=[48, 10], edge_index=[2, 94]),
#  Data(x=[55, 10], edge_index=[2, 120]),
#  Data(x=[87, 10], edge_index=[2, 196]),
#  Data(x=[88, 10], edge_index=[2, 194]),
#  Data(x=[81, 10], edge_index=[2, 186]),
#  Data(x=[105, 10], edge_index=[2, 244]),
#  Data(x=[97, 10], edge_index=[2, 226]),
#  Data(x=[95, 10], edge_index=[2, 214]),
#  Data(x=[83, 10], edge_index=[2, 202]),
#  Data(x=[98, 10], edge_index=[2, 224]),
#  Data(x=[43, 10], edge_index=[2, 88]),
#  Data(x=[105, 10], edge_index=[2, 250]),
#  Data(x=[96, 10], edge_index=[2, 230]),
#  Data(x=[45, 10], edge_index=[2, 96]),
#  Data(x=[105, 10], edge_index=[2, 252]),
#  Data(x=[48, 10], edge_index=[2, 98]),
#  Data(x=[103, 10], edge_index=[2, 252]),
#  Data(x=[126, 10], edge_index=[2, 280]),
#  Data(x=[109, 10], edge_index=[2, 254]),
#  Data(x=[119, 10], edge_index=[2, 286]),
#  Data(x=[59, 10], edge_index=[2, 140]),
#  Data(x=[112, 10], edge_index=[2, 238]),
#  Data(x=[84, 10], edge_index=[2, 182]),
#  Data(x=[93, 10], edge_index=[2, 202]),
#  Data(x=[71, 10], edge_index=[2, 164]),
#  Data(x=[126, 10], edge_index=[2, 294]),
#  Data(x=[80, 10], edge_index=[2, 206]),
#  Data(x=[84, 10], edge_index=[2, 184]),
#  Data(x=[98, 10], edge_index=[2, 256]),
#  Data(x=[77, 10], edge_index=[2, 172]),
#  Data(x=[78, 10], edge_index=[2, 168]),
#  Data(x=[79, 10], edge_index=[2, 174]),
#  Data(x=[111, 10], edge_index=[2, 254]),
#  Data(x=[129, 10], edge_index=[2, 282]),
#  Data(x=[80, 10], edge_index=[2, 184]),
#  Data(x=[98, 10], edge_index=[2, 209]),
#  Data(x=[78, 10], edge_index=[2, 169]),
#  Data(x=[92, 10], edge_index=[2, 218]),
#  Data(x=[77, 10], edge_index=[2, 184]),
#  Data(x=[91, 10], edge_index=[2, 200]),
#  Data(x=[77, 10], edge_index=[2, 164]),
#  Data(x=[86, 10], edge_index=[2, 194]),
#  Data(x=[77, 10], edge_index=[2, 184]),
#  Data(x=[77, 10], edge_index=[2, 192]),
#  Data(x=[98, 10], edge_index=[2, 236]),
#  Data(x=[75, 10], edge_index=[2, 166]),
#  Data(x=[143, 10], edge_index=[2, 316]),
#  Data(x=[118, 10], edge_index=[2, 268]),
#  Data(x=[109, 10], edge_index=[2, 284]),
#  Data(x=[69, 10], edge_index=[2, 148]),
#  Data(x=[81, 10], edge_index=[2, 176]),
#  Data(x=[110, 10], edge_index=[2, 248]),
#  Data(x=[80, 10], edge_index=[2, 186]),
#  Data(x=[100, 10], edge_index=[2, 234]),
#  Data(x=[70, 10], edge_index=[2, 164]),
#  Data(x=[46, 10], edge_index=[2, 102]),
#  Data(x=[79, 10], edge_index=[2, 174]),
#  Data(x=[107, 10], edge_index=[2, 246]),
#  Data(x=[69, 10], edge_index=[2, 154]),
#  Data(x=[96, 10], edge_index=[2, 220]),
#  Data(x=[105, 10], edge_index=[2, 248]),
#  Data(x=[79, 10], edge_index=[2, 180]),
#  Data(x=[102, 10], edge_index=[2, 232]),
#  Data(x=[85, 10], edge_index=[2, 182]),
#  Data(x=[108, 10], edge_index=[2, 257]),
#  Data(x=[94, 10], edge_index=[2, 212]),
#  Data(x=[99, 10], edge_index=[2, 218]),
#  Data(x=[112, 10], edge_index=[2, 278]),
#  Data(x=[116, 10], edge_index=[2, 264]),
#  Data(x=[104, 10], edge_index=[2, 248]),
#  Data(x=[81, 10], edge_index=[2, 176]),
#  Data(x=[97, 10], edge_index=[2, 222]),
#  Data(x=[109, 10], edge_index=[2, 262]),
#  Data(x=[79, 10], edge_index=[2, 190]),
#  Data(x=[64, 10], edge_index=[2, 136]),
#  Data(x=[84, 10], edge_index=[2, 188]),
#  Data(x=[85, 10], edge_index=[2, 189]),
#  Data(x=[78, 10], edge_index=[2, 178]),
#  Data(x=[92, 10], edge_index=[2, 213]),
#  Data(x=[69, 10], edge_index=[2, 142]),
#  Data(x=[105, 10], edge_index=[2, 224]),
#  Data(x=[78, 10], edge_index=[2, 166]),
#  Data(x=[105, 10], edge_index=[2, 262]),
#  Data(x=[84, 10], edge_index=[2, 200]),
#  Data(x=[86, 10], edge_index=[2, 188]),
#  Data(x=[91, 10], edge_index=[2, 216]),
#  Data(x=[102, 10], edge_index=[2, 226]),
#  Data(x=[102, 10], edge_index=[2, 224]),
#  Data(x=[112, 10], edge_index=[2, 244]),
#  Data(x=[110, 10], edge_index=[2, 246]),
#  Data(x=[115, 10], edge_index=[2, 270]),
#  Data(x=[115, 10], edge_index=[2, 272]),
#  Data(x=[125, 10], edge_index=[2, 278]),
#  Data(x=[73, 10], edge_index=[2, 170]),
#  Data(x=[77, 10], edge_index=[2, 174]),
#  Data(x=[105, 10], edge_index=[2, 246]),
#  Data(x=[103, 10], edge_index=[2, 230]),
#  Data(x=[75, 10], edge_index=[2, 160]),
#  Data(x=[50, 10], edge_index=[2, 102]),
#  Data(x=[85, 10], edge_index=[2, 176]),
#  Data(x=[98, 10], edge_index=[2, 224]),
#  Data(x=[87, 10], edge_index=[2, 191]),
#  Data(x=[81, 10], edge_index=[2, 184]),
#  Data(x=[74, 10], edge_index=[2, 166]),
#  Data(x=[84, 10], edge_index=[2, 190]),
#  Data(x=[199, 10], edge_index=[2, 480]),
#  Data(x=[94, 10], edge_index=[2, 210]),
#  Data(x=[79, 10], edge_index=[2, 168]),
#  Data(x=[46, 10], edge_index=[2, 96]),
#  Data(x=[99, 10], edge_index=[2, 222]),
#  Data(x=[77, 10], edge_index=[2, 180]),
#  Data(x=[100, 10], edge_index=[2, 222]),
#  Data(x=[123, 10], edge_index=[2, 286]),
#  Data(x=[104, 10], edge_index=[2, 230]),
#  Data(x=[36, 10], edge_index=[2, 74]),
#  Data(x=[84, 10], edge_index=[2, 198]),
#  Data(x=[209, 10], edge_index=[2, 486]),
#  Data(x=[72, 10], edge_index=[2, 160]),
#  Data(x=[115, 10], edge_index=[2, 264]),
#  Data(x=[81, 10], edge_index=[2, 190]),
#  Data(x=[80, 10], edge_index=[2, 174]),
#  Data(x=[94, 10], edge_index=[2, 200]),
#  Data(x=[189, 10], edge_index=[2, 474]),
#  Data(x=[68, 10], edge_index=[2, 148]),
#  Data(x=[76, 10], edge_index=[2, 172]),
#  Data(x=[123, 10], edge_index=[2, 270]),
#  Data(x=[78, 10], edge_index=[2, 176]),
#  Data(x=[54, 10], edge_index=[2, 116]),
#  Data(x=[39, 10], edge_index=[2, 78]),
#  Data(x=[99, 10], edge_index=[2, 228]),
#  Data(x=[86, 10], edge_index=[2, 180]),
#  Data(x=[114, 10], edge_index=[2, 262]),
#  Data(x=[115, 10], edge_index=[2, 272]),
#  Data(x=[131, 10], edge_index=[2, 284]),
#  Data(x=[122, 10], edge_index=[2, 278]),
#  Data(x=[129, 10], edge_index=[2, 292]),
#  Data(x=[88, 10], edge_index=[2, 200]),
#  Data(x=[92, 10], edge_index=[2, 196]),
#  Data(x=[79, 10], edge_index=[2, 172]),
#  Data(x=[92, 10], edge_index=[2, 220]),
#  Data(x=[101, 10], edge_index=[2, 232]),
#  Data(x=[109, 10], edge_index=[2, 246]),
#  Data(x=[116, 10], edge_index=[2, 271]),
#  Data(x=[93, 10], edge_index=[2, 226]),
#  Data(x=[82, 10], edge_index=[2, 184]),
#  Data(x=[91, 10], edge_index=[2, 194]),
#  Data(x=[73, 10], edge_index=[2, 157]),
#  Data(x=[48, 10], edge_index=[2, 98]),
#  Data(x=[99, 10], edge_index=[2, 262]),
#  Data(x=[86, 10], edge_index=[2, 206]),
#  Data(x=[78, 10], edge_index=[2, 180]),
#  Data(x=[83, 10], edge_index=[2, 186]),
#  Data(x=[55, 10], edge_index=[2, 128]),
#  Data(x=[99, 10], edge_index=[2, 222]),
#  Data(x=[117, 10], edge_index=[2, 268]),
#  Data(x=[107, 10], edge_index=[2, 236]),
#  Data(x=[96, 10], edge_index=[2, 212]),
#  Data(x=[90, 10], edge_index=[2, 192]),
#  Data(x=[87, 10], edge_index=[2, 182]),
#  Data(x=[71, 10], edge_index=[2, 156]),
#  Data(x=[114, 10], edge_index=[2, 254]),
#  Data(x=[115, 10], edge_index=[2, 252]),
#  Data(x=[134, 10], edge_index=[2, 300]),
#  Data(x=[77, 10], edge_index=[2, 186]),
#  Data(x=[73, 10], edge_index=[2, 158]),
#  Data(x=[77, 10], edge_index=[2, 174]),
#  Data(x=[110, 10], edge_index=[2, 256]),
#  Data(x=[73, 10], edge_index=[2, 156]),
#  Data(x=[131, 10], edge_index=[2, 310]),
#  Data(x=[92, 10], edge_index=[2, 200]),
#  Data(x=[97, 10], edge_index=[2, 214]),
#  Data(x=[106, 10], edge_index=[2, 262]),
#  Data(x=[100, 10], edge_index=[2, 232]),
#  Data(x=[107, 10], edge_index=[2, 246]),
#  Data(x=[123, 10], edge_index=[2, 288]),
#  Data(x=[82, 10], edge_index=[2, 184]),
#  Data(x=[94, 10], edge_index=[2, 210]),
#  Data(x=[81, 10], edge_index=[2, 168]),
#  Data(x=[65, 10], edge_index=[2, 146]),
#  Data(x=[84, 10], edge_index=[2, 203]),
#  Data(x=[83, 10], edge_index=[2, 200]),
#  Data(x=[36, 10], edge_index=[2, 76]),
#  Data(x=[104, 10], edge_index=[2, 236]),
#  Data(x=[91, 10], edge_index=[2, 200]),
#  Data(x=[101, 10], edge_index=[2, 212]),
#  Data(x=[74, 10], edge_index=[2, 162]),
#  Data(x=[76, 10], edge_index=[2, 160]),
#  Data(x=[96, 10], edge_index=[2, 214]),
#  Data(x=[86, 10], edge_index=[2, 184]),
#  Data(x=[78, 10], edge_index=[2, 215]),
#  Data(x=[87, 10], edge_index=[2, 190]),
#  Data(x=[111, 10], edge_index=[2, 268]),
#  Data(x=[113, 10], edge_index=[2, 260]),
#  Data(x=[96, 10], edge_index=[2, 228]),
#  Data(x=[106, 10], edge_index=[2, 252]),
#  Data(x=[42, 10], edge_index=[2, 88]),
#  Data(x=[111, 10], edge_index=[2, 250]),
#  Data(x=[88, 10], edge_index=[2, 208]),
#  Data(x=[78, 10], edge_index=[2, 172]),
#  Data(x=[59, 10], edge_index=[2, 120]),
#  Data(x=[90, 10], edge_index=[2, 198]),
#  Data(x=[95, 10], edge_index=[2, 218]),
#  Data(x=[75, 10], edge_index=[2, 164]),
#  Data(x=[97, 10], edge_index=[2, 236]),
#  Data(x=[76, 10], edge_index=[2, 180]),
#  Data(x=[31, 10], edge_index=[2, 66]),
#  Data(x=[38, 10], edge_index=[2, 90]),
#  Data(x=[52, 10], edge_index=[2, 108]),
#  Data(x=[53, 10], edge_index=[2, 114]),
#  Data(x=[103, 10], edge_index=[2, 254]),
#  Data(x=[116, 10], edge_index=[2, 275]),
#  Data(x=[119, 10], edge_index=[2, 272]),
#  Data(x=[90, 10], edge_index=[2, 198]),
#  Data(x=[95, 10], edge_index=[2, 220]),
#  Data(x=[99, 10], edge_index=[2, 226]),
#  Data(x=[92, 10], edge_index=[2, 194]),
#  Data(x=[103, 10], edge_index=[2, 262]),
#  Data(x=[119, 10], edge_index=[2, 266]),
#  Data(x=[55, 10], edge_index=[2, 148]),
#  Data(x=[80, 10], edge_index=[2, 184]),
#  Data(x=[69, 10], edge_index=[2, 150]),
#  Data(x=[81, 10], edge_index=[2, 186]),
#  Data(x=[99, 10], edge_index=[2, 244]),
#  Data(x=[102, 10], edge_index=[2, 250]),
#  Data(x=[121, 10], edge_index=[2, 288]),
#  Data(x=[91, 10], edge_index=[2, 196]),
#  Data(x=[102, 10], edge_index=[2, 238]),
#  Data(x=[90, 10], edge_index=[2, 219]),
#  Data(x=[83, 10], edge_index=[2, 204]),
#  Data(x=[66, 10], edge_index=[2, 150]),
#  Data(x=[93, 10], edge_index=[2, 198]),
#  Data(x=[83, 10], edge_index=[2, 200]),
#  Data(x=[72, 10], edge_index=[2, 160]),
#  Data(x=[76, 10], edge_index=[2, 164]),
#  Data(x=[62, 10], edge_index=[2, 134]),
#  Data(x=[64, 10], edge_index=[2, 140]),
#  Data(x=[65, 10], edge_index=[2, 146]),
#  Data(x=[82, 10], edge_index=[2, 178]),
#  Data(x=[66, 10], edge_index=[2, 156]),
#  Data(x=[73, 10], edge_index=[2, 170]),
#  Data(x=[106, 10], edge_index=[2, 258]),
#  Data(x=[99, 10], edge_index=[2, 216]),
#  Data(x=[115, 10], edge_index=[2, 266]),
#  Data(x=[123, 10], edge_index=[2, 284]),
#  Data(x=[84, 10], edge_index=[2, 188]),
#  Data(x=[74, 10], edge_index=[2, 170]),
#  Data(x=[80, 10], edge_index=[2, 210]),
#  Data(x=[79, 10], edge_index=[2, 172]),
#  Data(x=[91, 10], edge_index=[2, 206]),
#  Data(x=[124, 10], edge_index=[2, 284]),
#  Data(x=[94, 10], edge_index=[2, 210]),
#  Data(x=[110, 10], edge_index=[2, 244]),
#  Data(x=[105, 10], edge_index=[2, 220]),
#  Data(x=[55, 10], edge_index=[2, 108]),
#  Data(x=[79, 10], edge_index=[2, 166]),
#  Data(x=[78, 10], edge_index=[2, 186]),
#  Data(x=[80, 10], edge_index=[2, 204]),
#  Data(x=[102, 10], edge_index=[2, 242]),
#  Data(x=[124, 10], edge_index=[2, 290]),
#  Data(x=[92, 10], edge_index=[2, 210]),
#  Data(x=[119, 10], edge_index=[2, 276]),
#  Data(x=[92, 10], edge_index=[2, 226]),
#  Data(x=[100, 10], edge_index=[2, 224]),
#  Data(x=[98, 10], edge_index=[2, 234]),
#  Data(x=[110, 10], edge_index=[2, 238]),
#  Data(x=[87, 10], edge_index=[2, 200]),
#  Data(x=[86, 10], edge_index=[2, 182]),
#  Data(x=[110, 10], edge_index=[2, 262]),
#  Data(x=[105, 10], edge_index=[2, 256]),
#  Data(x=[115, 10], edge_index=[2, 282]),
#  Data(x=[118, 10], edge_index=[2, 272]),
#  Data(x=[93, 10], edge_index=[2, 206]),
#  Data(x=[104, 10], edge_index=[2, 248]),
#  Data(x=[91, 10], edge_index=[2, 216]),
#  Data(x=[111, 10], edge_index=[2, 258]),
#  Data(x=[74, 10], edge_index=[2, 176]),
#  Data(x=[109, 10], edge_index=[2, 261]),
#  Data(x=[114, 10], edge_index=[2, 264]),
#  Data(x=[107, 10], edge_index=[2, 230]),
#  Data(x=[106, 10], edge_index=[2, 244]),
#  Data(x=[109, 10], edge_index=[2, 261]),
#  Data(x=[112, 10], edge_index=[2, 264]),
#  Data(x=[92, 10], edge_index=[2, 216]),
#  Data(x=[99, 10], edge_index=[2, 246]),
#  Data(x=[102, 10], edge_index=[2, 244]),
#  Data(x=[114, 10], edge_index=[2, 276]),
#  Data(x=[73, 10], edge_index=[2, 167]),
#  Data(x=[95, 10], edge_index=[2, 210]),
#  Data(x=[70, 10], edge_index=[2, 156]),
#  Data(x=[109, 10], edge_index=[2, 232]),
#  Data(x=[63, 10], edge_index=[2, 142]),
#  Data(x=[88, 10], edge_index=[2, 188]),
#  Data(x=[91, 10], edge_index=[2, 218]),
#  Data(x=[72, 10], edge_index=[2, 152]),
#  Data(x=[94, 10], edge_index=[2, 214]),
#  Data(x=[73, 10], edge_index=[2, 160]),
#  Data(x=[186, 10], edge_index=[2, 452]),
#  Data(x=[53, 10], edge_index=[2, 110]),
#  Data(x=[110, 10], edge_index=[2, 250]),
#  Data(x=[77, 10], edge_index=[2, 160]),
#  Data(x=[78, 10], edge_index=[2, 182]),
#  Data(x=[81, 10], edge_index=[2, 170]),
#  Data(x=[64, 10], edge_index=[2, 150]),
#  Data(x=[75, 10], edge_index=[2, 178]),
#  Data(x=[70, 10], edge_index=[2, 148]),
#  Data(x=[81, 10], edge_index=[2, 182]),
#  Data(x=[95, 10], edge_index=[2, 204]),
#  Data(x=[100, 10], edge_index=[2, 234]),
#  Data(x=[90, 10], edge_index=[2, 198]),
#  Data(x=[99, 10], edge_index=[2, 244]),
#  Data(x=[91, 10], edge_index=[2, 226]),
#  Data(x=[70, 10], edge_index=[2, 162]),
#  Data(x=[86, 10], edge_index=[2, 196]),
#  Data(x=[129, 10], edge_index=[2, 288]),
#  Data(x=[98, 10], edge_index=[2, 212]),
#  Data(x=[116, 10], edge_index=[2, 274]),
#  Data(x=[90, 10], edge_index=[2, 200]),
#  Data(x=[81, 10], edge_index=[2, 198]),
#  Data(x=[56, 10], edge_index=[2, 128]),
#  Data(x=[78, 10], edge_index=[2, 186]),
#  Data(x=[65, 10], edge_index=[2, 150]),
#  Data(x=[77, 10], edge_index=[2, 176]),
#  Data(x=[76, 10], edge_index=[2, 166]),
#  Data(x=[79, 10], edge_index=[2, 184]),
#  Data(x=[83, 10], edge_index=[2, 178]),
#  Data(x=[88, 10], edge_index=[2, 196]),
#  Data(x=[87, 10], edge_index=[2, 222]),
#  Data(x=[80, 10], edge_index=[2, 164]),
#  Data(x=[83, 10], edge_index=[2, 174]),
#  Data(x=[85, 10], edge_index=[2, 194]),
#  Data(x=[77, 10], edge_index=[2, 174]),
#  Data(x=[91, 10], edge_index=[2, 198]),
#  Data(x=[74, 10], edge_index=[2, 164]),
#  Data(x=[109, 10], edge_index=[2, 248]),
#  Data(x=[67, 10], edge_index=[2, 144]),
#  Data(x=[88, 10], edge_index=[2, 196]),
#  Data(x=[88, 10], edge_index=[2, 182]),
#  Data(x=[70, 10], edge_index=[2, 148]),
#  Data(x=[75, 10], edge_index=[2, 160]),
#  Data(x=[81, 10], edge_index=[2, 166]),
#  Data(x=[80, 10], edge_index=[2, 170]),
#  Data(x=[99, 10], edge_index=[2, 214]),
#  Data(x=[103, 10], edge_index=[2, 232]),
#  Data(x=[111, 10], edge_index=[2, 252]),
#  Data(x=[111, 10], edge_index=[2, 264]),
#  Data(x=[74, 10], edge_index=[2, 156]),
#  Data(x=[94, 10], edge_index=[2, 230]),
#  Data(x=[113, 10], edge_index=[2, 258]),
#  Data(x=[73, 10], edge_index=[2, 162]),
#  Data(x=[80, 10], edge_index=[2, 184]),
#  Data(x=[121, 10], edge_index=[2, 278]),
#  Data(x=[113, 10], edge_index=[2, 272]),
#  Data(x=[77, 10], edge_index=[2, 168]),
#  Data(x=[70, 10], edge_index=[2, 178]),
#  Data(x=[77, 10], edge_index=[2, 174]),
#  Data(x=[70, 10], edge_index=[2, 158]),
#  Data(x=[84, 10], edge_index=[2, 192]),
#  Data(x=[96, 10], edge_index=[2, 208]),
#  Data(x=[111, 10], edge_index=[2, 250]),
#  Data(x=[90, 10], edge_index=[2, 208]),
#  Data(x=[64, 10], edge_index=[2, 150]),
#  Data(x=[76, 10], edge_index=[2, 166]),
#  Data(x=[85, 10], edge_index=[2, 186]),
#  Data(x=[70, 10], edge_index=[2, 163]),
#  Data(x=[80, 10], edge_index=[2, 180]),
#  Data(x=[94, 10], edge_index=[2, 210]),
#  Data(x=[104, 10], edge_index=[2, 267]),
#  Data(x=[76, 10], edge_index=[2, 172]),
#  Data(x=[94, 10], edge_index=[2, 220]),
#  Data(x=[50, 10], edge_index=[2, 100]),
#  Data(x=[98, 10], edge_index=[2, 236]),
#  Data(x=[90, 10], edge_index=[2, 204]),
#  Data(x=[87, 10], edge_index=[2, 210]),
#  Data(x=[100, 10], edge_index=[2, 254]),
#  Data(x=[94, 10], edge_index=[2, 212]),
#  Data(x=[69, 10], edge_index=[2, 164]),
#  Data(x=[74, 10], edge_index=[2, 168]),
#  Data(x=[66, 10], edge_index=[2, 154]),
#  Data(x=[50, 10], edge_index=[2, 104]),
#  Data(x=[67, 10], edge_index=[2, 150]),
#  Data(x=[87, 10], edge_index=[2, 192]),
#  Data(x=[76, 10], edge_index=[2, 169]),
#  Data(x=[53, 10], edge_index=[2, 138]),
#  Data(x=[112, 10], edge_index=[2, 270]),
#  Data(x=[79, 10], edge_index=[2, 182]),
#  Data(x=[87, 10], edge_index=[2, 198]),
#  Data(x=[91, 10], edge_index=[2, 210]),
#  Data(x=[103, 10], edge_index=[2, 248]),
#  Data(x=[97, 10], edge_index=[2, 226]),
#  Data(x=[82, 10], edge_index=[2, 178]),
#  Data(x=[94, 10], edge_index=[2, 218]),
#  Data(x=[89, 10], edge_index=[2, 206]),
#  Data(x=[81, 10], edge_index=[2, 189]),
#  Data(x=[78, 10], edge_index=[2, 172]),
#  Data(x=[73, 10], edge_index=[2, 164]),
#  Data(x=[121, 10], edge_index=[2, 303]),
#  Data(x=[79, 10], edge_index=[2, 176]),
#  Data(x=[68, 10], edge_index=[2, 158]),
#  Data(x=[84, 10], edge_index=[2, 182]),
#  Data(x=[88, 10], edge_index=[2, 204]),
#  Data(x=[104, 10], edge_index=[2, 220]),
#  Data(x=[127, 10], edge_index=[2, 310]),
#  Data(x=[75, 10], edge_index=[2, 169]),
#  Data(x=[76, 10], edge_index=[2, 166]),
#  Data(x=[80, 10], edge_index=[2, 174]),
#  Data(x=[91, 10], edge_index=[2, 206]),
#  Data(x=[90, 10], edge_index=[2, 212]),
#  Data(x=[84, 10], edge_index=[2, 196]),
#  Data(x=[92, 10], edge_index=[2, 214]),
#  Data(x=[76, 10], edge_index=[2, 160]),
#  Data(x=[115, 10], edge_index=[2, 266]),
#  Data(x=[78, 10], edge_index=[2, 158]),
#  Data(x=[81, 10], edge_index=[2, 166]),
#  Data(x=[99, 10], edge_index=[2, 220]),
#  Data(x=[77, 10], edge_index=[2, 166]),
#  Data(x=[88, 10], edge_index=[2, 196]),
#  Data(x=[83, 10], edge_index=[2, 176]),
#  Data(x=[117, 10], edge_index=[2, 268]),
#  Data(x=[102, 10], edge_index=[2, 222]),
#  Data(x=[115, 10], edge_index=[2, 244]),
#  Data(x=[115, 10], edge_index=[2, 256]),
#  Data(x=[92, 10], edge_index=[2, 212]),
#  Data(x=[193, 10], edge_index=[2, 448]),
#  Data(x=[86, 10], edge_index=[2, 204]),
#  Data(x=[94, 10], edge_index=[2, 226]),
#  Data(x=[90, 10], edge_index=[2, 203]),
#  Data(x=[58, 10], edge_index=[2, 136]),
#  Data(x=[72, 10], edge_index=[2, 164]),
#  Data(x=[93, 10], edge_index=[2, 223]),
#  Data(x=[80, 10], edge_index=[2, 188]),
#  Data(x=[95, 10], edge_index=[2, 204]),
#  Data(x=[104, 10], edge_index=[2, 234]),
#  Data(x=[80, 10], edge_index=[2, 174]),
#  Data(x=[93, 10], edge_index=[2, 204]),
#  Data(x=[75, 10], edge_index=[2, 164]),
#  Data(x=[84, 10], edge_index=[2, 198]),
#  Data(x=[79, 10], edge_index=[2, 172]),
#  Data(x=[99, 10], edge_index=[2, 236]),
#  Data(x=[76, 10], edge_index=[2, 168]),
#  Data(x=[96, 10], edge_index=[2, 226]),
#  Data(x=[82, 10], edge_index=[2, 198]),
#  Data(x=[85, 10], edge_index=[2, 192]),
#  Data(x=[90, 10], edge_index=[2, 200]),
#  Data(x=[95, 10], edge_index=[2, 204]),
#  Data(x=[100, 10], edge_index=[2, 224]),
#  Data(x=[97, 10], edge_index=[2, 226]),
#  Data(x=[86, 10], edge_index=[2, 216]),
#  Data(x=[81, 10], edge_index=[2, 172]),
#  Data(x=[87, 10], edge_index=[2, 184]),
#  Data(x=[90, 10], edge_index=[2, 232]),
#  Data(x=[81, 10], edge_index=[2, 180]),
#  Data(x=[105, 10], edge_index=[2, 224]),
#  Data(x=[100, 10], edge_index=[2, 218]),
#  Data(x=[90, 10], edge_index=[2, 206]),
#  Data(x=[96, 10], edge_index=[2, 209]),
#  Data(x=[106, 10], edge_index=[2, 228]),
#  Data(x=[92, 10], edge_index=[2, 192]),
#  Data(x=[116, 10], edge_index=[2, 276]),
#  Data(x=[89, 10], edge_index=[2, 192]),
#  Data(x=[83, 10], edge_index=[2, 208]),
#  Data(x=[67, 10], edge_index=[2, 158]),
#  Data(x=[88, 10], edge_index=[2, 200]),
#  Data(x=[98, 10], edge_index=[2, 220]),
#  Data(x=[83, 10], edge_index=[2, 174]),
#  Data(x=[84, 10], edge_index=[2, 172]),
#  Data(x=[87, 10], edge_index=[2, 192]),
#  Data(x=[94, 10], edge_index=[2, 208]),
#  Data(x=[80, 10], edge_index=[2, 162]),
#  Data(x=[91, 10], edge_index=[2, 186]),
#  Data(x=[88, 10], edge_index=[2, 192]),
#  Data(x=[75, 10], edge_index=[2, 166]),
#  Data(x=[88, 10], edge_index=[2, 212]),
#  Data(x=[78, 10], edge_index=[2, 180]),
#  Data(x=[96, 10], edge_index=[2, 210]),
#  Data(x=[75, 10], edge_index=[2, 184]),
#  Data(x=[69, 10], edge_index=[2, 154]),
#  Data(x=[89, 10], edge_index=[2, 204]),
#  Data(x=[72, 10], edge_index=[2, 162]),
#  Data(x=[99, 10], edge_index=[2, 220]),
#  Data(x=[74, 10], edge_index=[2, 174]),
#  Data(x=[120, 10], edge_index=[2, 270]),
#  Data(x=[82, 10], edge_index=[2, 168]),
#  Data(x=[87, 10], edge_index=[2, 221]),
#  Data(x=[92, 10], edge_index=[2, 204]),
#  Data(x=[106, 10], edge_index=[2, 246]),
#  Data(x=[82, 10], edge_index=[2, 182]),
#  Data(x=[79, 10], edge_index=[2, 162]),
#  Data(x=[110, 10], edge_index=[2, 250]),
#  Data(x=[93, 10], edge_index=[2, 202]),
#  Data(x=[97, 10], edge_index=[2, 224]),
#  Data(x=[106, 10], edge_index=[2, 266]),
#  Data(x=[42, 10], edge_index=[2, 84]),
#  Data(x=[307, 10], edge_index=[2, 984]),
#  Data(x=[304, 10], edge_index=[2, 864]),
#  Data(x=[37, 10], edge_index=[2, 72]),
#  Data(x=[26, 10], edge_index=[2, 54]),
#  Data(x=[30, 10], edge_index=[2, 62]),
#  Data(x=[43, 10], edge_index=[2, 90]),
#  Data(x=[55, 10], edge_index=[2, 112]),
#  Data(x=[49, 10], edge_index=[2, 106]),
#  Data(x=[58, 10], edge_index=[2, 138]),
#  Data(x=[47, 10], edge_index=[2, 106]),
#  Data(x=[53, 10], edge_index=[2, 106]),
#  Data(x=[59, 10], edge_index=[2, 128]),
#  Data(x=[48, 10], edge_index=[2, 108]),
#  Data(x=[48, 10], edge_index=[2, 104]),
#  Data(x=[71, 10], edge_index=[2, 166]),
#  Data(x=[54, 10], edge_index=[2, 140]),
#  Data(x=[37, 10], edge_index=[2, 80]),
#  Data(x=[18, 10], edge_index=[2, 36]),
#  Data(x=[18, 10], edge_index=[2, 36]),
#  Data(x=[23, 10], edge_index=[2, 48]),
#  Data(x=[61, 10], edge_index=[2, 130]),
#  Data(x=[35, 10], edge_index=[2, 74]),
#  Data(x=[44, 10], edge_index=[2, 96]),
#  Data(x=[42, 10], edge_index=[2, 96]),
#  Data(x=[40, 10], edge_index=[2, 82]),
#  Data(x=[70, 10], edge_index=[2, 154]),
#  Data(x=[35, 10], edge_index=[2, 70]),
#  Data(x=[60, 10], edge_index=[2, 138]),
#  Data(x=[72, 10], edge_index=[2, 158]),
#  Data(x=[73, 10], edge_index=[2, 156]),
#  Data(x=[45, 10], edge_index=[2, 96]),
#  Data(x=[58, 10], edge_index=[2, 128]),
#  Data(x=[70, 10], edge_index=[2, 150]),
#  Data(x=[89, 10], edge_index=[2, 188]),
#  Data(x=[99, 10], edge_index=[2, 220]),
#  Data(x=[58, 10], edge_index=[2, 122]),
#  Data(x=[92, 10], edge_index=[2, 216]),
#  Data(x=[67, 10], edge_index=[2, 142]),
#  Data(x=[40, 10], edge_index=[2, 82]),
#  Data(x=[52, 10], edge_index=[2, 106]),
#  Data(x=[55, 10], edge_index=[2, 112]),
#  Data(x=[56, 10], edge_index=[2, 112]),
#  Data(x=[57, 10], edge_index=[2, 132]),
#  Data(x=[62, 10], edge_index=[2, 130]),
#  Data(x=[54, 10], edge_index=[2, 118]),
#  Data(x=[67, 10], edge_index=[2, 140]),
#  Data(x=[31, 10], edge_index=[2, 64]),
#  Data(x=[80, 10], edge_index=[2, 174]),
#  Data(x=[77, 10], edge_index=[2, 174]),
#  Data(x=[43, 10], edge_index=[2, 88]),
#  Data(x=[32, 10], edge_index=[2, 62]),
#  Data(x=[58, 10], edge_index=[2, 133]),
#  Data(x=[23, 10], edge_index=[2, 48]),
#  Data(x=[78, 10], edge_index=[2, 182]),
#  Data(x=[33, 10], edge_index=[2, 74]),
#  Data(x=[27, 10], edge_index=[2, 52]),
#  Data(x=[46, 10], edge_index=[2, 100]),
#  Data(x=[37, 10], edge_index=[2, 78]),
#  Data(x=[40, 10], edge_index=[2, 82]),
#  Data(x=[31, 10], edge_index=[2, 60]),
#  Data(x=[44, 10], edge_index=[2, 90]),
#  Data(x=[55, 10], edge_index=[2, 122]),
#  Data(x=[60, 10], edge_index=[2, 128]),
#  Data(x=[76, 10], edge_index=[2, 178]),
#  Data(x=[58, 10], edge_index=[2, 133]),
#  Data(x=[68, 10], edge_index=[2, 154]),
#  Data(x=[42, 10], edge_index=[2, 90]),
#  Data(x=[20, 10], edge_index=[2, 42]),
#  Data(x=[68, 10], edge_index=[2, 154]),
#  Data(x=[24, 10], edge_index=[2, 46]),
#  Data(x=[24, 10], edge_index=[2, 46]),
#  Data(x=[19, 10], edge_index=[2, 40]),
#  Data(x=[49, 10], edge_index=[2, 104]),
#  Data(x=[85, 10], edge_index=[2, 182]),
#  Data(x=[38, 10], edge_index=[2, 80]),
#  Data(x=[25, 10], edge_index=[2, 48]),
#  Data(x=[31, 10], edge_index=[2, 62]),
#  Data(x=[55, 10], edge_index=[2, 132]),
#  Data(x=[52, 10], edge_index=[2, 108]),
#  Data(x=[39, 10], edge_index=[2, 86]),
#  Data(x=[49, 10], edge_index=[2, 108]),
#  Data(x=[63, 10], edge_index=[2, 142]),
#  Data(x=[62, 10], edge_index=[2, 134]),
#  Data(x=[72, 10], edge_index=[2, 160]),
#  Data(x=[57, 10], edge_index=[2, 128]),
#  Data(x=[51, 10], edge_index=[2, 106]),
#  Data(x=[54, 10], edge_index=[2, 114]),
#  Data(x=[45, 10], edge_index=[2, 98]),
#  Data(x=[74, 10], edge_index=[2, 154]),
#  Data(x=[33, 10], edge_index=[2, 74]),
#  Data(x=[41, 10], edge_index=[2, 82]),
#  Data(x=[88, 10], edge_index=[2, 208]),
#  Data(x=[47, 10], edge_index=[2, 96]),
#  Data(x=[52, 10], edge_index=[2, 104]),
#  Data(x=[81, 10], edge_index=[2, 180]),
#  Data(x=[102, 10], edge_index=[2, 238]),
#  Data(x=[309, 10], edge_index=[2, 956]),
#  Data(x=[104, 10], edge_index=[2, 248]),
#  Data(x=[65, 10], edge_index=[2, 148]),
#  Data(x=[56, 10], edge_index=[2, 149]),
#  Data(x=[77, 10], edge_index=[2, 158]),
#  Data(x=[91, 10], edge_index=[2, 232]),
#  Data(x=[126, 10], edge_index=[2, 286]),
#  Data(x=[113, 10], edge_index=[2, 248]),
#  Data(x=[104, 10], edge_index=[2, 252]),
#  Data(x=[84, 10], edge_index=[2, 202]),
#  Data(x=[99, 10], edge_index=[2, 230]),
#  Data(x=[72, 10], edge_index=[2, 154]),
#  Data(x=[35, 10], edge_index=[2, 74]),
#  Data(x=[333, 10], edge_index=[2, 948]),
#  Data(x=[300, 10], edge_index=[2, 792]),
#  Data(x=[210, 10], edge_index=[2, 506]),
#  Data(x=[39, 10], edge_index=[2, 80]),
#  Data(x=[263, 10], edge_index=[2, 796]),
#  Data(x=[109, 10], edge_index=[2, 246]),
#  Data(x=[185, 10], edge_index=[2, 466]),
#  Data(x=[339, 10], edge_index=[2, 1042]),
#  Data(x=[172, 10], edge_index=[2, 480]),
#  Data(x=[290, 10], edge_index=[2, 841]),
#  Data(x=[167, 10], edge_index=[2, 452]),
#  Data(x=[317, 10], edge_index=[2, 952]),
#  Data(x=[113, 10], edge_index=[2, 266]),
#  Data(x=[222, 10], edge_index=[2, 574]),
#  Data(x=[221, 10], edge_index=[2, 572]),
#  Data(x=[180, 10], edge_index=[2, 486]),
#  Data(x=[215, 10], edge_index=[2, 546]),
#  Data(x=[173, 10], edge_index=[2, 482]),
#  Data(x=[165, 10], edge_index=[2, 448]),
#  Data(x=[29, 10], edge_index=[2, 58]),
#  Data(x=[33, 10], edge_index=[2, 70]),
#  Data(x=[20, 10], edge_index=[2, 38]),
#  Data(x=[26, 10], edge_index=[2, 54]),
#  Data(x=[22, 10], edge_index=[2, 44]),
#  Data(x=[11, 10], edge_index=[2, 20]),
#  Data(x=[19, 10], edge_index=[2, 38]),
#  Data(x=[24, 10], edge_index=[2, 48]),
#  Data(x=[13, 10], edge_index=[2, 24]),
#  Data(x=[11, 10], edge_index=[2, 20]),
#  Data(x=[21, 10], edge_index=[2, 42]),
#  Data(x=[15, 10], edge_index=[2, 28]),
#  Data(x=[14, 10], edge_index=[2, 26]),
#  Data(x=[11, 10], edge_index=[2, 20]),
#  Data(x=[25, 10], edge_index=[2, 48]),
#  Data(x=[14, 10], edge_index=[2, 26]),
#  ...]

# %%
# NB non andava bene la funzione con set perchè toglieva l'ordinamento!!!!!!!

def Toglie_Duplicati(array):
    Docunique_list = []
    seen = set()

    for item in array:
        item_tuple = tuple(item)
        if item_tuple not in seen:
            seen.add(item_tuple)
            Docunique_list.append(item_tuple)

    Docunique_array = np.array(Docunique_list)
    return Docunique_array

# %%
#Docprova = np.array([[1,2,3],[7,8,9],[11,3,16],[7,7,4],[7,8,9]])
#print(Toglie_Duplicati(Docprova))

# %%
x_list = []
for Doc in corpus_filtrato_embedding:
    DocNew = Toglie_Duplicati(Doc)
    DocNew = np.array(DocNew)
    x = torch.tensor(DocNew, dtype=torch.float)
    x_list.append(x)

# %%
datasetGrafi = []
for i in range(len(A_list)):
    x = x_list[i]
    A = A_list[i]
    edge_index = torch.tensor(np.column_stack(np.where(A == 1)), dtype=torch.long)
    data = Data(x=x, edge_index=edge_index.t().contiguous())
    datasetGrafi.append(data)

# %%
#print(datasetGrafi[10].x)
#print(datasetGrafi[10].edge_index)

# "text": "Un paziente di 72 anni con parkinsonismo presenta piedi edematosi di color rossastro, sensibili, molto dolorosi."
#word2Vec_model.wv['parkinson']
#word2Vec_model.wv['72']
#word2Vec_model.wv['pazient']

# Ok tutto torna!

# %%
data_load = DataLoader(datasetGrafi, batch_size=128)

# %%
with open('datasetGrafi_NO_ripetizioni.pkl', 'wb') as file:
    pickle.dump(datasetGrafi, file)

# Save data_load to a pickle file
with open('data_load_NO_ripetizioni.pkl', 'wb') as file:
    pickle.dump(data_load, file)

# %% [markdown]
# NB: queste sono le modifiche al 4 febbraio: non considero la finestra p ma solo p = 1 per semplicità, la grossa modifica fatta
#         è che non ci sono ripetizioni di parole (nella matrice di adiacenza non si formano nuovi nodi se una parola era già comparsa)

# %% [markdown]
# # Stessa cosa per layer1 !!! (6 Febbraio)

# %%
import pickle
import numpy as np
import torch
from torch_geometric.data import Data
from torch_geometric.loader import DataLoader

# %%
with open('corpusParoleInutiliStemming_layer1.pkl', 'rb') as file:
    # Carica i dati dal file
    corpus_filtrato1 = pickle.load(file)
#len(corpus_filtrato[0])

# %%
# len(corpus_filtrato) = 86
# Out:
# 86

# %%
with open("my_vecs_GennaioStemming.p", "rb") as file:
    word2Vec_model = pickle.load(file)

# %%
word_names = word2Vec_model.wv.index_to_key

word_vectors = [word2Vec_model.wv[word] for word in word_names]

corpus_filtrato_embedding1 = []
for doc in corpus_filtrato1:
    doc_embedding = []
    for parola in doc:
        
        # NB: VOCABOLARIO E'IL SET DI PAROLE APPARSE IN LAYER 3, LE RIMUOVO DA LAYER 1 PERCHE' NON POSSONO ESSERE
        # TRADOTTE DAL WORD EMBEDDINGS (ALLENATO SOLO SUL LAYER3)
        
        if parola in vocabolario: 
            doc_embedding.append(word2Vec_model.wv[parola])
        else:
            doc.remove(parola)
    corpus_filtrato_embedding1.append(doc_embedding)
    
#corpus_filtrato[1]
#word2Vec_model.wv['giovan']
#corpus_filtrato_embedding[0]

# %%
len(corpus_filtrato_embedding1[0])
# Out:
# 293

# %%
len(corpus_filtrato1[0])
# Out:
# 306

# %%
len(set(corpus_filtrato1[0]))
# Out:
# 235

# %%
A_list1 =[]
for i,Doc in enumerate(corpus_filtrato1):
    A = Crea_Matrice_Adiacenza(Doc)
    A_list1.append(A)

# %%
x_list1 = []
for Doc in corpus_filtrato_embedding1:
    DocNew = Toglie_Duplicati(Doc)
    DocNew = np.array(DocNew)
    x = torch.tensor(DocNew, dtype=torch.float)
    x_list1.append(x)

# %%
datasetGrafi1 = []
for i in range(len(A_list1)):
    x = x_list1[i]
    A = A_list1[i]
    edge_index = torch.tensor(np.column_stack(np.where(A == 1)), dtype=torch.long)
    data = Data(x=x, edge_index=edge_index.t().contiguous())
    datasetGrafi1.append(data)

# %%
data_load1 = DataLoader(datasetGrafi1, batch_size=128)

# %%
with open('datasetGrafi_NO_ripetizioni_layer1.pkl', 'wb') as file:
    pickle.dump(datasetGrafi1, file)

# Save data_load to a pickle file
with open('data_load_NO_ripetizioni_layer1.pkl', 'wb') as file:
    pickle.dump(data_load1, file)

# %%
datasetGrafi
# Out:
# [Data(x=[236, 10], edge_index=[2, 740]),
#  Data(x=[365, 10], edge_index=[2, 1148]),
#  Data(x=[251, 10], edge_index=[2, 792]),
#  Data(x=[195, 10], edge_index=[2, 478]),
#  Data(x=[320, 10], edge_index=[2, 991]),
#  Data(x=[316, 10], edge_index=[2, 836]),
#  Data(x=[239, 10], edge_index=[2, 720]),
#  Data(x=[259, 10], edge_index=[2, 726]),
#  Data(x=[243, 10], edge_index=[2, 742]),
#  Data(x=[347, 10], edge_index=[2, 912]),
#  Data(x=[12, 10], edge_index=[2, 22]),
#  Data(x=[9, 10], edge_index=[2, 16]),
#  Data(x=[14, 10], edge_index=[2, 28]),
#  Data(x=[23, 10], edge_index=[2, 44]),
#  Data(x=[9, 10], edge_index=[2, 16]),
#  Data(x=[9, 10], edge_index=[2, 16]),
#  Data(x=[11, 10], edge_index=[2, 20]),
#  Data(x=[11, 10], edge_index=[2, 20]),
#  Data(x=[10, 10], edge_index=[2, 18]),
#  Data(x=[12, 10], edge_index=[2, 22]),
#  Data(x=[19, 10], edge_index=[2, 36]),
#  Data(x=[18, 10], edge_index=[2, 34]),
#  Data(x=[16, 10], edge_index=[2, 30]),
#  Data(x=[14, 10], edge_index=[2, 37]),
#  Data(x=[27, 10], edge_index=[2, 52]),
#  Data(x=[23, 10], edge_index=[2, 44]),
#  Data(x=[25, 10], edge_index=[2, 50]),
#  Data(x=[12, 10], edge_index=[2, 22]),
#  Data(x=[12, 10], edge_index=[2, 22]),
#  Data(x=[13, 10], edge_index=[2, 24]),
#  Data(x=[23, 10], edge_index=[2, 44]),
#  Data(x=[10, 10], edge_index=[2, 20]),
#  Data(x=[16, 10], edge_index=[2, 32]),
#  Data(x=[13, 10], edge_index=[2, 26]),
#  Data(x=[13, 10], edge_index=[2, 29]),
#  Data(x=[9, 10], edge_index=[2, 16]),
#  Data(x=[18, 10], edge_index=[2, 40]),
#  Data(x=[15, 10], edge_index=[2, 34]),
#  Data(x=[18, 10], edge_index=[2, 38]),
#  Data(x=[16, 10], edge_index=[2, 31]),
#  Data(x=[21, 10], edge_index=[2, 44]),
#  Data(x=[9, 10], edge_index=[2, 16]),
#  Data(x=[15, 10], edge_index=[2, 28]),
#  Data(x=[31, 10], edge_index=[2, 64]),
#  Data(x=[8, 10], edge_index=[2, 14]),
#  Data(x=[30, 10], edge_index=[2, 58]),
#  Data(x=[26, 10], edge_index=[2, 50]),
#  Data(x=[17, 10], edge_index=[2, 34]),
#  Data(x=[18, 10], edge_index=[2, 34]),
#  Data(x=[15, 10], edge_index=[2, 28]),
#  Data(x=[12, 10], edge_index=[2, 22]),
#  Data(x=[25, 10], edge_index=[2, 52]),
#  Data(x=[8, 10], edge_index=[2, 14]),
#  Data(x=[12, 10], edge_index=[2, 22]),
#  Data(x=[13, 10], edge_index=[2, 24]),
#  Data(x=[15, 10], edge_index=[2, 28]),
#  Data(x=[10, 10], edge_index=[2, 18]),
#  Data(x=[13, 10], edge_index=[2, 26]),
#  Data(x=[5, 10], edge_index=[2, 8]),
#  Data(x=[6, 10], edge_index=[2, 10]),
#  Data(x=[8, 10], edge_index=[2, 14]),
#  Data(x=[24, 10], edge_index=[2, 48]),
#  Data(x=[32, 10], edge_index=[2, 64]),
#  Data(x=[14, 10], edge_index=[2, 26]),
#  Data(x=[19, 10], edge_index=[2, 38]),
#  Data(x=[15, 10], edge_index=[2, 28]),
#  Data(x=[16, 10], edge_index=[2, 34]),
#  Data(x=[20, 10], edge_index=[2, 38]),
#  Data(x=[10, 10], edge_index=[2, 18]),
#  Data(x=[25, 10], edge_index=[2, 48]),
#  Data(x=[22, 10], edge_index=[2, 42]),
#  Data(x=[4, 10], edge_index=[2, 6]),
#  Data(x=[34, 10], edge_index=[2, 71]),
#  Data(x=[5, 10], edge_index=[2, 8]),
#  Data(x=[16, 10], edge_index=[2, 32]),
#  Data(x=[13, 10], edge_index=[2, 24]),
#  Data(x=[15, 10], edge_index=[2, 28]),
#  Data(x=[21, 10], edge_index=[2, 42]),
#  Data(x=[21, 10], edge_index=[2, 40]),
#  Data(x=[28, 10], edge_index=[2, 58]),
#  Data(x=[26, 10], edge_index=[2, 52]),
#  Data(x=[38, 10], edge_index=[2, 76]),
#  Data(x=[6, 10], edge_index=[2, 12]),
#  Data(x=[26, 10], edge_index=[2, 50]),
#  Data(x=[26, 10], edge_index=[2, 50]),
#  Data(x=[15, 10], edge_index=[2, 28]),
#  Data(x=[28, 10], edge_index=[2, 54]),
#  Data(x=[21, 10], edge_index=[2, 40]),
#  Data(x=[25, 10], edge_index=[2, 50]),
#  Data(x=[31, 10], edge_index=[2, 60]),
#  Data(x=[32, 10], edge_index=[2, 64]),
#  Data(x=[36, 10], edge_index=[2, 72]),
#  Data(x=[11, 10], edge_index=[2, 20]),
#  Data(x=[9, 10], edge_index=[2, 16]),
#  Data(x=[22, 10], edge_index=[2, 42]),
#  Data(x=[20, 10], edge_index=[2, 40]),
#  Data(x=[13, 10], edge_index=[2, 24]),
#  Data(x=[33, 10], edge_index=[2, 66]),
#  Data(x=[17, 10], edge_index=[2, 32]),
#  Data(x=[18, 10], edge_index=[2, 38]),
#  Data(x=[6, 10], edge_index=[2, 12]),
#  Data(x=[8, 10], edge_index=[2, 14]),
#  Data(x=[6, 10], edge_index=[2, 10]),
#  Data(x=[9, 10], edge_index=[2, 16]),
#  Data(x=[11, 10], edge_index=[2, 20]),
#  Data(x=[12, 10], edge_index=[2, 24]),
#  Data(x=[25, 10], edge_index=[2, 48]),
#  Data(x=[16, 10], edge_index=[2, 30]),
#  Data(x=[12, 10], edge_index=[2, 24]),
#  Data(x=[13, 10], edge_index=[2, 24]),
#  Data(x=[9, 10], edge_index=[2, 16]),
#  Data(x=[12, 10], edge_index=[2, 22]),
#  Data(x=[19, 10], edge_index=[2, 36]),
#  Data(x=[6, 10], edge_index=[2, 10]),
#  Data(x=[6, 10], edge_index=[2, 10]),
#  Data(x=[14, 10], edge_index=[2, 26]),
#  Data(x=[23, 10], edge_index=[2, 46]),
#  Data(x=[12, 10], edge_index=[2, 24]),
#  Data(x=[25, 10], edge_index=[2, 52]),
#  Data(x=[16, 10], edge_index=[2, 30]),
#  Data(x=[23, 10], edge_index=[2, 44]),
#  Data(x=[12, 10], edge_index=[2, 22]),
#  Data(x=[22, 10], edge_index=[2, 42]),
#  Data(x=[22, 10], edge_index=[2, 42]),
#  Data(x=[27, 10], edge_index=[2, 52]),
#  Data(x=[28, 10], edge_index=[2, 58]),
#  Data(x=[31, 10], edge_index=[2, 68]),
#  Data(x=[44, 10], edge_index=[2, 92]),
#  Data(x=[42, 10], edge_index=[2, 88]),
#  Data(x=[24, 10], edge_index=[2, 48]),
#  Data(x=[54, 10], edge_index=[2, 106]),
#  Data(x=[35, 10], edge_index=[2, 74]),
#  Data(x=[13, 10], edge_index=[2, 24]),
#  Data(x=[25, 10], edge_index=[2, 52]),
#  Data(x=[20, 10], edge_index=[2, 38]),
#  Data(x=[21, 10], edge_index=[2, 40]),
#  Data(x=[31, 10], edge_index=[2, 60]),
#  Data(x=[25, 10], edge_index=[2, 52]),
#  Data(x=[45, 10], edge_index=[2, 88]),
#  Data(x=[38, 10], edge_index=[2, 76]),
#  Data(x=[21, 10], edge_index=[2, 44]),
#  Data(x=[29, 10], edge_index=[2, 58]),
#  Data(x=[33, 10], edge_index=[2, 70]),
#  Data(x=[39, 10], edge_index=[2, 78]),
#  Data(x=[14, 10], edge_index=[2, 26]),
#  Data(x=[19, 10], edge_index=[2, 36]),
#  Data(x=[25, 10], edge_index=[2, 54]),
#  Data(x=[18, 10], edge_index=[2, 34]),
#  Data(x=[26, 10], edge_index=[2, 54]),
#  Data(x=[31, 10], edge_index=[2, 62]),
#  Data(x=[28, 10], edge_index=[2, 56]),
#  Data(x=[18, 10], edge_index=[2, 34]),
#  Data(x=[17, 10], edge_index=[2, 34]),
#  Data(x=[9, 10], edge_index=[2, 16]),
#  Data(x=[29, 10], edge_index=[2, 58]),
#  Data(x=[24, 10], edge_index=[2, 48]),
#  Data(x=[17, 10], edge_index=[2, 32]),
#  Data(x=[14, 10], edge_index=[2, 26]),
#  Data(x=[41, 10], edge_index=[2, 86]),
#  Data(x=[23, 10], edge_index=[2, 46]),
#  Data(x=[6, 10], edge_index=[2, 10]),
#  Data(x=[10, 10], edge_index=[2, 18]),
#  Data(x=[10, 10], edge_index=[2, 18]),
#  Data(x=[17, 10], edge_index=[2, 32]),
#  Data(x=[14, 10], edge_index=[2, 26]),
#  Data(x=[13, 10], edge_index=[2, 26]),
#  Data(x=[18, 10], edge_index=[2, 36]),
#  Data(x=[14, 10], edge_index=[2, 26]),
#  Data(x=[27, 10], edge_index=[2, 52]),
#  Data(x=[19, 10], edge_index=[2, 38]),
#  Data(x=[36, 10], edge_index=[2, 76]),
#  Data(x=[15, 10], edge_index=[2, 28]),
#  Data(x=[7, 10], edge_index=[2, 12]),
#  Data(x=[19, 10], edge_index=[2, 36]),
#  Data(x=[18, 10], edge_index=[2, 34]),
#  Data(x=[16, 10], edge_index=[2, 30]),
#  Data(x=[45, 10], edge_index=[2, 98]),
#  Data(x=[19, 10], edge_index=[2, 36]),
#  Data(x=[45, 10], edge_index=[2, 88]),
#  Data(x=[15, 10], edge_index=[2, 30]),
#  Data(x=[23, 10], edge_index=[2, 46]),
#  Data(x=[31, 10], edge_index=[2, 62]),
#  Data(x=[49, 10], edge_index=[2, 100]),
#  Data(x=[30, 10], edge_index=[2, 62]),
#  Data(x=[26, 10], edge_index=[2, 50]),
#  Data(x=[49, 10], edge_index=[2, 96]),
#  Data(x=[46, 10], edge_index=[2, 96]),
#  Data(x=[48, 10], edge_index=[2, 96]),
#  Data(x=[28, 10], edge_index=[2, 54]),
#  Data(x=[25, 10], edge_index=[2, 52]),
#  Data(x=[41, 10], edge_index=[2, 84]),
#  Data(x=[24, 10], edge_index=[2, 48]),
#  Data(x=[61, 10], edge_index=[2, 142]),
#  Data(x=[25, 10], edge_index=[2, 50]),
#  Data(x=[18, 10], edge_index=[2, 38]),
#  Data(x=[17, 10], edge_index=[2, 32]),
#  Data(x=[24, 10], edge_index=[2, 50]),
#  Data(x=[20, 10], edge_index=[2, 40]),
#  Data(x=[18, 10], edge_index=[2, 34]),
#  Data(x=[13, 10], edge_index=[2, 24]),
#  Data(x=[25, 10], edge_index=[2, 48]),
#  Data(x=[10, 10], edge_index=[2, 18]),
#  Data(x=[13, 10], edge_index=[2, 26]),
#  Data(x=[27, 10], edge_index=[2, 56]),
#  Data(x=[13, 10], edge_index=[2, 24]),
#  Data(x=[18, 10], edge_index=[2, 34]),
#  Data(x=[22, 10], edge_index=[2, 46]),
#  Data(x=[11, 10], edge_index=[2, 20]),
#  Data(x=[31, 10], edge_index=[2, 66]),
#  Data(x=[35, 10], edge_index=[2, 70]),
#  Data(x=[24, 10], edge_index=[2, 50]),
#  Data(x=[22, 10], edge_index=[2, 48]),
#  Data(x=[17, 10], edge_index=[2, 34]),
#  Data(x=[22, 10], edge_index=[2, 42]),
#  Data(x=[16, 10], edge_index=[2, 34]),
#  Data(x=[17, 10], edge_index=[2, 32]),
#  Data(x=[16, 10], edge_index=[2, 34]),
#  Data(x=[20, 10], edge_index=[2, 44]),
#  Data(x=[32, 10], edge_index=[2, 68]),
#  Data(x=[18, 10], edge_index=[2, 36]),
#  Data(x=[12, 10], edge_index=[2, 24]),
#  Data(x=[23, 10], edge_index=[2, 50]),
#  Data(x=[35, 10], edge_index=[2, 68]),
#  Data(x=[23, 10], edge_index=[2, 44]),
#  Data(x=[29, 10], edge_index=[2, 58]),
#  Data(x=[18, 10], edge_index=[2, 36]),
#  Data(x=[8, 10], edge_index=[2, 14]),
#  Data(x=[11, 10], edge_index=[2, 20]),
#  Data(x=[14, 10], edge_index=[2, 26]),
#  Data(x=[9, 10], edge_index=[2, 16]),
#  Data(x=[29, 10], edge_index=[2, 58]),
#  Data(x=[20, 10], edge_index=[2, 40]),
#  Data(x=[29, 10], edge_index=[2, 58]),
#  Data(x=[24, 10], edge_index=[2, 48]),
#  Data(x=[14, 10], edge_index=[2, 26]),
#  Data(x=[15, 10], edge_index=[2, 28]),
#  Data(x=[16, 10], edge_index=[2, 30]),
#  Data(x=[10, 10], edge_index=[2, 18]),
#  Data(x=[17, 10], edge_index=[2, 34]),
#  Data(x=[36, 10], edge_index=[2, 72]),
#  Data(x=[10, 10], edge_index=[2, 18]),
#  Data(x=[15, 10], edge_index=[2, 30]),
#  Data(x=[24, 10], edge_index=[2, 46]),
#  Data(x=[23, 10], edge_index=[2, 44]),
#  Data(x=[21, 10], edge_index=[2, 42]),
#  Data(x=[15, 10], edge_index=[2, 28]),
#  Data(x=[9, 10], edge_index=[2, 16]),
#  Data(x=[19, 10], edge_index=[2, 40]),
#  Data(x=[13, 10], edge_index=[2, 26]),
#  Data(x=[23, 10], edge_index=[2, 48]),
#  Data(x=[24, 10], edge_index=[2, 50]),
#  Data(x=[13, 10], edge_index=[2, 24]),
#  Data(x=[24, 10], edge_index=[2, 50]),
#  Data(x=[12, 10], edge_index=[2, 22]),
#  Data(x=[15, 10], edge_index=[2, 32]),
#  Data(x=[20, 10], edge_index=[2, 42]),
#  Data(x=[18, 10], edge_index=[2, 34]),
#  Data(x=[27, 10], edge_index=[2, 52]),
#  Data(x=[7, 10], edge_index=[2, 12]),
#  Data(x=[10, 10], edge_index=[2, 18]),
#  Data(x=[24, 10], edge_index=[2, 54]),
#  Data(x=[22, 10], edge_index=[2, 44]),
#  Data(x=[6, 10], edge_index=[2, 10]),
#  Data(x=[18, 10], edge_index=[2, 36]),
#  Data(x=[19, 10], edge_index=[2, 38]),
#  Data(x=[8, 10], edge_index=[2, 14]),
#  Data(x=[8, 10], edge_index=[2, 14]),
#  Data(x=[11, 10], edge_index=[2, 20]),
#  Data(x=[16, 10], edge_index=[2, 30]),
#  Data(x=[14, 10], edge_index=[2, 28]),
#  Data(x=[7, 10], edge_index=[2, 12]),
#  Data(x=[21, 10], edge_index=[2, 46]),
#  Data(x=[12, 10], edge_index=[2, 24]),
#  Data(x=[23, 10], edge_index=[2, 46]),
#  Data(x=[9, 10], edge_index=[2, 16]),
#  Data(x=[26, 10], edge_index=[2, 58]),
#  Data(x=[14, 10], edge_index=[2, 26]),
#  Data(x=[29, 10], edge_index=[2, 59]),
#  Data(x=[22, 10], edge_index=[2, 42]),
#  Data(x=[12, 10], edge_index=[2, 24]),
#  Data(x=[13, 10], edge_index=[2, 24]),
#  Data(x=[18, 10], edge_index=[2, 36]),
#  Data(x=[21, 10], edge_index=[2, 44]),
#  Data(x=[17, 10], edge_index=[2, 34]),
#  Data(x=[21, 10], edge_index=[2, 44]),
#  Data(x=[17, 10], edge_index=[2, 34]),
#  Data(x=[16, 10], edge_index=[2, 34]),
#  Data(x=[14, 10], edge_index=[2, 26]),
#  Data(x=[13, 10], edge_index=[2, 24]),
#  Data(x=[16, 10], edge_index=[2, 34]),
#  Data(x=[12, 10], edge_index=[2, 22]),
#  Data(x=[10, 10], edge_index=[2, 18]),
#  Data(x=[12, 10], edge_index=[2, 22]),
#  Data(x=[9, 10], edge_index=[2, 16]),
#  Data(x=[17, 10], edge_index=[2, 32]),
#  Data(x=[12, 10], edge_index=[2, 22]),
#  Data(x=[14, 10], edge_index=[2, 26]),
#  Data(x=[17, 10], edge_index=[2, 32]),
#  Data(x=[18, 10], edge_index=[2, 36]),
#  Data(x=[14, 10], edge_index=[2, 26]),
#  Data(x=[11, 10], edge_index=[2, 20]),
#  Data(x=[6, 10], edge_index=[2, 10]),
#  Data(x=[6, 10], edge_index=[2, 10]),
#  Data(x=[10, 10], edge_index=[2, 18]),
#  Data(x=[8, 10], edge_index=[2, 14]),
#  Data(x=[5, 10], edge_index=[2, 8]),
#  Data(x=[11, 10], edge_index=[2, 20]),
#  Data(x=[28, 10], edge_index=[2, 58]),
#  Data(x=[6, 10], edge_index=[2, 10]),
#  Data(x=[26, 10], edge_index=[2, 56]),
#  Data(x=[16, 10], edge_index=[2, 30]),
#  Data(x=[11, 10], edge_index=[2, 20]),
#  Data(x=[41, 10], edge_index=[2, 80]),
#  Data(x=[284, 10], edge_index=[2, 756]),
#  Data(x=[78, 10], edge_index=[2, 168]),
#  Data(x=[83, 10], edge_index=[2, 202]),
#  Data(x=[116, 10], edge_index=[2, 280]),
#  Data(x=[49, 10], edge_index=[2, 136]),
#  Data(x=[109, 10], edge_index=[2, 238]),
#  Data(x=[68, 10], edge_index=[2, 154]),
#  Data(x=[114, 10], edge_index=[2, 262]),
#  Data(x=[104, 10], edge_index=[2, 222]),
#  Data(x=[96, 10], edge_index=[2, 234]),
#  Data(x=[94, 10], edge_index=[2, 214]),
#  Data(x=[121, 10], edge_index=[2, 270]),
#  Data(x=[107, 10], edge_index=[2, 244]),
#  Data(x=[69, 10], edge_index=[2, 150]),
#  Data(x=[97, 10], edge_index=[2, 224]),
#  Data(x=[99, 10], edge_index=[2, 228]),
#  Data(x=[109, 10], edge_index=[2, 242]),
#  Data(x=[91, 10], edge_index=[2, 206]),
#  Data(x=[111, 10], edge_index=[2, 272]),
#  Data(x=[86, 10], edge_index=[2, 204]),
#  Data(x=[104, 10], edge_index=[2, 258]),
#  Data(x=[122, 10], edge_index=[2, 280]),
#  Data(x=[106, 10], edge_index=[2, 264]),
#  Data(x=[104, 10], edge_index=[2, 254]),
#  Data(x=[116, 10], edge_index=[2, 262]),
#  Data(x=[120, 10], edge_index=[2, 264]),
#  Data(x=[125, 10], edge_index=[2, 277]),
#  Data(x=[125, 10], edge_index=[2, 286]),
#  Data(x=[128, 10], edge_index=[2, 288]),
#  Data(x=[111, 10], edge_index=[2, 272]),
#  Data(x=[109, 10], edge_index=[2, 256]),
#  Data(x=[91, 10], edge_index=[2, 224]),
#  Data(x=[125, 10], edge_index=[2, 310]),
#  Data(x=[110, 10], edge_index=[2, 230]),
#  Data(x=[125, 10], edge_index=[2, 270]),
#  Data(x=[121, 10], edge_index=[2, 260]),
#  Data(x=[105, 10], edge_index=[2, 238]),
#  Data(x=[121, 10], edge_index=[2, 262]),
#  Data(x=[129, 10], edge_index=[2, 272]),
#  Data(x=[120, 10], edge_index=[2, 278]),
#  Data(x=[104, 10], edge_index=[2, 232]),
#  Data(x=[97, 10], edge_index=[2, 212]),
#  Data(x=[102, 10], edge_index=[2, 248]),
#  Data(x=[103, 10], edge_index=[2, 234]),
#  Data(x=[117, 10], edge_index=[2, 280]),
#  Data(x=[91, 10], edge_index=[2, 214]),
#  Data(x=[89, 10], edge_index=[2, 206]),
#  Data(x=[108, 10], edge_index=[2, 256]),
#  Data(x=[109, 10], edge_index=[2, 260]),
#  Data(x=[112, 10], edge_index=[2, 260]),
#  Data(x=[90, 10], edge_index=[2, 184]),
#  Data(x=[48, 10], edge_index=[2, 94]),
#  Data(x=[55, 10], edge_index=[2, 120]),
#  Data(x=[87, 10], edge_index=[2, 196]),
#  Data(x=[88, 10], edge_index=[2, 194]),
#  Data(x=[81, 10], edge_index=[2, 186]),
#  Data(x=[105, 10], edge_index=[2, 244]),
#  Data(x=[97, 10], edge_index=[2, 226]),
#  Data(x=[95, 10], edge_index=[2, 214]),
#  Data(x=[83, 10], edge_index=[2, 202]),
#  Data(x=[98, 10], edge_index=[2, 224]),
#  Data(x=[43, 10], edge_index=[2, 88]),
#  Data(x=[105, 10], edge_index=[2, 250]),
#  Data(x=[96, 10], edge_index=[2, 230]),
#  Data(x=[45, 10], edge_index=[2, 96]),
#  Data(x=[105, 10], edge_index=[2, 252]),
#  Data(x=[48, 10], edge_index=[2, 98]),
#  Data(x=[103, 10], edge_index=[2, 252]),
#  Data(x=[126, 10], edge_index=[2, 280]),
#  Data(x=[109, 10], edge_index=[2, 254]),
#  Data(x=[119, 10], edge_index=[2, 286]),
#  Data(x=[59, 10], edge_index=[2, 140]),
#  Data(x=[112, 10], edge_index=[2, 238]),
#  Data(x=[84, 10], edge_index=[2, 182]),
#  Data(x=[93, 10], edge_index=[2, 202]),
#  Data(x=[71, 10], edge_index=[2, 164]),
#  Data(x=[126, 10], edge_index=[2, 294]),
#  Data(x=[80, 10], edge_index=[2, 206]),
#  Data(x=[84, 10], edge_index=[2, 184]),
#  Data(x=[98, 10], edge_index=[2, 256]),
#  Data(x=[77, 10], edge_index=[2, 172]),
#  Data(x=[78, 10], edge_index=[2, 168]),
#  Data(x=[79, 10], edge_index=[2, 174]),
#  Data(x=[111, 10], edge_index=[2, 254]),
#  Data(x=[129, 10], edge_index=[2, 282]),
#  Data(x=[80, 10], edge_index=[2, 184]),
#  Data(x=[98, 10], edge_index=[2, 209]),
#  Data(x=[78, 10], edge_index=[2, 169]),
#  Data(x=[92, 10], edge_index=[2, 218]),
#  Data(x=[77, 10], edge_index=[2, 184]),
#  Data(x=[91, 10], edge_index=[2, 200]),
#  Data(x=[77, 10], edge_index=[2, 164]),
#  Data(x=[86, 10], edge_index=[2, 194]),
#  Data(x=[77, 10], edge_index=[2, 184]),
#  Data(x=[77, 10], edge_index=[2, 192]),
#  Data(x=[98, 10], edge_index=[2, 236]),
#  Data(x=[75, 10], edge_index=[2, 166]),
#  Data(x=[143, 10], edge_index=[2, 316]),
#  Data(x=[118, 10], edge_index=[2, 268]),
#  Data(x=[109, 10], edge_index=[2, 284]),
#  Data(x=[69, 10], edge_index=[2, 148]),
#  Data(x=[81, 10], edge_index=[2, 176]),
#  Data(x=[110, 10], edge_index=[2, 248]),
#  Data(x=[80, 10], edge_index=[2, 186]),
#  Data(x=[100, 10], edge_index=[2, 234]),
#  Data(x=[70, 10], edge_index=[2, 164]),
#  Data(x=[46, 10], edge_index=[2, 102]),
#  Data(x=[79, 10], edge_index=[2, 174]),
#  Data(x=[107, 10], edge_index=[2, 246]),
#  Data(x=[69, 10], edge_index=[2, 154]),
#  Data(x=[96, 10], edge_index=[2, 220]),
#  Data(x=[105, 10], edge_index=[2, 248]),
#  Data(x=[79, 10], edge_index=[2, 180]),
#  Data(x=[102, 10], edge_index=[2, 232]),
#  Data(x=[85, 10], edge_index=[2, 182]),
#  Data(x=[108, 10], edge_index=[2, 257]),
#  Data(x=[94, 10], edge_index=[2, 212]),
#  Data(x=[99, 10], edge_index=[2, 218]),
#  Data(x=[112, 10], edge_index=[2, 278]),
#  Data(x=[116, 10], edge_index=[2, 264]),
#  Data(x=[104, 10], edge_index=[2, 248]),
#  Data(x=[81, 10], edge_index=[2, 176]),
#  Data(x=[97, 10], edge_index=[2, 222]),
#  Data(x=[109, 10], edge_index=[2, 262]),
#  Data(x=[79, 10], edge_index=[2, 190]),
#  Data(x=[64, 10], edge_index=[2, 136]),
#  Data(x=[84, 10], edge_index=[2, 188]),
#  Data(x=[85, 10], edge_index=[2, 189]),
#  Data(x=[78, 10], edge_index=[2, 178]),
#  Data(x=[92, 10], edge_index=[2, 213]),
#  Data(x=[69, 10], edge_index=[2, 142]),
#  Data(x=[105, 10], edge_index=[2, 224]),
#  Data(x=[78, 10], edge_index=[2, 166]),
#  Data(x=[105, 10], edge_index=[2, 262]),
#  Data(x=[84, 10], edge_index=[2, 200]),
#  Data(x=[86, 10], edge_index=[2, 188]),
#  Data(x=[91, 10], edge_index=[2, 216]),
#  Data(x=[102, 10], edge_index=[2, 226]),
#  Data(x=[102, 10], edge_index=[2, 224]),
#  Data(x=[112, 10], edge_index=[2, 244]),
#  Data(x=[110, 10], edge_index=[2, 246]),
#  Data(x=[115, 10], edge_index=[2, 270]),
#  Data(x=[115, 10], edge_index=[2, 272]),
#  Data(x=[125, 10], edge_index=[2, 278]),
#  Data(x=[73, 10], edge_index=[2, 170]),
#  Data(x=[77, 10], edge_index=[2, 174]),
#  Data(x=[105, 10], edge_index=[2, 246]),
#  Data(x=[103, 10], edge_index=[2, 230]),
#  Data(x=[75, 10], edge_index=[2, 160]),
#  Data(x=[50, 10], edge_index=[2, 102]),
#  Data(x=[85, 10], edge_index=[2, 176]),
#  Data(x=[98, 10], edge_index=[2, 224]),
#  Data(x=[87, 10], edge_index=[2, 191]),
#  Data(x=[81, 10], edge_index=[2, 184]),
#  Data(x=[74, 10], edge_index=[2, 166]),
#  Data(x=[84, 10], edge_index=[2, 190]),
#  Data(x=[199, 10], edge_index=[2, 480]),
#  Data(x=[94, 10], edge_index=[2, 210]),
#  Data(x=[79, 10], edge_index=[2, 168]),
#  Data(x=[46, 10], edge_index=[2, 96]),
#  Data(x=[99, 10], edge_index=[2, 222]),
#  Data(x=[77, 10], edge_index=[2, 180]),
#  Data(x=[100, 10], edge_index=[2, 222]),
#  Data(x=[123, 10], edge_index=[2, 286]),
#  Data(x=[104, 10], edge_index=[2, 230]),
#  Data(x=[36, 10], edge_index=[2, 74]),
#  Data(x=[84, 10], edge_index=[2, 198]),
#  Data(x=[209, 10], edge_index=[2, 486]),
#  Data(x=[72, 10], edge_index=[2, 160]),
#  Data(x=[115, 10], edge_index=[2, 264]),
#  Data(x=[81, 10], edge_index=[2, 190]),
#  Data(x=[80, 10], edge_index=[2, 174]),
#  Data(x=[94, 10], edge_index=[2, 200]),
#  Data(x=[189, 10], edge_index=[2, 474]),
#  Data(x=[68, 10], edge_index=[2, 148]),
#  Data(x=[76, 10], edge_index=[2, 172]),
#  Data(x=[123, 10], edge_index=[2, 270]),
#  Data(x=[78, 10], edge_index=[2, 176]),
#  Data(x=[54, 10], edge_index=[2, 116]),
#  Data(x=[39, 10], edge_index=[2, 78]),
#  Data(x=[99, 10], edge_index=[2, 228]),
#  Data(x=[86, 10], edge_index=[2, 180]),
#  Data(x=[114, 10], edge_index=[2, 262]),
#  Data(x=[115, 10], edge_index=[2, 272]),
#  Data(x=[131, 10], edge_index=[2, 284]),
#  Data(x=[122, 10], edge_index=[2, 278]),
#  Data(x=[129, 10], edge_index=[2, 292]),
#  Data(x=[88, 10], edge_index=[2, 200]),
#  Data(x=[92, 10], edge_index=[2, 196]),
#  Data(x=[79, 10], edge_index=[2, 172]),
#  Data(x=[92, 10], edge_index=[2, 220]),
#  Data(x=[101, 10], edge_index=[2, 232]),
#  Data(x=[109, 10], edge_index=[2, 246]),
#  Data(x=[116, 10], edge_index=[2, 271]),
#  Data(x=[93, 10], edge_index=[2, 226]),
#  Data(x=[82, 10], edge_index=[2, 184]),
#  Data(x=[91, 10], edge_index=[2, 194]),
#  Data(x=[73, 10], edge_index=[2, 157]),
#  Data(x=[48, 10], edge_index=[2, 98]),
#  Data(x=[99, 10], edge_index=[2, 262]),
#  Data(x=[86, 10], edge_index=[2, 206]),
#  Data(x=[78, 10], edge_index=[2, 180]),
#  Data(x=[83, 10], edge_index=[2, 186]),
#  Data(x=[55, 10], edge_index=[2, 128]),
#  Data(x=[99, 10], edge_index=[2, 222]),
#  Data(x=[117, 10], edge_index=[2, 268]),
#  Data(x=[107, 10], edge_index=[2, 236]),
#  Data(x=[96, 10], edge_index=[2, 212]),
#  Data(x=[90, 10], edge_index=[2, 192]),
#  Data(x=[87, 10], edge_index=[2, 182]),
#  Data(x=[71, 10], edge_index=[2, 156]),
#  Data(x=[114, 10], edge_index=[2, 254]),
#  Data(x=[115, 10], edge_index=[2, 252]),
#  Data(x=[134, 10], edge_index=[2, 300]),
#  Data(x=[77, 10], edge_index=[2, 186]),
#  Data(x=[73, 10], edge_index=[2, 158]),
#  Data(x=[77, 10], edge_index=[2, 174]),
#  Data(x=[110, 10], edge_index=[2, 256]),
#  Data(x=[73, 10], edge_index=[2, 156]),
#  Data(x=[131, 10], edge_index=[2, 310]),
#  Data(x=[92, 10], edge_index=[2, 200]),
#  Data(x=[97, 10], edge_index=[2, 214]),
#  Data(x=[106, 10], edge_index=[2, 262]),
#  Data(x=[100, 10], edge_index=[2, 232]),
#  Data(x=[107, 10], edge_index=[2, 246]),
#  Data(x=[123, 10], edge_index=[2, 288]),
#  Data(x=[82, 10], edge_index=[2, 184]),
#  Data(x=[94, 10], edge_index=[2, 210]),
#  Data(x=[81, 10], edge_index=[2, 168]),
#  Data(x=[65, 10], edge_index=[2, 146]),
#  Data(x=[84, 10], edge_index=[2, 203]),
#  Data(x=[83, 10], edge_index=[2, 200]),
#  Data(x=[36, 10], edge_index=[2, 76]),
#  Data(x=[104, 10], edge_index=[2, 236]),
#  Data(x=[91, 10], edge_index=[2, 200]),
#  Data(x=[101, 10], edge_index=[2, 212]),
#  Data(x=[74, 10], edge_index=[2, 162]),
#  Data(x=[76, 10], edge_index=[2, 160]),
#  Data(x=[96, 10], edge_index=[2, 214]),
#  Data(x=[86, 10], edge_index=[2, 184]),
#  Data(x=[78, 10], edge_index=[2, 215]),
#  Data(x=[87, 10], edge_index=[2, 190]),
#  Data(x=[111, 10], edge_index=[2, 268]),
#  Data(x=[113, 10], edge_index=[2, 260]),
#  Data(x=[96, 10], edge_index=[2, 228]),
#  Data(x=[106, 10], edge_index=[2, 252]),
#  Data(x=[42, 10], edge_index=[2, 88]),
#  Data(x=[111, 10], edge_index=[2, 250]),
#  Data(x=[88, 10], edge_index=[2, 208]),
#  Data(x=[78, 10], edge_index=[2, 172]),
#  Data(x=[59, 10], edge_index=[2, 120]),
#  Data(x=[90, 10], edge_index=[2, 198]),
#  Data(x=[95, 10], edge_index=[2, 218]),
#  Data(x=[75, 10], edge_index=[2, 164]),
#  Data(x=[97, 10], edge_index=[2, 236]),
#  Data(x=[76, 10], edge_index=[2, 180]),
#  Data(x=[31, 10], edge_index=[2, 66]),
#  Data(x=[38, 10], edge_index=[2, 90]),
#  Data(x=[52, 10], edge_index=[2, 108]),
#  Data(x=[53, 10], edge_index=[2, 114]),
#  Data(x=[103, 10], edge_index=[2, 254]),
#  Data(x=[116, 10], edge_index=[2, 275]),
#  Data(x=[119, 10], edge_index=[2, 272]),
#  Data(x=[90, 10], edge_index=[2, 198]),
#  Data(x=[95, 10], edge_index=[2, 220]),
#  Data(x=[99, 10], edge_index=[2, 226]),
#  Data(x=[92, 10], edge_index=[2, 194]),
#  Data(x=[103, 10], edge_index=[2, 262]),
#  Data(x=[119, 10], edge_index=[2, 266]),
#  Data(x=[55, 10], edge_index=[2, 148]),
#  Data(x=[80, 10], edge_index=[2, 184]),
#  Data(x=[69, 10], edge_index=[2, 150]),
#  Data(x=[81, 10], edge_index=[2, 186]),
#  Data(x=[99, 10], edge_index=[2, 244]),
#  Data(x=[102, 10], edge_index=[2, 250]),
#  Data(x=[121, 10], edge_index=[2, 288]),
#  Data(x=[91, 10], edge_index=[2, 196]),
#  Data(x=[102, 10], edge_index=[2, 238]),
#  Data(x=[90, 10], edge_index=[2, 219]),
#  Data(x=[83, 10], edge_index=[2, 204]),
#  Data(x=[66, 10], edge_index=[2, 150]),
#  Data(x=[93, 10], edge_index=[2, 198]),
#  Data(x=[83, 10], edge_index=[2, 200]),
#  Data(x=[72, 10], edge_index=[2, 160]),
#  Data(x=[76, 10], edge_index=[2, 164]),
#  Data(x=[62, 10], edge_index=[2, 134]),
#  Data(x=[64, 10], edge_index=[2, 140]),
#  Data(x=[65, 10], edge_index=[2, 146]),
#  Data(x=[82, 10], edge_index=[2, 178]),
#  Data(x=[66, 10], edge_index=[2, 156]),
#  Data(x=[73, 10], edge_index=[2, 170]),
#  Data(x=[106, 10], edge_index=[2, 258]),
#  Data(x=[99, 10], edge_index=[2, 216]),
#  Data(x=[115, 10], edge_index=[2, 266]),
#  Data(x=[123, 10], edge_index=[2, 284]),
#  Data(x=[84, 10], edge_index=[2, 188]),
#  Data(x=[74, 10], edge_index=[2, 170]),
#  Data(x=[80, 10], edge_index=[2, 210]),
#  Data(x=[79, 10], edge_index=[2, 172]),
#  Data(x=[91, 10], edge_index=[2, 206]),
#  Data(x=[124, 10], edge_index=[2, 284]),
#  Data(x=[94, 10], edge_index=[2, 210]),
#  Data(x=[110, 10], edge_index=[2, 244]),
#  Data(x=[105, 10], edge_index=[2, 220]),
#  Data(x=[55, 10], edge_index=[2, 108]),
#  Data(x=[79, 10], edge_index=[2, 166]),
#  Data(x=[78, 10], edge_index=[2, 186]),
#  Data(x=[80, 10], edge_index=[2, 204]),
#  Data(x=[102, 10], edge_index=[2, 242]),
#  Data(x=[124, 10], edge_index=[2, 290]),
#  Data(x=[92, 10], edge_index=[2, 210]),
#  Data(x=[119, 10], edge_index=[2, 276]),
#  Data(x=[92, 10], edge_index=[2, 226]),
#  Data(x=[100, 10], edge_index=[2, 224]),
#  Data(x=[98, 10], edge_index=[2, 234]),
#  Data(x=[110, 10], edge_index=[2, 238]),
#  Data(x=[87, 10], edge_index=[2, 200]),
#  Data(x=[86, 10], edge_index=[2, 182]),
#  Data(x=[110, 10], edge_index=[2, 262]),
#  Data(x=[105, 10], edge_index=[2, 256]),
#  Data(x=[115, 10], edge_index=[2, 282]),
#  Data(x=[118, 10], edge_index=[2, 272]),
#  Data(x=[93, 10], edge_index=[2, 206]),
#  Data(x=[104, 10], edge_index=[2, 248]),
#  Data(x=[91, 10], edge_index=[2, 216]),
#  Data(x=[111, 10], edge_index=[2, 258]),
#  Data(x=[74, 10], edge_index=[2, 176]),
#  Data(x=[109, 10], edge_index=[2, 261]),
#  Data(x=[114, 10], edge_index=[2, 264]),
#  Data(x=[107, 10], edge_index=[2, 230]),
#  Data(x=[106, 10], edge_index=[2, 244]),
#  Data(x=[109, 10], edge_index=[2, 261]),
#  Data(x=[112, 10], edge_index=[2, 264]),
#  Data(x=[92, 10], edge_index=[2, 216]),
#  Data(x=[99, 10], edge_index=[2, 246]),
#  Data(x=[102, 10], edge_index=[2, 244]),
#  Data(x=[114, 10], edge_index=[2, 276]),
#  Data(x=[73, 10], edge_index=[2, 167]),
#  Data(x=[95, 10], edge_index=[2, 210]),
#  Data(x=[70, 10], edge_index=[2, 156]),
#  Data(x=[109, 10], edge_index=[2, 232]),
#  Data(x=[63, 10], edge_index=[2, 142]),
#  Data(x=[88, 10], edge_index=[2, 188]),
#  Data(x=[91, 10], edge_index=[2, 218]),
#  Data(x=[72, 10], edge_index=[2, 152]),
#  Data(x=[94, 10], edge_index=[2, 214]),
#  Data(x=[73, 10], edge_index=[2, 160]),
#  Data(x=[186, 10], edge_index=[2, 452]),
#  Data(x=[53, 10], edge_index=[2, 110]),
#  Data(x=[110, 10], edge_index=[2, 250]),
#  Data(x=[77, 10], edge_index=[2, 160]),
#  Data(x=[78, 10], edge_index=[2, 182]),
#  Data(x=[81, 10], edge_index=[2, 170]),
#  Data(x=[64, 10], edge_index=[2, 150]),
#  Data(x=[75, 10], edge_index=[2, 178]),
#  Data(x=[70, 10], edge_index=[2, 148]),
#  Data(x=[81, 10], edge_index=[2, 182]),
#  Data(x=[95, 10], edge_index=[2, 204]),
#  Data(x=[100, 10], edge_index=[2, 234]),
#  Data(x=[90, 10], edge_index=[2, 198]),
#  Data(x=[99, 10], edge_index=[2, 244]),
#  Data(x=[91, 10], edge_index=[2, 226]),
#  Data(x=[70, 10], edge_index=[2, 162]),
#  Data(x=[86, 10], edge_index=[2, 196]),
#  Data(x=[129, 10], edge_index=[2, 288]),
#  Data(x=[98, 10], edge_index=[2, 212]),
#  Data(x=[116, 10], edge_index=[2, 274]),
#  Data(x=[90, 10], edge_index=[2, 200]),
#  Data(x=[81, 10], edge_index=[2, 198]),
#  Data(x=[56, 10], edge_index=[2, 128]),
#  Data(x=[78, 10], edge_index=[2, 186]),
#  Data(x=[65, 10], edge_index=[2, 150]),
#  Data(x=[77, 10], edge_index=[2, 176]),
#  Data(x=[76, 10], edge_index=[2, 166]),
#  Data(x=[79, 10], edge_index=[2, 184]),
#  Data(x=[83, 10], edge_index=[2, 178]),
#  Data(x=[88, 10], edge_index=[2, 196]),
#  Data(x=[87, 10], edge_index=[2, 222]),
#  Data(x=[80, 10], edge_index=[2, 164]),
#  Data(x=[83, 10], edge_index=[2, 174]),
#  Data(x=[85, 10], edge_index=[2, 194]),
#  Data(x=[77, 10], edge_index=[2, 174]),
#  Data(x=[91, 10], edge_index=[2, 198]),
#  Data(x=[74, 10], edge_index=[2, 164]),
#  Data(x=[109, 10], edge_index=[2, 248]),
#  Data(x=[67, 10], edge_index=[2, 144]),
#  Data(x=[88, 10], edge_index=[2, 196]),
#  Data(x=[88, 10], edge_index=[2, 182]),
#  Data(x=[70, 10], edge_index=[2, 148]),
#  Data(x=[75, 10], edge_index=[2, 160]),
#  Data(x=[81, 10], edge_index=[2, 166]),
#  Data(x=[80, 10], edge_index=[2, 170]),
#  Data(x=[99, 10], edge_index=[2, 214]),
#  Data(x=[103, 10], edge_index=[2, 232]),
#  Data(x=[111, 10], edge_index=[2, 252]),
#  Data(x=[111, 10], edge_index=[2, 264]),
#  Data(x=[74, 10], edge_index=[2, 156]),
#  Data(x=[94, 10], edge_index=[2, 230]),
#  Data(x=[113, 10], edge_index=[2, 258]),
#  Data(x=[73, 10], edge_index=[2, 162]),
#  Data(x=[80, 10], edge_index=[2, 184]),
#  Data(x=[121, 10], edge_index=[2, 278]),
#  Data(x=[113, 10], edge_index=[2, 272]),
#  Data(x=[77, 10], edge_index=[2, 168]),
#  Data(x=[70, 10], edge_index=[2, 178]),
#  Data(x=[77, 10], edge_index=[2, 174]),
#  Data(x=[70, 10], edge_index=[2, 158]),
#  Data(x=[84, 10], edge_index=[2, 192]),
#  Data(x=[96, 10], edge_index=[2, 208]),
#  Data(x=[111, 10], edge_index=[2, 250]),
#  Data(x=[90, 10], edge_index=[2, 208]),
#  Data(x=[64, 10], edge_index=[2, 150]),
#  Data(x=[76, 10], edge_index=[2, 166]),
#  Data(x=[85, 10], edge_index=[2, 186]),
#  Data(x=[70, 10], edge_index=[2, 163]),
#  Data(x=[80, 10], edge_index=[2, 180]),
#  Data(x=[94, 10], edge_index=[2, 210]),
#  Data(x=[104, 10], edge_index=[2, 267]),
#  Data(x=[76, 10], edge_index=[2, 172]),
#  Data(x=[94, 10], edge_index=[2, 220]),
#  Data(x=[50, 10], edge_index=[2, 100]),
#  Data(x=[98, 10], edge_index=[2, 236]),
#  Data(x=[90, 10], edge_index=[2, 204]),
#  Data(x=[87, 10], edge_index=[2, 210]),
#  Data(x=[100, 10], edge_index=[2, 254]),
#  Data(x=[94, 10], edge_index=[2, 212]),
#  Data(x=[69, 10], edge_index=[2, 164]),
#  Data(x=[74, 10], edge_index=[2, 168]),
#  Data(x=[66, 10], edge_index=[2, 154]),
#  Data(x=[50, 10], edge_index=[2, 104]),
#  Data(x=[67, 10], edge_index=[2, 150]),
#  Data(x=[87, 10], edge_index=[2, 192]),
#  Data(x=[76, 10], edge_index=[2, 169]),
#  Data(x=[53, 10], edge_index=[2, 138]),
#  Data(x=[112, 10], edge_index=[2, 270]),
#  Data(x=[79, 10], edge_index=[2, 182]),
#  Data(x=[87, 10], edge_index=[2, 198]),
#  Data(x=[91, 10], edge_index=[2, 210]),
#  Data(x=[103, 10], edge_index=[2, 248]),
#  Data(x=[97, 10], edge_index=[2, 226]),
#  Data(x=[82, 10], edge_index=[2, 178]),
#  Data(x=[94, 10], edge_index=[2, 218]),
#  Data(x=[89, 10], edge_index=[2, 206]),
#  Data(x=[81, 10], edge_index=[2, 189]),
#  Data(x=[78, 10], edge_index=[2, 172]),
#  Data(x=[73, 10], edge_index=[2, 164]),
#  Data(x=[121, 10], edge_index=[2, 303]),
#  Data(x=[79, 10], edge_index=[2, 176]),
#  Data(x=[68, 10], edge_index=[2, 158]),
#  Data(x=[84, 10], edge_index=[2, 182]),
#  Data(x=[88, 10], edge_index=[2, 204]),
#  Data(x=[104, 10], edge_index=[2, 220]),
#  Data(x=[127, 10], edge_index=[2, 310]),
#  Data(x=[75, 10], edge_index=[2, 169]),
#  Data(x=[76, 10], edge_index=[2, 166]),
#  Data(x=[80, 10], edge_index=[2, 174]),
#  Data(x=[91, 10], edge_index=[2, 206]),
#  Data(x=[90, 10], edge_index=[2, 212]),
#  Data(x=[84, 10], edge_index=[2, 196]),
#  Data(x=[92, 10], edge_index=[2, 214]),
#  Data(x=[76, 10], edge_index=[2, 160]),
#  Data(x=[115, 10], edge_index=[2, 266]),
#  Data(x=[78, 10], edge_index=[2, 158]),
#  Data(x=[81, 10], edge_index=[2, 166]),
#  Data(x=[99, 10], edge_index=[2, 220]),
#  Data(x=[77, 10], edge_index=[2, 166]),
#  Data(x=[88, 10], edge_index=[2, 196]),
#  Data(x=[83, 10], edge_index=[2, 176]),
#  Data(x=[117, 10], edge_index=[2, 268]),
#  Data(x=[102, 10], edge_index=[2, 222]),
#  Data(x=[115, 10], edge_index=[2, 244]),
#  Data(x=[115, 10], edge_index=[2, 256]),
#  Data(x=[92, 10], edge_index=[2, 212]),
#  Data(x=[193, 10], edge_index=[2, 448]),
#  Data(x=[86, 10], edge_index=[2, 204]),
#  Data(x=[94, 10], edge_index=[2, 226]),
#  Data(x=[90, 10], edge_index=[2, 203]),
#  Data(x=[58, 10], edge_index=[2, 136]),
#  Data(x=[72, 10], edge_index=[2, 164]),
#  Data(x=[93, 10], edge_index=[2, 223]),
#  Data(x=[80, 10], edge_index=[2, 188]),
#  Data(x=[95, 10], edge_index=[2, 204]),
#  Data(x=[104, 10], edge_index=[2, 234]),
#  Data(x=[80, 10], edge_index=[2, 174]),
#  Data(x=[93, 10], edge_index=[2, 204]),
#  Data(x=[75, 10], edge_index=[2, 164]),
#  Data(x=[84, 10], edge_index=[2, 198]),
#  Data(x=[79, 10], edge_index=[2, 172]),
#  Data(x=[99, 10], edge_index=[2, 236]),
#  Data(x=[76, 10], edge_index=[2, 168]),
#  Data(x=[96, 10], edge_index=[2, 226]),
#  Data(x=[82, 10], edge_index=[2, 198]),
#  Data(x=[85, 10], edge_index=[2, 192]),
#  Data(x=[90, 10], edge_index=[2, 200]),
#  Data(x=[95, 10], edge_index=[2, 204]),
#  Data(x=[100, 10], edge_index=[2, 224]),
#  Data(x=[97, 10], edge_index=[2, 226]),
#  Data(x=[86, 10], edge_index=[2, 216]),
#  Data(x=[81, 10], edge_index=[2, 172]),
#  Data(x=[87, 10], edge_index=[2, 184]),
#  Data(x=[90, 10], edge_index=[2, 232]),
#  Data(x=[81, 10], edge_index=[2, 180]),
#  Data(x=[105, 10], edge_index=[2, 224]),
#  Data(x=[100, 10], edge_index=[2, 218]),
#  Data(x=[90, 10], edge_index=[2, 206]),
#  Data(x=[96, 10], edge_index=[2, 209]),
#  Data(x=[106, 10], edge_index=[2, 228]),
#  Data(x=[92, 10], edge_index=[2, 192]),
#  Data(x=[116, 10], edge_index=[2, 276]),
#  Data(x=[89, 10], edge_index=[2, 192]),
#  Data(x=[83, 10], edge_index=[2, 208]),
#  Data(x=[67, 10], edge_index=[2, 158]),
#  Data(x=[88, 10], edge_index=[2, 200]),
#  Data(x=[98, 10], edge_index=[2, 220]),
#  Data(x=[83, 10], edge_index=[2, 174]),
#  Data(x=[84, 10], edge_index=[2, 172]),
#  Data(x=[87, 10], edge_index=[2, 192]),
#  Data(x=[94, 10], edge_index=[2, 208]),
#  Data(x=[80, 10], edge_index=[2, 162]),
#  Data(x=[91, 10], edge_index=[2, 186]),
#  Data(x=[88, 10], edge_index=[2, 192]),
#  Data(x=[75, 10], edge_index=[2, 166]),
#  Data(x=[88, 10], edge_index=[2, 212]),
#  Data(x=[78, 10], edge_index=[2, 180]),
#  Data(x=[96, 10], edge_index=[2, 210]),
#  Data(x=[75, 10], edge_index=[2, 184]),
#  Data(x=[69, 10], edge_index=[2, 154]),
#  Data(x=[89, 10], edge_index=[2, 204]),
#  Data(x=[72, 10], edge_index=[2, 162]),
#  Data(x=[99, 10], edge_index=[2, 220]),
#  Data(x=[74, 10], edge_index=[2, 174]),
#  Data(x=[120, 10], edge_index=[2, 270]),
#  Data(x=[82, 10], edge_index=[2, 168]),
#  Data(x=[87, 10], edge_index=[2, 221]),
#  Data(x=[92, 10], edge_index=[2, 204]),
#  Data(x=[106, 10], edge_index=[2, 246]),
#  Data(x=[82, 10], edge_index=[2, 182]),
#  Data(x=[79, 10], edge_index=[2, 162]),
#  Data(x=[110, 10], edge_index=[2, 250]),
#  Data(x=[93, 10], edge_index=[2, 202]),
#  Data(x=[97, 10], edge_index=[2, 224]),
#  Data(x=[106, 10], edge_index=[2, 266]),
#  Data(x=[42, 10], edge_index=[2, 84]),
#  Data(x=[307, 10], edge_index=[2, 984]),
#  Data(x=[304, 10], edge_index=[2, 864]),
#  Data(x=[37, 10], edge_index=[2, 72]),
#  Data(x=[26, 10], edge_index=[2, 54]),
#  Data(x=[30, 10], edge_index=[2, 62]),
#  Data(x=[43, 10], edge_index=[2, 90]),
#  Data(x=[55, 10], edge_index=[2, 112]),
#  Data(x=[49, 10], edge_index=[2, 106]),
#  Data(x=[58, 10], edge_index=[2, 138]),
#  Data(x=[47, 10], edge_index=[2, 106]),
#  Data(x=[53, 10], edge_index=[2, 106]),
#  Data(x=[59, 10], edge_index=[2, 128]),
#  Data(x=[48, 10], edge_index=[2, 108]),
#  Data(x=[48, 10], edge_index=[2, 104]),
#  Data(x=[71, 10], edge_index=[2, 166]),
#  Data(x=[54, 10], edge_index=[2, 140]),
#  Data(x=[37, 10], edge_index=[2, 80]),
#  Data(x=[18, 10], edge_index=[2, 36]),
#  Data(x=[18, 10], edge_index=[2, 36]),
#  Data(x=[23, 10], edge_index=[2, 48]),
#  Data(x=[61, 10], edge_index=[2, 130]),
#  Data(x=[35, 10], edge_index=[2, 74]),
#  Data(x=[44, 10], edge_index=[2, 96]),
#  Data(x=[42, 10], edge_index=[2, 96]),
#  Data(x=[40, 10], edge_index=[2, 82]),
#  Data(x=[70, 10], edge_index=[2, 154]),
#  Data(x=[35, 10], edge_index=[2, 70]),
#  Data(x=[60, 10], edge_index=[2, 138]),
#  Data(x=[72, 10], edge_index=[2, 158]),
#  Data(x=[73, 10], edge_index=[2, 156]),
#  Data(x=[45, 10], edge_index=[2, 96]),
#  Data(x=[58, 10], edge_index=[2, 128]),
#  Data(x=[70, 10], edge_index=[2, 150]),
#  Data(x=[89, 10], edge_index=[2, 188]),
#  Data(x=[99, 10], edge_index=[2, 220]),
#  Data(x=[58, 10], edge_index=[2, 122]),
#  Data(x=[92, 10], edge_index=[2, 216]),
#  Data(x=[67, 10], edge_index=[2, 142]),
#  Data(x=[40, 10], edge_index=[2, 82]),
#  Data(x=[52, 10], edge_index=[2, 106]),
#  Data(x=[55, 10], edge_index=[2, 112]),
#  Data(x=[56, 10], edge_index=[2, 112]),
#  Data(x=[57, 10], edge_index=[2, 132]),
#  Data(x=[62, 10], edge_index=[2, 130]),
#  Data(x=[54, 10], edge_index=[2, 118]),
#  Data(x=[67, 10], edge_index=[2, 140]),
#  Data(x=[31, 10], edge_index=[2, 64]),
#  Data(x=[80, 10], edge_index=[2, 174]),
#  Data(x=[77, 10], edge_index=[2, 174]),
#  Data(x=[43, 10], edge_index=[2, 88]),
#  Data(x=[32, 10], edge_index=[2, 62]),
#  Data(x=[58, 10], edge_index=[2, 133]),
#  Data(x=[23, 10], edge_index=[2, 48]),
#  Data(x=[78, 10], edge_index=[2, 182]),
#  Data(x=[33, 10], edge_index=[2, 74]),
#  Data(x=[27, 10], edge_index=[2, 52]),
#  Data(x=[46, 10], edge_index=[2, 100]),
#  Data(x=[37, 10], edge_index=[2, 78]),
#  Data(x=[40, 10], edge_index=[2, 82]),
#  Data(x=[31, 10], edge_index=[2, 60]),
#  Data(x=[44, 10], edge_index=[2, 90]),
#  Data(x=[55, 10], edge_index=[2, 122]),
#  Data(x=[60, 10], edge_index=[2, 128]),
#  Data(x=[76, 10], edge_index=[2, 178]),
#  Data(x=[58, 10], edge_index=[2, 133]),
#  Data(x=[68, 10], edge_index=[2, 154]),
#  Data(x=[42, 10], edge_index=[2, 90]),
#  Data(x=[20, 10], edge_index=[2, 42]),
#  Data(x=[68, 10], edge_index=[2, 154]),
#  Data(x=[24, 10], edge_index=[2, 46]),
#  Data(x=[24, 10], edge_index=[2, 46]),
#  Data(x=[19, 10], edge_index=[2, 40]),
#  Data(x=[49, 10], edge_index=[2, 104]),
#  Data(x=[85, 10], edge_index=[2, 182]),
#  Data(x=[38, 10], edge_index=[2, 80]),
#  Data(x=[25, 10], edge_index=[2, 48]),
#  Data(x=[31, 10], edge_index=[2, 62]),
#  Data(x=[55, 10], edge_index=[2, 132]),
#  Data(x=[52, 10], edge_index=[2, 108]),
#  Data(x=[39, 10], edge_index=[2, 86]),
#  Data(x=[49, 10], edge_index=[2, 108]),
#  Data(x=[63, 10], edge_index=[2, 142]),
#  Data(x=[62, 10], edge_index=[2, 134]),
#  Data(x=[72, 10], edge_index=[2, 160]),
#  Data(x=[57, 10], edge_index=[2, 128]),
#  Data(x=[51, 10], edge_index=[2, 106]),
#  Data(x=[54, 10], edge_index=[2, 114]),
#  Data(x=[45, 10], edge_index=[2, 98]),
#  Data(x=[74, 10], edge_index=[2, 154]),
#  Data(x=[33, 10], edge_index=[2, 74]),
#  Data(x=[41, 10], edge_index=[2, 82]),
#  Data(x=[88, 10], edge_index=[2, 208]),
#  Data(x=[47, 10], edge_index=[2, 96]),
#  Data(x=[52, 10], edge_index=[2, 104]),
#  Data(x=[81, 10], edge_index=[2, 180]),
#  Data(x=[102, 10], edge_index=[2, 238]),
#  Data(x=[309, 10], edge_index=[2, 956]),
#  Data(x=[104, 10], edge_index=[2, 248]),
#  Data(x=[65, 10], edge_index=[2, 148]),
#  Data(x=[56, 10], edge_index=[2, 149]),
#  Data(x=[77, 10], edge_index=[2, 158]),
#  Data(x=[91, 10], edge_index=[2, 232]),
#  Data(x=[126, 10], edge_index=[2, 286]),
#  Data(x=[113, 10], edge_index=[2, 248]),
#  Data(x=[104, 10], edge_index=[2, 252]),
#  Data(x=[84, 10], edge_index=[2, 202]),
#  Data(x=[99, 10], edge_index=[2, 230]),
#  Data(x=[72, 10], edge_index=[2, 154]),
#  Data(x=[35, 10], edge_index=[2, 74]),
#  Data(x=[333, 10], edge_index=[2, 948]),
#  Data(x=[300, 10], edge_index=[2, 792]),
#  Data(x=[210, 10], edge_index=[2, 506]),
#  Data(x=[39, 10], edge_index=[2, 80]),
#  Data(x=[263, 10], edge_index=[2, 796]),
#  Data(x=[109, 10], edge_index=[2, 246]),
#  Data(x=[185, 10], edge_index=[2, 466]),
#  Data(x=[339, 10], edge_index=[2, 1042]),
#  Data(x=[172, 10], edge_index=[2, 480]),
#  Data(x=[290, 10], edge_index=[2, 841]),
#  Data(x=[167, 10], edge_index=[2, 452]),
#  Data(x=[317, 10], edge_index=[2, 952]),
#  Data(x=[113, 10], edge_index=[2, 266]),
#  Data(x=[222, 10], edge_index=[2, 574]),
#  Data(x=[221, 10], edge_index=[2, 572]),
#  Data(x=[180, 10], edge_index=[2, 486]),
#  Data(x=[215, 10], edge_index=[2, 546]),
#  Data(x=[173, 10], edge_index=[2, 482]),
#  Data(x=[165, 10], edge_index=[2, 448]),
#  Data(x=[29, 10], edge_index=[2, 58]),
#  Data(x=[33, 10], edge_index=[2, 70]),
#  Data(x=[20, 10], edge_index=[2, 38]),
#  Data(x=[26, 10], edge_index=[2, 54]),
#  Data(x=[22, 10], edge_index=[2, 44]),
#  Data(x=[11, 10], edge_index=[2, 20]),
#  Data(x=[19, 10], edge_index=[2, 38]),
#  Data(x=[24, 10], edge_index=[2, 48]),
#  Data(x=[13, 10], edge_index=[2, 24]),
#  Data(x=[11, 10], edge_index=[2, 20]),
#  Data(x=[21, 10], edge_index=[2, 42]),
#  Data(x=[15, 10], edge_index=[2, 28]),
#  Data(x=[14, 10], edge_index=[2, 26]),
#  Data(x=[11, 10], edge_index=[2, 20]),
#  Data(x=[25, 10], edge_index=[2, 48]),
#  Data(x=[14, 10], edge_index=[2, 26]),
#  ...]

# %%
len(x_list1[0])
# Out:
# 222

# %%
datasetGrafi1
# Out:
# [Data(x=[222, 10], edge_index=[2, 624]),
#  Data(x=[170, 10], edge_index=[2, 468]),
#  Data(x=[207, 10], edge_index=[2, 576]),
#  Data(x=[188, 10], edge_index=[2, 520]),
#  Data(x=[203, 10], edge_index=[2, 634]),
#  Data(x=[43, 10], edge_index=[2, 100]),
#  Data(x=[43, 10], edge_index=[2, 100]),
#  Data(x=[198, 10], edge_index=[2, 670]),
#  Data(x=[199, 10], edge_index=[2, 583]),
#  Data(x=[194, 10], edge_index=[2, 616]),
#  Data(x=[159, 10], edge_index=[2, 512]),
#  Data(x=[237, 10], edge_index=[2, 622]),
#  Data(x=[119, 10], edge_index=[2, 285]),
#  Data(x=[134, 10], edge_index=[2, 324]),
#  Data(x=[133, 10], edge_index=[2, 336]),
#  Data(x=[225, 10], edge_index=[2, 588]),
#  Data(x=[60, 10], edge_index=[2, 144]),
#  Data(x=[124, 10], edge_index=[2, 304]),
#  Data(x=[74, 10], edge_index=[2, 166]),
#  Data(x=[153, 10], edge_index=[2, 382]),
#  Data(x=[48, 10], edge_index=[2, 108]),
#  Data(x=[61, 10], edge_index=[2, 134]),
#  Data(x=[212, 10], edge_index=[2, 530]),
#  Data(x=[53, 10], edge_index=[2, 124]),
#  Data(x=[116, 10], edge_index=[2, 284]),
#  Data(x=[50, 10], edge_index=[2, 114]),
#  Data(x=[123, 10], edge_index=[2, 292]),
#  Data(x=[62, 10], edge_index=[2, 136]),
#  Data(x=[103, 10], edge_index=[2, 308]),
#  Data(x=[56, 10], edge_index=[2, 122]),
#  Data(x=[64, 10], edge_index=[2, 144]),
#  Data(x=[158, 10], edge_index=[2, 407]),
#  Data(x=[183, 10], edge_index=[2, 472]),
#  Data(x=[74, 10], edge_index=[2, 160]),
#  Data(x=[61, 10], edge_index=[2, 134]),
#  Data(x=[58, 10], edge_index=[2, 136]),
#  Data(x=[130, 10], edge_index=[2, 306]),
#  Data(x=[110, 10], edge_index=[2, 310]),
#  Data(x=[110, 10], edge_index=[2, 285]),
#  Data(x=[53, 10], edge_index=[2, 118]),
#  Data(x=[130, 10], edge_index=[2, 306]),
#  Data(x=[172, 10], edge_index=[2, 434]),
#  Data(x=[149, 10], edge_index=[2, 352]),
#  Data(x=[117, 10], edge_index=[2, 280]),
#  Data(x=[57, 10], edge_index=[2, 132]),
#  Data(x=[125, 10], edge_index=[2, 290]),
#  Data(x=[242, 10], edge_index=[2, 615]),
#  Data(x=[220, 10], edge_index=[2, 603]),
#  Data(x=[57, 10], edge_index=[2, 130]),
#  Data(x=[61, 10], edge_index=[2, 132]),
#  Data(x=[55, 10], edge_index=[2, 126]),
#  Data(x=[50, 10], edge_index=[2, 124]),
#  Data(x=[61, 10], edge_index=[2, 132]),
#  Data(x=[50, 10], edge_index=[2, 116]),
#  Data(x=[52, 10], edge_index=[2, 106]),
#  Data(x=[54, 10], edge_index=[2, 116]),
#  Data(x=[53, 10], edge_index=[2, 118]),
#  Data(x=[41, 10], edge_index=[2, 94]),
#  Data(x=[48, 10], edge_index=[2, 112]),
#  Data(x=[116, 10], edge_index=[2, 304]),
#  Data(x=[131, 10], edge_index=[2, 362]),
#  Data(x=[119, 10], edge_index=[2, 290]),
#  Data(x=[200, 10], edge_index=[2, 592]),
#  Data(x=[138, 10], edge_index=[2, 332]),
#  Data(x=[198, 10], edge_index=[2, 578]),
#  Data(x=[144, 10], edge_index=[2, 344]),
#  Data(x=[181, 10], edge_index=[2, 450]),
#  Data(x=[221, 10], edge_index=[2, 572]),
#  Data(x=[150, 10], edge_index=[2, 380]),
#  Data(x=[129, 10], edge_index=[2, 356]),
#  Data(x=[215, 10], edge_index=[2, 546]),
#  Data(x=[163, 10], edge_index=[2, 428]),
#  Data(x=[136, 10], edge_index=[2, 334]),
#  Data(x=[193, 10], edge_index=[2, 560]),
#  Data(x=[163, 10], edge_index=[2, 462]),
#  Data(x=[218, 10], edge_index=[2, 584]),
#  Data(x=[208, 10], edge_index=[2, 570]),
#  Data(x=[166, 10], edge_index=[2, 507]),
#  Data(x=[180, 10], edge_index=[2, 510]),
#  Data(x=[186, 10], edge_index=[2, 548]),
#  Data(x=[186, 10], edge_index=[2, 534]),
#  Data(x=[58, 10], edge_index=[2, 132]),
#  Data(x=[53, 10], edge_index=[2, 116]),
#  Data(x=[189, 10], edge_index=[2, 460]),
#  Data(x=[215, 10], edge_index=[2, 608]),
#  Data(x=[209, 10], edge_index=[2, 560])]

# %%
len(datasetGrafi)
# Out:
# 10213

# %%
len(datasetGrafi1)
# Out:
# 10299

# %%
len(datasetGrafi)+len(datasetGrafi1)
# Out:
# 10299

# %%
datasetGrafi1.extend(datasetGrafi)

# %%
datasetGrafi1and3 = datasetGrafi1

# %%
datasetGrafi1and3
# Out:
# [Data(x=[222, 10], edge_index=[2, 624]),
#  Data(x=[170, 10], edge_index=[2, 468]),
#  Data(x=[207, 10], edge_index=[2, 576]),
#  Data(x=[188, 10], edge_index=[2, 520]),
#  Data(x=[203, 10], edge_index=[2, 634]),
#  Data(x=[43, 10], edge_index=[2, 100]),
#  Data(x=[43, 10], edge_index=[2, 100]),
#  Data(x=[198, 10], edge_index=[2, 670]),
#  Data(x=[199, 10], edge_index=[2, 583]),
#  Data(x=[194, 10], edge_index=[2, 616]),
#  Data(x=[159, 10], edge_index=[2, 512]),
#  Data(x=[237, 10], edge_index=[2, 622]),
#  Data(x=[119, 10], edge_index=[2, 285]),
#  Data(x=[134, 10], edge_index=[2, 324]),
#  Data(x=[133, 10], edge_index=[2, 336]),
#  Data(x=[225, 10], edge_index=[2, 588]),
#  Data(x=[60, 10], edge_index=[2, 144]),
#  Data(x=[124, 10], edge_index=[2, 304]),
#  Data(x=[74, 10], edge_index=[2, 166]),
#  Data(x=[153, 10], edge_index=[2, 382]),
#  Data(x=[48, 10], edge_index=[2, 108]),
#  Data(x=[61, 10], edge_index=[2, 134]),
#  Data(x=[212, 10], edge_index=[2, 530]),
#  Data(x=[53, 10], edge_index=[2, 124]),
#  Data(x=[116, 10], edge_index=[2, 284]),
#  Data(x=[50, 10], edge_index=[2, 114]),
#  Data(x=[123, 10], edge_index=[2, 292]),
#  Data(x=[62, 10], edge_index=[2, 136]),
#  Data(x=[103, 10], edge_index=[2, 308]),
#  Data(x=[56, 10], edge_index=[2, 122]),
#  Data(x=[64, 10], edge_index=[2, 144]),
#  Data(x=[158, 10], edge_index=[2, 407]),
#  Data(x=[183, 10], edge_index=[2, 472]),
#  Data(x=[74, 10], edge_index=[2, 160]),
#  Data(x=[61, 10], edge_index=[2, 134]),
#  Data(x=[58, 10], edge_index=[2, 136]),
#  Data(x=[130, 10], edge_index=[2, 306]),
#  Data(x=[110, 10], edge_index=[2, 310]),
#  Data(x=[110, 10], edge_index=[2, 285]),
#  Data(x=[53, 10], edge_index=[2, 118]),
#  Data(x=[130, 10], edge_index=[2, 306]),
#  Data(x=[172, 10], edge_index=[2, 434]),
#  Data(x=[149, 10], edge_index=[2, 352]),
#  Data(x=[117, 10], edge_index=[2, 280]),
#  Data(x=[57, 10], edge_index=[2, 132]),
#  Data(x=[125, 10], edge_index=[2, 290]),
#  Data(x=[242, 10], edge_index=[2, 615]),
#  Data(x=[220, 10], edge_index=[2, 603]),
#  Data(x=[57, 10], edge_index=[2, 130]),
#  Data(x=[61, 10], edge_index=[2, 132]),
#  Data(x=[55, 10], edge_index=[2, 126]),
#  Data(x=[50, 10], edge_index=[2, 124]),
#  Data(x=[61, 10], edge_index=[2, 132]),
#  Data(x=[50, 10], edge_index=[2, 116]),
#  Data(x=[52, 10], edge_index=[2, 106]),
#  Data(x=[54, 10], edge_index=[2, 116]),
#  Data(x=[53, 10], edge_index=[2, 118]),
#  Data(x=[41, 10], edge_index=[2, 94]),
#  Data(x=[48, 10], edge_index=[2, 112]),
#  Data(x=[116, 10], edge_index=[2, 304]),
#  Data(x=[131, 10], edge_index=[2, 362]),
#  Data(x=[119, 10], edge_index=[2, 290]),
#  Data(x=[200, 10], edge_index=[2, 592]),
#  Data(x=[138, 10], edge_index=[2, 332]),
#  Data(x=[198, 10], edge_index=[2, 578]),
#  Data(x=[144, 10], edge_index=[2, 344]),
#  Data(x=[181, 10], edge_index=[2, 450]),
#  Data(x=[221, 10], edge_index=[2, 572]),
#  Data(x=[150, 10], edge_index=[2, 380]),
#  Data(x=[129, 10], edge_index=[2, 356]),
#  Data(x=[215, 10], edge_index=[2, 546]),
#  Data(x=[163, 10], edge_index=[2, 428]),
#  Data(x=[136, 10], edge_index=[2, 334]),
#  Data(x=[193, 10], edge_index=[2, 560]),
#  Data(x=[163, 10], edge_index=[2, 462]),
#  Data(x=[218, 10], edge_index=[2, 584]),
#  Data(x=[208, 10], edge_index=[2, 570]),
#  Data(x=[166, 10], edge_index=[2, 507]),
#  Data(x=[180, 10], edge_index=[2, 510]),
#  Data(x=[186, 10], edge_index=[2, 548]),
#  Data(x=[186, 10], edge_index=[2, 534]),
#  Data(x=[58, 10], edge_index=[2, 132]),
#  Data(x=[53, 10], edge_index=[2, 116]),
#  Data(x=[189, 10], edge_index=[2, 460]),
#  Data(x=[215, 10], edge_index=[2, 608]),
#  Data(x=[209, 10], edge_index=[2, 560]),
#  Data(x=[236, 10], edge_index=[2, 740]),
#  Data(x=[365, 10], edge_index=[2, 1148]),
#  Data(x=[251, 10], edge_index=[2, 792]),
#  Data(x=[195, 10], edge_index=[2, 478]),
#  Data(x=[320, 10], edge_index=[2, 991]),
#  Data(x=[316, 10], edge_index=[2, 836]),
#  Data(x=[239, 10], edge_index=[2, 720]),
#  Data(x=[259, 10], edge_index=[2, 726]),
#  Data(x=[243, 10], edge_index=[2, 742]),
#  Data(x=[347, 10], edge_index=[2, 912]),
#  Data(x=[12, 10], edge_index=[2, 22]),
#  Data(x=[9, 10], edge_index=[2, 16]),
#  Data(x=[14, 10], edge_index=[2, 28]),
#  Data(x=[23, 10], edge_index=[2, 44]),
#  Data(x=[9, 10], edge_index=[2, 16]),
#  Data(x=[9, 10], edge_index=[2, 16]),
#  Data(x=[11, 10], edge_index=[2, 20]),
#  Data(x=[11, 10], edge_index=[2, 20]),
#  Data(x=[10, 10], edge_index=[2, 18]),
#  Data(x=[12, 10], edge_index=[2, 22]),
#  Data(x=[19, 10], edge_index=[2, 36]),
#  Data(x=[18, 10], edge_index=[2, 34]),
#  Data(x=[16, 10], edge_index=[2, 30]),
#  Data(x=[14, 10], edge_index=[2, 37]),
#  Data(x=[27, 10], edge_index=[2, 52]),
#  Data(x=[23, 10], edge_index=[2, 44]),
#  Data(x=[25, 10], edge_index=[2, 50]),
#  Data(x=[12, 10], edge_index=[2, 22]),
#  Data(x=[12, 10], edge_index=[2, 22]),
#  Data(x=[13, 10], edge_index=[2, 24]),
#  Data(x=[23, 10], edge_index=[2, 44]),
#  Data(x=[10, 10], edge_index=[2, 20]),
#  Data(x=[16, 10], edge_index=[2, 32]),
#  Data(x=[13, 10], edge_index=[2, 26]),
#  Data(x=[13, 10], edge_index=[2, 29]),
#  Data(x=[9, 10], edge_index=[2, 16]),
#  Data(x=[18, 10], edge_index=[2, 40]),
#  Data(x=[15, 10], edge_index=[2, 34]),
#  Data(x=[18, 10], edge_index=[2, 38]),
#  Data(x=[16, 10], edge_index=[2, 31]),
#  Data(x=[21, 10], edge_index=[2, 44]),
#  Data(x=[9, 10], edge_index=[2, 16]),
#  Data(x=[15, 10], edge_index=[2, 28]),
#  Data(x=[31, 10], edge_index=[2, 64]),
#  Data(x=[8, 10], edge_index=[2, 14]),
#  Data(x=[30, 10], edge_index=[2, 58]),
#  Data(x=[26, 10], edge_index=[2, 50]),
#  Data(x=[17, 10], edge_index=[2, 34]),
#  Data(x=[18, 10], edge_index=[2, 34]),
#  Data(x=[15, 10], edge_index=[2, 28]),
#  Data(x=[12, 10], edge_index=[2, 22]),
#  Data(x=[25, 10], edge_index=[2, 52]),
#  Data(x=[8, 10], edge_index=[2, 14]),
#  Data(x=[12, 10], edge_index=[2, 22]),
#  Data(x=[13, 10], edge_index=[2, 24]),
#  Data(x=[15, 10], edge_index=[2, 28]),
#  Data(x=[10, 10], edge_index=[2, 18]),
#  Data(x=[13, 10], edge_index=[2, 26]),
#  Data(x=[5, 10], edge_index=[2, 8]),
#  Data(x=[6, 10], edge_index=[2, 10]),
#  Data(x=[8, 10], edge_index=[2, 14]),
#  Data(x=[24, 10], edge_index=[2, 48]),
#  Data(x=[32, 10], edge_index=[2, 64]),
#  Data(x=[14, 10], edge_index=[2, 26]),
#  Data(x=[19, 10], edge_index=[2, 38]),
#  Data(x=[15, 10], edge_index=[2, 28]),
#  Data(x=[16, 10], edge_index=[2, 34]),
#  Data(x=[20, 10], edge_index=[2, 38]),
#  Data(x=[10, 10], edge_index=[2, 18]),
#  Data(x=[25, 10], edge_index=[2, 48]),
#  Data(x=[22, 10], edge_index=[2, 42]),
#  Data(x=[4, 10], edge_index=[2, 6]),
#  Data(x=[34, 10], edge_index=[2, 71]),
#  Data(x=[5, 10], edge_index=[2, 8]),
#  Data(x=[16, 10], edge_index=[2, 32]),
#  Data(x=[13, 10], edge_index=[2, 24]),
#  Data(x=[15, 10], edge_index=[2, 28]),
#  Data(x=[21, 10], edge_index=[2, 42]),
#  Data(x=[21, 10], edge_index=[2, 40]),
#  Data(x=[28, 10], edge_index=[2, 58]),
#  Data(x=[26, 10], edge_index=[2, 52]),
#  Data(x=[38, 10], edge_index=[2, 76]),
#  Data(x=[6, 10], edge_index=[2, 12]),
#  Data(x=[26, 10], edge_index=[2, 50]),
#  Data(x=[26, 10], edge_index=[2, 50]),
#  Data(x=[15, 10], edge_index=[2, 28]),
#  Data(x=[28, 10], edge_index=[2, 54]),
#  Data(x=[21, 10], edge_index=[2, 40]),
#  Data(x=[25, 10], edge_index=[2, 50]),
#  Data(x=[31, 10], edge_index=[2, 60]),
#  Data(x=[32, 10], edge_index=[2, 64]),
#  Data(x=[36, 10], edge_index=[2, 72]),
#  Data(x=[11, 10], edge_index=[2, 20]),
#  Data(x=[9, 10], edge_index=[2, 16]),
#  Data(x=[22, 10], edge_index=[2, 42]),
#  Data(x=[20, 10], edge_index=[2, 40]),
#  Data(x=[13, 10], edge_index=[2, 24]),
#  Data(x=[33, 10], edge_index=[2, 66]),
#  Data(x=[17, 10], edge_index=[2, 32]),
#  Data(x=[18, 10], edge_index=[2, 38]),
#  Data(x=[6, 10], edge_index=[2, 12]),
#  Data(x=[8, 10], edge_index=[2, 14]),
#  Data(x=[6, 10], edge_index=[2, 10]),
#  Data(x=[9, 10], edge_index=[2, 16]),
#  Data(x=[11, 10], edge_index=[2, 20]),
#  Data(x=[12, 10], edge_index=[2, 24]),
#  Data(x=[25, 10], edge_index=[2, 48]),
#  Data(x=[16, 10], edge_index=[2, 30]),
#  Data(x=[12, 10], edge_index=[2, 24]),
#  Data(x=[13, 10], edge_index=[2, 24]),
#  Data(x=[9, 10], edge_index=[2, 16]),
#  Data(x=[12, 10], edge_index=[2, 22]),
#  Data(x=[19, 10], edge_index=[2, 36]),
#  Data(x=[6, 10], edge_index=[2, 10]),
#  Data(x=[6, 10], edge_index=[2, 10]),
#  Data(x=[14, 10], edge_index=[2, 26]),
#  Data(x=[23, 10], edge_index=[2, 46]),
#  Data(x=[12, 10], edge_index=[2, 24]),
#  Data(x=[25, 10], edge_index=[2, 52]),
#  Data(x=[16, 10], edge_index=[2, 30]),
#  Data(x=[23, 10], edge_index=[2, 44]),
#  Data(x=[12, 10], edge_index=[2, 22]),
#  Data(x=[22, 10], edge_index=[2, 42]),
#  Data(x=[22, 10], edge_index=[2, 42]),
#  Data(x=[27, 10], edge_index=[2, 52]),
#  Data(x=[28, 10], edge_index=[2, 58]),
#  Data(x=[31, 10], edge_index=[2, 68]),
#  Data(x=[44, 10], edge_index=[2, 92]),
#  Data(x=[42, 10], edge_index=[2, 88]),
#  Data(x=[24, 10], edge_index=[2, 48]),
#  Data(x=[54, 10], edge_index=[2, 106]),
#  Data(x=[35, 10], edge_index=[2, 74]),
#  Data(x=[13, 10], edge_index=[2, 24]),
#  Data(x=[25, 10], edge_index=[2, 52]),
#  Data(x=[20, 10], edge_index=[2, 38]),
#  Data(x=[21, 10], edge_index=[2, 40]),
#  Data(x=[31, 10], edge_index=[2, 60]),
#  Data(x=[25, 10], edge_index=[2, 52]),
#  Data(x=[45, 10], edge_index=[2, 88]),
#  Data(x=[38, 10], edge_index=[2, 76]),
#  Data(x=[21, 10], edge_index=[2, 44]),
#  Data(x=[29, 10], edge_index=[2, 58]),
#  Data(x=[33, 10], edge_index=[2, 70]),
#  Data(x=[39, 10], edge_index=[2, 78]),
#  Data(x=[14, 10], edge_index=[2, 26]),
#  Data(x=[19, 10], edge_index=[2, 36]),
#  Data(x=[25, 10], edge_index=[2, 54]),
#  Data(x=[18, 10], edge_index=[2, 34]),
#  Data(x=[26, 10], edge_index=[2, 54]),
#  Data(x=[31, 10], edge_index=[2, 62]),
#  Data(x=[28, 10], edge_index=[2, 56]),
#  Data(x=[18, 10], edge_index=[2, 34]),
#  Data(x=[17, 10], edge_index=[2, 34]),
#  Data(x=[9, 10], edge_index=[2, 16]),
#  Data(x=[29, 10], edge_index=[2, 58]),
#  Data(x=[24, 10], edge_index=[2, 48]),
#  Data(x=[17, 10], edge_index=[2, 32]),
#  Data(x=[14, 10], edge_index=[2, 26]),
#  Data(x=[41, 10], edge_index=[2, 86]),
#  Data(x=[23, 10], edge_index=[2, 46]),
#  Data(x=[6, 10], edge_index=[2, 10]),
#  Data(x=[10, 10], edge_index=[2, 18]),
#  Data(x=[10, 10], edge_index=[2, 18]),
#  Data(x=[17, 10], edge_index=[2, 32]),
#  Data(x=[14, 10], edge_index=[2, 26]),
#  Data(x=[13, 10], edge_index=[2, 26]),
#  Data(x=[18, 10], edge_index=[2, 36]),
#  Data(x=[14, 10], edge_index=[2, 26]),
#  Data(x=[27, 10], edge_index=[2, 52]),
#  Data(x=[19, 10], edge_index=[2, 38]),
#  Data(x=[36, 10], edge_index=[2, 76]),
#  Data(x=[15, 10], edge_index=[2, 28]),
#  Data(x=[7, 10], edge_index=[2, 12]),
#  Data(x=[19, 10], edge_index=[2, 36]),
#  Data(x=[18, 10], edge_index=[2, 34]),
#  Data(x=[16, 10], edge_index=[2, 30]),
#  Data(x=[45, 10], edge_index=[2, 98]),
#  Data(x=[19, 10], edge_index=[2, 36]),
#  Data(x=[45, 10], edge_index=[2, 88]),
#  Data(x=[15, 10], edge_index=[2, 30]),
#  Data(x=[23, 10], edge_index=[2, 46]),
#  Data(x=[31, 10], edge_index=[2, 62]),
#  Data(x=[49, 10], edge_index=[2, 100]),
#  Data(x=[30, 10], edge_index=[2, 62]),
#  Data(x=[26, 10], edge_index=[2, 50]),
#  Data(x=[49, 10], edge_index=[2, 96]),
#  Data(x=[46, 10], edge_index=[2, 96]),
#  Data(x=[48, 10], edge_index=[2, 96]),
#  Data(x=[28, 10], edge_index=[2, 54]),
#  Data(x=[25, 10], edge_index=[2, 52]),
#  Data(x=[41, 10], edge_index=[2, 84]),
#  Data(x=[24, 10], edge_index=[2, 48]),
#  Data(x=[61, 10], edge_index=[2, 142]),
#  Data(x=[25, 10], edge_index=[2, 50]),
#  Data(x=[18, 10], edge_index=[2, 38]),
#  Data(x=[17, 10], edge_index=[2, 32]),
#  Data(x=[24, 10], edge_index=[2, 50]),
#  Data(x=[20, 10], edge_index=[2, 40]),
#  Data(x=[18, 10], edge_index=[2, 34]),
#  Data(x=[13, 10], edge_index=[2, 24]),
#  Data(x=[25, 10], edge_index=[2, 48]),
#  Data(x=[10, 10], edge_index=[2, 18]),
#  Data(x=[13, 10], edge_index=[2, 26]),
#  Data(x=[27, 10], edge_index=[2, 56]),
#  Data(x=[13, 10], edge_index=[2, 24]),
#  Data(x=[18, 10], edge_index=[2, 34]),
#  Data(x=[22, 10], edge_index=[2, 46]),
#  Data(x=[11, 10], edge_index=[2, 20]),
#  Data(x=[31, 10], edge_index=[2, 66]),
#  Data(x=[35, 10], edge_index=[2, 70]),
#  Data(x=[24, 10], edge_index=[2, 50]),
#  Data(x=[22, 10], edge_index=[2, 48]),
#  Data(x=[17, 10], edge_index=[2, 34]),
#  Data(x=[22, 10], edge_index=[2, 42]),
#  Data(x=[16, 10], edge_index=[2, 34]),
#  Data(x=[17, 10], edge_index=[2, 32]),
#  Data(x=[16, 10], edge_index=[2, 34]),
#  Data(x=[20, 10], edge_index=[2, 44]),
#  Data(x=[32, 10], edge_index=[2, 68]),
#  Data(x=[18, 10], edge_index=[2, 36]),
#  Data(x=[12, 10], edge_index=[2, 24]),
#  Data(x=[23, 10], edge_index=[2, 50]),
#  Data(x=[35, 10], edge_index=[2, 68]),
#  Data(x=[23, 10], edge_index=[2, 44]),
#  Data(x=[29, 10], edge_index=[2, 58]),
#  Data(x=[18, 10], edge_index=[2, 36]),
#  Data(x=[8, 10], edge_index=[2, 14]),
#  Data(x=[11, 10], edge_index=[2, 20]),
#  Data(x=[14, 10], edge_index=[2, 26]),
#  Data(x=[9, 10], edge_index=[2, 16]),
#  Data(x=[29, 10], edge_index=[2, 58]),
#  Data(x=[20, 10], edge_index=[2, 40]),
#  Data(x=[29, 10], edge_index=[2, 58]),
#  Data(x=[24, 10], edge_index=[2, 48]),
#  Data(x=[14, 10], edge_index=[2, 26]),
#  Data(x=[15, 10], edge_index=[2, 28]),
#  Data(x=[16, 10], edge_index=[2, 30]),
#  Data(x=[10, 10], edge_index=[2, 18]),
#  Data(x=[17, 10], edge_index=[2, 34]),
#  Data(x=[36, 10], edge_index=[2, 72]),
#  Data(x=[10, 10], edge_index=[2, 18]),
#  Data(x=[15, 10], edge_index=[2, 30]),
#  Data(x=[24, 10], edge_index=[2, 46]),
#  Data(x=[23, 10], edge_index=[2, 44]),
#  Data(x=[21, 10], edge_index=[2, 42]),
#  Data(x=[15, 10], edge_index=[2, 28]),
#  Data(x=[9, 10], edge_index=[2, 16]),
#  Data(x=[19, 10], edge_index=[2, 40]),
#  Data(x=[13, 10], edge_index=[2, 26]),
#  Data(x=[23, 10], edge_index=[2, 48]),
#  Data(x=[24, 10], edge_index=[2, 50]),
#  Data(x=[13, 10], edge_index=[2, 24]),
#  Data(x=[24, 10], edge_index=[2, 50]),
#  Data(x=[12, 10], edge_index=[2, 22]),
#  Data(x=[15, 10], edge_index=[2, 32]),
#  Data(x=[20, 10], edge_index=[2, 42]),
#  Data(x=[18, 10], edge_index=[2, 34]),
#  Data(x=[27, 10], edge_index=[2, 52]),
#  Data(x=[7, 10], edge_index=[2, 12]),
#  Data(x=[10, 10], edge_index=[2, 18]),
#  Data(x=[24, 10], edge_index=[2, 54]),
#  Data(x=[22, 10], edge_index=[2, 44]),
#  Data(x=[6, 10], edge_index=[2, 10]),
#  Data(x=[18, 10], edge_index=[2, 36]),
#  Data(x=[19, 10], edge_index=[2, 38]),
#  Data(x=[8, 10], edge_index=[2, 14]),
#  Data(x=[8, 10], edge_index=[2, 14]),
#  Data(x=[11, 10], edge_index=[2, 20]),
#  Data(x=[16, 10], edge_index=[2, 30]),
#  Data(x=[14, 10], edge_index=[2, 28]),
#  Data(x=[7, 10], edge_index=[2, 12]),
#  Data(x=[21, 10], edge_index=[2, 46]),
#  Data(x=[12, 10], edge_index=[2, 24]),
#  Data(x=[23, 10], edge_index=[2, 46]),
#  Data(x=[9, 10], edge_index=[2, 16]),
#  Data(x=[26, 10], edge_index=[2, 58]),
#  Data(x=[14, 10], edge_index=[2, 26]),
#  Data(x=[29, 10], edge_index=[2, 59]),
#  Data(x=[22, 10], edge_index=[2, 42]),
#  Data(x=[12, 10], edge_index=[2, 24]),
#  Data(x=[13, 10], edge_index=[2, 24]),
#  Data(x=[18, 10], edge_index=[2, 36]),
#  Data(x=[21, 10], edge_index=[2, 44]),
#  Data(x=[17, 10], edge_index=[2, 34]),
#  Data(x=[21, 10], edge_index=[2, 44]),
#  Data(x=[17, 10], edge_index=[2, 34]),
#  Data(x=[16, 10], edge_index=[2, 34]),
#  Data(x=[14, 10], edge_index=[2, 26]),
#  Data(x=[13, 10], edge_index=[2, 24]),
#  Data(x=[16, 10], edge_index=[2, 34]),
#  Data(x=[12, 10], edge_index=[2, 22]),
#  Data(x=[10, 10], edge_index=[2, 18]),
#  Data(x=[12, 10], edge_index=[2, 22]),
#  Data(x=[9, 10], edge_index=[2, 16]),
#  Data(x=[17, 10], edge_index=[2, 32]),
#  Data(x=[12, 10], edge_index=[2, 22]),
#  Data(x=[14, 10], edge_index=[2, 26]),
#  Data(x=[17, 10], edge_index=[2, 32]),
#  Data(x=[18, 10], edge_index=[2, 36]),
#  Data(x=[14, 10], edge_index=[2, 26]),
#  Data(x=[11, 10], edge_index=[2, 20]),
#  Data(x=[6, 10], edge_index=[2, 10]),
#  Data(x=[6, 10], edge_index=[2, 10]),
#  Data(x=[10, 10], edge_index=[2, 18]),
#  Data(x=[8, 10], edge_index=[2, 14]),
#  Data(x=[5, 10], edge_index=[2, 8]),
#  Data(x=[11, 10], edge_index=[2, 20]),
#  Data(x=[28, 10], edge_index=[2, 58]),
#  Data(x=[6, 10], edge_index=[2, 10]),
#  Data(x=[26, 10], edge_index=[2, 56]),
#  Data(x=[16, 10], edge_index=[2, 30]),
#  Data(x=[11, 10], edge_index=[2, 20]),
#  Data(x=[41, 10], edge_index=[2, 80]),
#  Data(x=[284, 10], edge_index=[2, 756]),
#  Data(x=[78, 10], edge_index=[2, 168]),
#  Data(x=[83, 10], edge_index=[2, 202]),
#  Data(x=[116, 10], edge_index=[2, 280]),
#  Data(x=[49, 10], edge_index=[2, 136]),
#  Data(x=[109, 10], edge_index=[2, 238]),
#  Data(x=[68, 10], edge_index=[2, 154]),
#  Data(x=[114, 10], edge_index=[2, 262]),
#  Data(x=[104, 10], edge_index=[2, 222]),
#  Data(x=[96, 10], edge_index=[2, 234]),
#  Data(x=[94, 10], edge_index=[2, 214]),
#  Data(x=[121, 10], edge_index=[2, 270]),
#  Data(x=[107, 10], edge_index=[2, 244]),
#  Data(x=[69, 10], edge_index=[2, 150]),
#  Data(x=[97, 10], edge_index=[2, 224]),
#  Data(x=[99, 10], edge_index=[2, 228]),
#  Data(x=[109, 10], edge_index=[2, 242]),
#  Data(x=[91, 10], edge_index=[2, 206]),
#  Data(x=[111, 10], edge_index=[2, 272]),
#  Data(x=[86, 10], edge_index=[2, 204]),
#  Data(x=[104, 10], edge_index=[2, 258]),
#  Data(x=[122, 10], edge_index=[2, 280]),
#  Data(x=[106, 10], edge_index=[2, 264]),
#  Data(x=[104, 10], edge_index=[2, 254]),
#  Data(x=[116, 10], edge_index=[2, 262]),
#  Data(x=[120, 10], edge_index=[2, 264]),
#  Data(x=[125, 10], edge_index=[2, 277]),
#  Data(x=[125, 10], edge_index=[2, 286]),
#  Data(x=[128, 10], edge_index=[2, 288]),
#  Data(x=[111, 10], edge_index=[2, 272]),
#  Data(x=[109, 10], edge_index=[2, 256]),
#  Data(x=[91, 10], edge_index=[2, 224]),
#  Data(x=[125, 10], edge_index=[2, 310]),
#  Data(x=[110, 10], edge_index=[2, 230]),
#  Data(x=[125, 10], edge_index=[2, 270]),
#  Data(x=[121, 10], edge_index=[2, 260]),
#  Data(x=[105, 10], edge_index=[2, 238]),
#  Data(x=[121, 10], edge_index=[2, 262]),
#  Data(x=[129, 10], edge_index=[2, 272]),
#  Data(x=[120, 10], edge_index=[2, 278]),
#  Data(x=[104, 10], edge_index=[2, 232]),
#  Data(x=[97, 10], edge_index=[2, 212]),
#  Data(x=[102, 10], edge_index=[2, 248]),
#  Data(x=[103, 10], edge_index=[2, 234]),
#  Data(x=[117, 10], edge_index=[2, 280]),
#  Data(x=[91, 10], edge_index=[2, 214]),
#  Data(x=[89, 10], edge_index=[2, 206]),
#  Data(x=[108, 10], edge_index=[2, 256]),
#  Data(x=[109, 10], edge_index=[2, 260]),
#  Data(x=[112, 10], edge_index=[2, 260]),
#  Data(x=[90, 10], edge_index=[2, 184]),
#  Data(x=[48, 10], edge_index=[2, 94]),
#  Data(x=[55, 10], edge_index=[2, 120]),
#  Data(x=[87, 10], edge_index=[2, 196]),
#  Data(x=[88, 10], edge_index=[2, 194]),
#  Data(x=[81, 10], edge_index=[2, 186]),
#  Data(x=[105, 10], edge_index=[2, 244]),
#  Data(x=[97, 10], edge_index=[2, 226]),
#  Data(x=[95, 10], edge_index=[2, 214]),
#  Data(x=[83, 10], edge_index=[2, 202]),
#  Data(x=[98, 10], edge_index=[2, 224]),
#  Data(x=[43, 10], edge_index=[2, 88]),
#  Data(x=[105, 10], edge_index=[2, 250]),
#  Data(x=[96, 10], edge_index=[2, 230]),
#  Data(x=[45, 10], edge_index=[2, 96]),
#  Data(x=[105, 10], edge_index=[2, 252]),
#  Data(x=[48, 10], edge_index=[2, 98]),
#  Data(x=[103, 10], edge_index=[2, 252]),
#  Data(x=[126, 10], edge_index=[2, 280]),
#  Data(x=[109, 10], edge_index=[2, 254]),
#  Data(x=[119, 10], edge_index=[2, 286]),
#  Data(x=[59, 10], edge_index=[2, 140]),
#  Data(x=[112, 10], edge_index=[2, 238]),
#  Data(x=[84, 10], edge_index=[2, 182]),
#  Data(x=[93, 10], edge_index=[2, 202]),
#  Data(x=[71, 10], edge_index=[2, 164]),
#  Data(x=[126, 10], edge_index=[2, 294]),
#  Data(x=[80, 10], edge_index=[2, 206]),
#  Data(x=[84, 10], edge_index=[2, 184]),
#  Data(x=[98, 10], edge_index=[2, 256]),
#  Data(x=[77, 10], edge_index=[2, 172]),
#  Data(x=[78, 10], edge_index=[2, 168]),
#  Data(x=[79, 10], edge_index=[2, 174]),
#  Data(x=[111, 10], edge_index=[2, 254]),
#  Data(x=[129, 10], edge_index=[2, 282]),
#  Data(x=[80, 10], edge_index=[2, 184]),
#  Data(x=[98, 10], edge_index=[2, 209]),
#  Data(x=[78, 10], edge_index=[2, 169]),
#  Data(x=[92, 10], edge_index=[2, 218]),
#  Data(x=[77, 10], edge_index=[2, 184]),
#  Data(x=[91, 10], edge_index=[2, 200]),
#  Data(x=[77, 10], edge_index=[2, 164]),
#  Data(x=[86, 10], edge_index=[2, 194]),
#  Data(x=[77, 10], edge_index=[2, 184]),
#  Data(x=[77, 10], edge_index=[2, 192]),
#  Data(x=[98, 10], edge_index=[2, 236]),
#  Data(x=[75, 10], edge_index=[2, 166]),
#  Data(x=[143, 10], edge_index=[2, 316]),
#  Data(x=[118, 10], edge_index=[2, 268]),
#  Data(x=[109, 10], edge_index=[2, 284]),
#  Data(x=[69, 10], edge_index=[2, 148]),
#  Data(x=[81, 10], edge_index=[2, 176]),
#  Data(x=[110, 10], edge_index=[2, 248]),
#  Data(x=[80, 10], edge_index=[2, 186]),
#  Data(x=[100, 10], edge_index=[2, 234]),
#  Data(x=[70, 10], edge_index=[2, 164]),
#  Data(x=[46, 10], edge_index=[2, 102]),
#  Data(x=[79, 10], edge_index=[2, 174]),
#  Data(x=[107, 10], edge_index=[2, 246]),
#  Data(x=[69, 10], edge_index=[2, 154]),
#  Data(x=[96, 10], edge_index=[2, 220]),
#  Data(x=[105, 10], edge_index=[2, 248]),
#  Data(x=[79, 10], edge_index=[2, 180]),
#  Data(x=[102, 10], edge_index=[2, 232]),
#  Data(x=[85, 10], edge_index=[2, 182]),
#  Data(x=[108, 10], edge_index=[2, 257]),
#  Data(x=[94, 10], edge_index=[2, 212]),
#  Data(x=[99, 10], edge_index=[2, 218]),
#  Data(x=[112, 10], edge_index=[2, 278]),
#  Data(x=[116, 10], edge_index=[2, 264]),
#  Data(x=[104, 10], edge_index=[2, 248]),
#  Data(x=[81, 10], edge_index=[2, 176]),
#  Data(x=[97, 10], edge_index=[2, 222]),
#  Data(x=[109, 10], edge_index=[2, 262]),
#  Data(x=[79, 10], edge_index=[2, 190]),
#  Data(x=[64, 10], edge_index=[2, 136]),
#  Data(x=[84, 10], edge_index=[2, 188]),
#  Data(x=[85, 10], edge_index=[2, 189]),
#  Data(x=[78, 10], edge_index=[2, 178]),
#  Data(x=[92, 10], edge_index=[2, 213]),
#  Data(x=[69, 10], edge_index=[2, 142]),
#  Data(x=[105, 10], edge_index=[2, 224]),
#  Data(x=[78, 10], edge_index=[2, 166]),
#  Data(x=[105, 10], edge_index=[2, 262]),
#  Data(x=[84, 10], edge_index=[2, 200]),
#  Data(x=[86, 10], edge_index=[2, 188]),
#  Data(x=[91, 10], edge_index=[2, 216]),
#  Data(x=[102, 10], edge_index=[2, 226]),
#  Data(x=[102, 10], edge_index=[2, 224]),
#  Data(x=[112, 10], edge_index=[2, 244]),
#  Data(x=[110, 10], edge_index=[2, 246]),
#  Data(x=[115, 10], edge_index=[2, 270]),
#  Data(x=[115, 10], edge_index=[2, 272]),
#  Data(x=[125, 10], edge_index=[2, 278]),
#  Data(x=[73, 10], edge_index=[2, 170]),
#  Data(x=[77, 10], edge_index=[2, 174]),
#  Data(x=[105, 10], edge_index=[2, 246]),
#  Data(x=[103, 10], edge_index=[2, 230]),
#  Data(x=[75, 10], edge_index=[2, 160]),
#  Data(x=[50, 10], edge_index=[2, 102]),
#  Data(x=[85, 10], edge_index=[2, 176]),
#  Data(x=[98, 10], edge_index=[2, 224]),
#  Data(x=[87, 10], edge_index=[2, 191]),
#  Data(x=[81, 10], edge_index=[2, 184]),
#  Data(x=[74, 10], edge_index=[2, 166]),
#  Data(x=[84, 10], edge_index=[2, 190]),
#  Data(x=[199, 10], edge_index=[2, 480]),
#  Data(x=[94, 10], edge_index=[2, 210]),
#  Data(x=[79, 10], edge_index=[2, 168]),
#  Data(x=[46, 10], edge_index=[2, 96]),
#  Data(x=[99, 10], edge_index=[2, 222]),
#  Data(x=[77, 10], edge_index=[2, 180]),
#  Data(x=[100, 10], edge_index=[2, 222]),
#  Data(x=[123, 10], edge_index=[2, 286]),
#  Data(x=[104, 10], edge_index=[2, 230]),
#  Data(x=[36, 10], edge_index=[2, 74]),
#  Data(x=[84, 10], edge_index=[2, 198]),
#  Data(x=[209, 10], edge_index=[2, 486]),
#  Data(x=[72, 10], edge_index=[2, 160]),
#  Data(x=[115, 10], edge_index=[2, 264]),
#  Data(x=[81, 10], edge_index=[2, 190]),
#  Data(x=[80, 10], edge_index=[2, 174]),
#  Data(x=[94, 10], edge_index=[2, 200]),
#  Data(x=[189, 10], edge_index=[2, 474]),
#  Data(x=[68, 10], edge_index=[2, 148]),
#  Data(x=[76, 10], edge_index=[2, 172]),
#  Data(x=[123, 10], edge_index=[2, 270]),
#  Data(x=[78, 10], edge_index=[2, 176]),
#  Data(x=[54, 10], edge_index=[2, 116]),
#  Data(x=[39, 10], edge_index=[2, 78]),
#  Data(x=[99, 10], edge_index=[2, 228]),
#  Data(x=[86, 10], edge_index=[2, 180]),
#  Data(x=[114, 10], edge_index=[2, 262]),
#  Data(x=[115, 10], edge_index=[2, 272]),
#  Data(x=[131, 10], edge_index=[2, 284]),
#  Data(x=[122, 10], edge_index=[2, 278]),
#  Data(x=[129, 10], edge_index=[2, 292]),
#  Data(x=[88, 10], edge_index=[2, 200]),
#  Data(x=[92, 10], edge_index=[2, 196]),
#  Data(x=[79, 10], edge_index=[2, 172]),
#  Data(x=[92, 10], edge_index=[2, 220]),
#  Data(x=[101, 10], edge_index=[2, 232]),
#  Data(x=[109, 10], edge_index=[2, 246]),
#  Data(x=[116, 10], edge_index=[2, 271]),
#  Data(x=[93, 10], edge_index=[2, 226]),
#  Data(x=[82, 10], edge_index=[2, 184]),
#  Data(x=[91, 10], edge_index=[2, 194]),
#  Data(x=[73, 10], edge_index=[2, 157]),
#  Data(x=[48, 10], edge_index=[2, 98]),
#  Data(x=[99, 10], edge_index=[2, 262]),
#  Data(x=[86, 10], edge_index=[2, 206]),
#  Data(x=[78, 10], edge_index=[2, 180]),
#  Data(x=[83, 10], edge_index=[2, 186]),
#  Data(x=[55, 10], edge_index=[2, 128]),
#  Data(x=[99, 10], edge_index=[2, 222]),
#  Data(x=[117, 10], edge_index=[2, 268]),
#  Data(x=[107, 10], edge_index=[2, 236]),
#  Data(x=[96, 10], edge_index=[2, 212]),
#  Data(x=[90, 10], edge_index=[2, 192]),
#  Data(x=[87, 10], edge_index=[2, 182]),
#  Data(x=[71, 10], edge_index=[2, 156]),
#  Data(x=[114, 10], edge_index=[2, 254]),
#  Data(x=[115, 10], edge_index=[2, 252]),
#  Data(x=[134, 10], edge_index=[2, 300]),
#  Data(x=[77, 10], edge_index=[2, 186]),
#  Data(x=[73, 10], edge_index=[2, 158]),
#  Data(x=[77, 10], edge_index=[2, 174]),
#  Data(x=[110, 10], edge_index=[2, 256]),
#  Data(x=[73, 10], edge_index=[2, 156]),
#  Data(x=[131, 10], edge_index=[2, 310]),
#  Data(x=[92, 10], edge_index=[2, 200]),
#  Data(x=[97, 10], edge_index=[2, 214]),
#  Data(x=[106, 10], edge_index=[2, 262]),
#  Data(x=[100, 10], edge_index=[2, 232]),
#  Data(x=[107, 10], edge_index=[2, 246]),
#  Data(x=[123, 10], edge_index=[2, 288]),
#  Data(x=[82, 10], edge_index=[2, 184]),
#  Data(x=[94, 10], edge_index=[2, 210]),
#  Data(x=[81, 10], edge_index=[2, 168]),
#  Data(x=[65, 10], edge_index=[2, 146]),
#  Data(x=[84, 10], edge_index=[2, 203]),
#  Data(x=[83, 10], edge_index=[2, 200]),
#  Data(x=[36, 10], edge_index=[2, 76]),
#  Data(x=[104, 10], edge_index=[2, 236]),
#  Data(x=[91, 10], edge_index=[2, 200]),
#  Data(x=[101, 10], edge_index=[2, 212]),
#  Data(x=[74, 10], edge_index=[2, 162]),
#  Data(x=[76, 10], edge_index=[2, 160]),
#  Data(x=[96, 10], edge_index=[2, 214]),
#  Data(x=[86, 10], edge_index=[2, 184]),
#  Data(x=[78, 10], edge_index=[2, 215]),
#  Data(x=[87, 10], edge_index=[2, 190]),
#  Data(x=[111, 10], edge_index=[2, 268]),
#  Data(x=[113, 10], edge_index=[2, 260]),
#  Data(x=[96, 10], edge_index=[2, 228]),
#  Data(x=[106, 10], edge_index=[2, 252]),
#  Data(x=[42, 10], edge_index=[2, 88]),
#  Data(x=[111, 10], edge_index=[2, 250]),
#  Data(x=[88, 10], edge_index=[2, 208]),
#  Data(x=[78, 10], edge_index=[2, 172]),
#  Data(x=[59, 10], edge_index=[2, 120]),
#  Data(x=[90, 10], edge_index=[2, 198]),
#  Data(x=[95, 10], edge_index=[2, 218]),
#  Data(x=[75, 10], edge_index=[2, 164]),
#  Data(x=[97, 10], edge_index=[2, 236]),
#  Data(x=[76, 10], edge_index=[2, 180]),
#  Data(x=[31, 10], edge_index=[2, 66]),
#  Data(x=[38, 10], edge_index=[2, 90]),
#  Data(x=[52, 10], edge_index=[2, 108]),
#  Data(x=[53, 10], edge_index=[2, 114]),
#  Data(x=[103, 10], edge_index=[2, 254]),
#  Data(x=[116, 10], edge_index=[2, 275]),
#  Data(x=[119, 10], edge_index=[2, 272]),
#  Data(x=[90, 10], edge_index=[2, 198]),
#  Data(x=[95, 10], edge_index=[2, 220]),
#  Data(x=[99, 10], edge_index=[2, 226]),
#  Data(x=[92, 10], edge_index=[2, 194]),
#  Data(x=[103, 10], edge_index=[2, 262]),
#  Data(x=[119, 10], edge_index=[2, 266]),
#  Data(x=[55, 10], edge_index=[2, 148]),
#  Data(x=[80, 10], edge_index=[2, 184]),
#  Data(x=[69, 10], edge_index=[2, 150]),
#  Data(x=[81, 10], edge_index=[2, 186]),
#  Data(x=[99, 10], edge_index=[2, 244]),
#  Data(x=[102, 10], edge_index=[2, 250]),
#  Data(x=[121, 10], edge_index=[2, 288]),
#  Data(x=[91, 10], edge_index=[2, 196]),
#  Data(x=[102, 10], edge_index=[2, 238]),
#  Data(x=[90, 10], edge_index=[2, 219]),
#  Data(x=[83, 10], edge_index=[2, 204]),
#  Data(x=[66, 10], edge_index=[2, 150]),
#  Data(x=[93, 10], edge_index=[2, 198]),
#  Data(x=[83, 10], edge_index=[2, 200]),
#  Data(x=[72, 10], edge_index=[2, 160]),
#  Data(x=[76, 10], edge_index=[2, 164]),
#  Data(x=[62, 10], edge_index=[2, 134]),
#  Data(x=[64, 10], edge_index=[2, 140]),
#  Data(x=[65, 10], edge_index=[2, 146]),
#  Data(x=[82, 10], edge_index=[2, 178]),
#  Data(x=[66, 10], edge_index=[2, 156]),
#  Data(x=[73, 10], edge_index=[2, 170]),
#  Data(x=[106, 10], edge_index=[2, 258]),
#  Data(x=[99, 10], edge_index=[2, 216]),
#  Data(x=[115, 10], edge_index=[2, 266]),
#  Data(x=[123, 10], edge_index=[2, 284]),
#  Data(x=[84, 10], edge_index=[2, 188]),
#  Data(x=[74, 10], edge_index=[2, 170]),
#  Data(x=[80, 10], edge_index=[2, 210]),
#  Data(x=[79, 10], edge_index=[2, 172]),
#  Data(x=[91, 10], edge_index=[2, 206]),
#  Data(x=[124, 10], edge_index=[2, 284]),
#  Data(x=[94, 10], edge_index=[2, 210]),
#  Data(x=[110, 10], edge_index=[2, 244]),
#  Data(x=[105, 10], edge_index=[2, 220]),
#  Data(x=[55, 10], edge_index=[2, 108]),
#  Data(x=[79, 10], edge_index=[2, 166]),
#  Data(x=[78, 10], edge_index=[2, 186]),
#  Data(x=[80, 10], edge_index=[2, 204]),
#  Data(x=[102, 10], edge_index=[2, 242]),
#  Data(x=[124, 10], edge_index=[2, 290]),
#  Data(x=[92, 10], edge_index=[2, 210]),
#  Data(x=[119, 10], edge_index=[2, 276]),
#  Data(x=[92, 10], edge_index=[2, 226]),
#  Data(x=[100, 10], edge_index=[2, 224]),
#  Data(x=[98, 10], edge_index=[2, 234]),
#  Data(x=[110, 10], edge_index=[2, 238]),
#  Data(x=[87, 10], edge_index=[2, 200]),
#  Data(x=[86, 10], edge_index=[2, 182]),
#  Data(x=[110, 10], edge_index=[2, 262]),
#  Data(x=[105, 10], edge_index=[2, 256]),
#  Data(x=[115, 10], edge_index=[2, 282]),
#  Data(x=[118, 10], edge_index=[2, 272]),
#  Data(x=[93, 10], edge_index=[2, 206]),
#  Data(x=[104, 10], edge_index=[2, 248]),
#  Data(x=[91, 10], edge_index=[2, 216]),
#  Data(x=[111, 10], edge_index=[2, 258]),
#  Data(x=[74, 10], edge_index=[2, 176]),
#  Data(x=[109, 10], edge_index=[2, 261]),
#  Data(x=[114, 10], edge_index=[2, 264]),
#  Data(x=[107, 10], edge_index=[2, 230]),
#  Data(x=[106, 10], edge_index=[2, 244]),
#  Data(x=[109, 10], edge_index=[2, 261]),
#  Data(x=[112, 10], edge_index=[2, 264]),
#  Data(x=[92, 10], edge_index=[2, 216]),
#  Data(x=[99, 10], edge_index=[2, 246]),
#  Data(x=[102, 10], edge_index=[2, 244]),
#  Data(x=[114, 10], edge_index=[2, 276]),
#  Data(x=[73, 10], edge_index=[2, 167]),
#  Data(x=[95, 10], edge_index=[2, 210]),
#  Data(x=[70, 10], edge_index=[2, 156]),
#  Data(x=[109, 10], edge_index=[2, 232]),
#  Data(x=[63, 10], edge_index=[2, 142]),
#  Data(x=[88, 10], edge_index=[2, 188]),
#  Data(x=[91, 10], edge_index=[2, 218]),
#  Data(x=[72, 10], edge_index=[2, 152]),
#  Data(x=[94, 10], edge_index=[2, 214]),
#  Data(x=[73, 10], edge_index=[2, 160]),
#  Data(x=[186, 10], edge_index=[2, 452]),
#  Data(x=[53, 10], edge_index=[2, 110]),
#  Data(x=[110, 10], edge_index=[2, 250]),
#  Data(x=[77, 10], edge_index=[2, 160]),
#  Data(x=[78, 10], edge_index=[2, 182]),
#  Data(x=[81, 10], edge_index=[2, 170]),
#  Data(x=[64, 10], edge_index=[2, 150]),
#  Data(x=[75, 10], edge_index=[2, 178]),
#  Data(x=[70, 10], edge_index=[2, 148]),
#  Data(x=[81, 10], edge_index=[2, 182]),
#  Data(x=[95, 10], edge_index=[2, 204]),
#  Data(x=[100, 10], edge_index=[2, 234]),
#  Data(x=[90, 10], edge_index=[2, 198]),
#  Data(x=[99, 10], edge_index=[2, 244]),
#  Data(x=[91, 10], edge_index=[2, 226]),
#  Data(x=[70, 10], edge_index=[2, 162]),
#  Data(x=[86, 10], edge_index=[2, 196]),
#  Data(x=[129, 10], edge_index=[2, 288]),
#  Data(x=[98, 10], edge_index=[2, 212]),
#  Data(x=[116, 10], edge_index=[2, 274]),
#  Data(x=[90, 10], edge_index=[2, 200]),
#  Data(x=[81, 10], edge_index=[2, 198]),
#  Data(x=[56, 10], edge_index=[2, 128]),
#  Data(x=[78, 10], edge_index=[2, 186]),
#  Data(x=[65, 10], edge_index=[2, 150]),
#  Data(x=[77, 10], edge_index=[2, 176]),
#  Data(x=[76, 10], edge_index=[2, 166]),
#  Data(x=[79, 10], edge_index=[2, 184]),
#  Data(x=[83, 10], edge_index=[2, 178]),
#  Data(x=[88, 10], edge_index=[2, 196]),
#  Data(x=[87, 10], edge_index=[2, 222]),
#  Data(x=[80, 10], edge_index=[2, 164]),
#  Data(x=[83, 10], edge_index=[2, 174]),
#  Data(x=[85, 10], edge_index=[2, 194]),
#  Data(x=[77, 10], edge_index=[2, 174]),
#  Data(x=[91, 10], edge_index=[2, 198]),
#  Data(x=[74, 10], edge_index=[2, 164]),
#  Data(x=[109, 10], edge_index=[2, 248]),
#  Data(x=[67, 10], edge_index=[2, 144]),
#  Data(x=[88, 10], edge_index=[2, 196]),
#  Data(x=[88, 10], edge_index=[2, 182]),
#  Data(x=[70, 10], edge_index=[2, 148]),
#  Data(x=[75, 10], edge_index=[2, 160]),
#  Data(x=[81, 10], edge_index=[2, 166]),
#  Data(x=[80, 10], edge_index=[2, 170]),
#  Data(x=[99, 10], edge_index=[2, 214]),
#  Data(x=[103, 10], edge_index=[2, 232]),
#  Data(x=[111, 10], edge_index=[2, 252]),
#  Data(x=[111, 10], edge_index=[2, 264]),
#  Data(x=[74, 10], edge_index=[2, 156]),
#  Data(x=[94, 10], edge_index=[2, 230]),
#  Data(x=[113, 10], edge_index=[2, 258]),
#  Data(x=[73, 10], edge_index=[2, 162]),
#  Data(x=[80, 10], edge_index=[2, 184]),
#  Data(x=[121, 10], edge_index=[2, 278]),
#  Data(x=[113, 10], edge_index=[2, 272]),
#  Data(x=[77, 10], edge_index=[2, 168]),
#  Data(x=[70, 10], edge_index=[2, 178]),
#  Data(x=[77, 10], edge_index=[2, 174]),
#  Data(x=[70, 10], edge_index=[2, 158]),
#  Data(x=[84, 10], edge_index=[2, 192]),
#  Data(x=[96, 10], edge_index=[2, 208]),
#  Data(x=[111, 10], edge_index=[2, 250]),
#  Data(x=[90, 10], edge_index=[2, 208]),
#  Data(x=[64, 10], edge_index=[2, 150]),
#  Data(x=[76, 10], edge_index=[2, 166]),
#  Data(x=[85, 10], edge_index=[2, 186]),
#  Data(x=[70, 10], edge_index=[2, 163]),
#  Data(x=[80, 10], edge_index=[2, 180]),
#  Data(x=[94, 10], edge_index=[2, 210]),
#  Data(x=[104, 10], edge_index=[2, 267]),
#  Data(x=[76, 10], edge_index=[2, 172]),
#  Data(x=[94, 10], edge_index=[2, 220]),
#  Data(x=[50, 10], edge_index=[2, 100]),
#  Data(x=[98, 10], edge_index=[2, 236]),
#  Data(x=[90, 10], edge_index=[2, 204]),
#  Data(x=[87, 10], edge_index=[2, 210]),
#  Data(x=[100, 10], edge_index=[2, 254]),
#  Data(x=[94, 10], edge_index=[2, 212]),
#  Data(x=[69, 10], edge_index=[2, 164]),
#  Data(x=[74, 10], edge_index=[2, 168]),
#  Data(x=[66, 10], edge_index=[2, 154]),
#  Data(x=[50, 10], edge_index=[2, 104]),
#  Data(x=[67, 10], edge_index=[2, 150]),
#  Data(x=[87, 10], edge_index=[2, 192]),
#  Data(x=[76, 10], edge_index=[2, 169]),
#  Data(x=[53, 10], edge_index=[2, 138]),
#  Data(x=[112, 10], edge_index=[2, 270]),
#  Data(x=[79, 10], edge_index=[2, 182]),
#  Data(x=[87, 10], edge_index=[2, 198]),
#  Data(x=[91, 10], edge_index=[2, 210]),
#  Data(x=[103, 10], edge_index=[2, 248]),
#  Data(x=[97, 10], edge_index=[2, 226]),
#  Data(x=[82, 10], edge_index=[2, 178]),
#  Data(x=[94, 10], edge_index=[2, 218]),
#  Data(x=[89, 10], edge_index=[2, 206]),
#  Data(x=[81, 10], edge_index=[2, 189]),
#  Data(x=[78, 10], edge_index=[2, 172]),
#  Data(x=[73, 10], edge_index=[2, 164]),
#  Data(x=[121, 10], edge_index=[2, 303]),
#  Data(x=[79, 10], edge_index=[2, 176]),
#  Data(x=[68, 10], edge_index=[2, 158]),
#  Data(x=[84, 10], edge_index=[2, 182]),
#  Data(x=[88, 10], edge_index=[2, 204]),
#  Data(x=[104, 10], edge_index=[2, 220]),
#  Data(x=[127, 10], edge_index=[2, 310]),
#  Data(x=[75, 10], edge_index=[2, 169]),
#  Data(x=[76, 10], edge_index=[2, 166]),
#  Data(x=[80, 10], edge_index=[2, 174]),
#  Data(x=[91, 10], edge_index=[2, 206]),
#  Data(x=[90, 10], edge_index=[2, 212]),
#  Data(x=[84, 10], edge_index=[2, 196]),
#  Data(x=[92, 10], edge_index=[2, 214]),
#  Data(x=[76, 10], edge_index=[2, 160]),
#  Data(x=[115, 10], edge_index=[2, 266]),
#  Data(x=[78, 10], edge_index=[2, 158]),
#  Data(x=[81, 10], edge_index=[2, 166]),
#  Data(x=[99, 10], edge_index=[2, 220]),
#  Data(x=[77, 10], edge_index=[2, 166]),
#  Data(x=[88, 10], edge_index=[2, 196]),
#  Data(x=[83, 10], edge_index=[2, 176]),
#  Data(x=[117, 10], edge_index=[2, 268]),
#  Data(x=[102, 10], edge_index=[2, 222]),
#  Data(x=[115, 10], edge_index=[2, 244]),
#  Data(x=[115, 10], edge_index=[2, 256]),
#  Data(x=[92, 10], edge_index=[2, 212]),
#  Data(x=[193, 10], edge_index=[2, 448]),
#  Data(x=[86, 10], edge_index=[2, 204]),
#  Data(x=[94, 10], edge_index=[2, 226]),
#  Data(x=[90, 10], edge_index=[2, 203]),
#  Data(x=[58, 10], edge_index=[2, 136]),
#  Data(x=[72, 10], edge_index=[2, 164]),
#  Data(x=[93, 10], edge_index=[2, 223]),
#  Data(x=[80, 10], edge_index=[2, 188]),
#  Data(x=[95, 10], edge_index=[2, 204]),
#  Data(x=[104, 10], edge_index=[2, 234]),
#  Data(x=[80, 10], edge_index=[2, 174]),
#  Data(x=[93, 10], edge_index=[2, 204]),
#  Data(x=[75, 10], edge_index=[2, 164]),
#  Data(x=[84, 10], edge_index=[2, 198]),
#  Data(x=[79, 10], edge_index=[2, 172]),
#  Data(x=[99, 10], edge_index=[2, 236]),
#  Data(x=[76, 10], edge_index=[2, 168]),
#  Data(x=[96, 10], edge_index=[2, 226]),
#  Data(x=[82, 10], edge_index=[2, 198]),
#  Data(x=[85, 10], edge_index=[2, 192]),
#  Data(x=[90, 10], edge_index=[2, 200]),
#  Data(x=[95, 10], edge_index=[2, 204]),
#  Data(x=[100, 10], edge_index=[2, 224]),
#  Data(x=[97, 10], edge_index=[2, 226]),
#  Data(x=[86, 10], edge_index=[2, 216]),
#  Data(x=[81, 10], edge_index=[2, 172]),
#  Data(x=[87, 10], edge_index=[2, 184]),
#  Data(x=[90, 10], edge_index=[2, 232]),
#  Data(x=[81, 10], edge_index=[2, 180]),
#  Data(x=[105, 10], edge_index=[2, 224]),
#  Data(x=[100, 10], edge_index=[2, 218]),
#  Data(x=[90, 10], edge_index=[2, 206]),
#  Data(x=[96, 10], edge_index=[2, 209]),
#  Data(x=[106, 10], edge_index=[2, 228]),
#  Data(x=[92, 10], edge_index=[2, 192]),
#  Data(x=[116, 10], edge_index=[2, 276]),
#  Data(x=[89, 10], edge_index=[2, 192]),
#  Data(x=[83, 10], edge_index=[2, 208]),
#  Data(x=[67, 10], edge_index=[2, 158]),
#  Data(x=[88, 10], edge_index=[2, 200]),
#  Data(x=[98, 10], edge_index=[2, 220]),
#  Data(x=[83, 10], edge_index=[2, 174]),
#  Data(x=[84, 10], edge_index=[2, 172]),
#  Data(x=[87, 10], edge_index=[2, 192]),
#  Data(x=[94, 10], edge_index=[2, 208]),
#  Data(x=[80, 10], edge_index=[2, 162]),
#  Data(x=[91, 10], edge_index=[2, 186]),
#  Data(x=[88, 10], edge_index=[2, 192]),
#  Data(x=[75, 10], edge_index=[2, 166]),
#  Data(x=[88, 10], edge_index=[2, 212]),
#  Data(x=[78, 10], edge_index=[2, 180]),
#  Data(x=[96, 10], edge_index=[2, 210]),
#  Data(x=[75, 10], edge_index=[2, 184]),
#  Data(x=[69, 10], edge_index=[2, 154]),
#  Data(x=[89, 10], edge_index=[2, 204]),
#  Data(x=[72, 10], edge_index=[2, 162]),
#  Data(x=[99, 10], edge_index=[2, 220]),
#  Data(x=[74, 10], edge_index=[2, 174]),
#  Data(x=[120, 10], edge_index=[2, 270]),
#  Data(x=[82, 10], edge_index=[2, 168]),
#  Data(x=[87, 10], edge_index=[2, 221]),
#  Data(x=[92, 10], edge_index=[2, 204]),
#  Data(x=[106, 10], edge_index=[2, 246]),
#  Data(x=[82, 10], edge_index=[2, 182]),
#  Data(x=[79, 10], edge_index=[2, 162]),
#  Data(x=[110, 10], edge_index=[2, 250]),
#  Data(x=[93, 10], edge_index=[2, 202]),
#  Data(x=[97, 10], edge_index=[2, 224]),
#  Data(x=[106, 10], edge_index=[2, 266]),
#  Data(x=[42, 10], edge_index=[2, 84]),
#  Data(x=[307, 10], edge_index=[2, 984]),
#  Data(x=[304, 10], edge_index=[2, 864]),
#  Data(x=[37, 10], edge_index=[2, 72]),
#  Data(x=[26, 10], edge_index=[2, 54]),
#  Data(x=[30, 10], edge_index=[2, 62]),
#  Data(x=[43, 10], edge_index=[2, 90]),
#  Data(x=[55, 10], edge_index=[2, 112]),
#  Data(x=[49, 10], edge_index=[2, 106]),
#  Data(x=[58, 10], edge_index=[2, 138]),
#  Data(x=[47, 10], edge_index=[2, 106]),
#  Data(x=[53, 10], edge_index=[2, 106]),
#  Data(x=[59, 10], edge_index=[2, 128]),
#  Data(x=[48, 10], edge_index=[2, 108]),
#  Data(x=[48, 10], edge_index=[2, 104]),
#  Data(x=[71, 10], edge_index=[2, 166]),
#  Data(x=[54, 10], edge_index=[2, 140]),
#  Data(x=[37, 10], edge_index=[2, 80]),
#  Data(x=[18, 10], edge_index=[2, 36]),
#  Data(x=[18, 10], edge_index=[2, 36]),
#  Data(x=[23, 10], edge_index=[2, 48]),
#  Data(x=[61, 10], edge_index=[2, 130]),
#  Data(x=[35, 10], edge_index=[2, 74]),
#  Data(x=[44, 10], edge_index=[2, 96]),
#  Data(x=[42, 10], edge_index=[2, 96]),
#  Data(x=[40, 10], edge_index=[2, 82]),
#  Data(x=[70, 10], edge_index=[2, 154]),
#  Data(x=[35, 10], edge_index=[2, 70]),
#  Data(x=[60, 10], edge_index=[2, 138]),
#  Data(x=[72, 10], edge_index=[2, 158]),
#  Data(x=[73, 10], edge_index=[2, 156]),
#  Data(x=[45, 10], edge_index=[2, 96]),
#  Data(x=[58, 10], edge_index=[2, 128]),
#  Data(x=[70, 10], edge_index=[2, 150]),
#  Data(x=[89, 10], edge_index=[2, 188]),
#  Data(x=[99, 10], edge_index=[2, 220]),
#  Data(x=[58, 10], edge_index=[2, 122]),
#  Data(x=[92, 10], edge_index=[2, 216]),
#  Data(x=[67, 10], edge_index=[2, 142]),
#  Data(x=[40, 10], edge_index=[2, 82]),
#  Data(x=[52, 10], edge_index=[2, 106]),
#  Data(x=[55, 10], edge_index=[2, 112]),
#  Data(x=[56, 10], edge_index=[2, 112]),
#  Data(x=[57, 10], edge_index=[2, 132]),
#  Data(x=[62, 10], edge_index=[2, 130]),
#  Data(x=[54, 10], edge_index=[2, 118]),
#  Data(x=[67, 10], edge_index=[2, 140]),
#  Data(x=[31, 10], edge_index=[2, 64]),
#  Data(x=[80, 10], edge_index=[2, 174]),
#  Data(x=[77, 10], edge_index=[2, 174]),
#  Data(x=[43, 10], edge_index=[2, 88]),
#  Data(x=[32, 10], edge_index=[2, 62]),
#  Data(x=[58, 10], edge_index=[2, 133]),
#  Data(x=[23, 10], edge_index=[2, 48]),
#  Data(x=[78, 10], edge_index=[2, 182]),
#  Data(x=[33, 10], edge_index=[2, 74]),
#  Data(x=[27, 10], edge_index=[2, 52]),
#  Data(x=[46, 10], edge_index=[2, 100]),
#  Data(x=[37, 10], edge_index=[2, 78]),
#  ...]

# %%
len(datasetGrafi1and3)
# Out:
# 10299

# %%
data_load1and3 = DataLoader(datasetGrafi1and3, batch_size=128)

# %%
data_load1and3
data_load
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25788\1428782851.py in <module>
#       1 data_load1and3
# ----> 2 data_load
#
# NameError: name 'data_load' is not defined

# %%
with open('datasetGrafi_NO_ripetizioni_layer1and_layer3.pkl', 'wb') as file:
    pickle.dump(datasetGrafi1and3, file)

# %%
listaa = ['a','b','c']

# %%
listab = ['d','e','f']

# %%
listaa.extend(listab)

# %%
listaa
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f']
